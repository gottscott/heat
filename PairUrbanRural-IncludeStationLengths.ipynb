# %%
# import libraries
# %matplotlib inline
import numpy as np
#import csv
import matplotlib.pyplot as plt
import pandas as pd
import glob
import ulmo
import os
import scipy.spatial

# %%
ghcn = pd.read_fwf('data/ghcnd-stations.txt', colspecs = [(0,11), (12,19), (21,29), (31,36),(38,40), (41,70), (72,74),(76,78),(80,85)], header = None) 
colnames = ['GHCN ID', 'lat', 'lon', 'elevation', 'state', 'name', 'gsn flag', 'HCN/CRN FLAG', 'WMO ID']
ghcn.columns = colnames

# append the brightness index 
BI = np.load('data/brightnessGHCN.npy')
ghcn['Brightness'] = BI
# from http://www1.ncdc.noaa.gov/pub/data/ghcn/daily/readme.txt
# FORMAT OF "ghcnd-stations.txt"
#
# ------------------------------
# Variable   Columns   Type
# ------------------------------
# ID            1-11   Character
# LATITUDE     13-20   Real
# LONGITUDE    22-30   Real
# ELEVATION    32-37   Real
# STATE        39-40   Character
# NAME         42-71   Character
# GSN FLAG     73-75   Character
# HCN/CRN FLAG 77-79   Character
# WMO ID       81-85   Character
# ------------------------------

# These variables have the following definitions:

# ID         is the station identification code.  Note that the first two
#            characters denote the FIPS  country code, the third character 
#            is a network code that identifies the station numbering system 
#            used, and the remaining eight characters contain the actual 
#            station ID. 

#            See "ghcnd-countries.txt" for a complete list of country codes.
# 	   See "ghcnd-states.txt" for a list of state/province/territory codes.

#            The network code  has the following five values:

#            0 = unspecified (station identified by up to eight 
# 	       alphanumeric characters)
# 	   1 = Community Collaborative Rain, Hail,and Snow (CoCoRaHS)
# 	       based identification number.  To ensure consistency with
# 	       with GHCN Daily, all numbers in the original CoCoRaHS IDs
# 	       have been left-filled to make them all four digits long. 
# 	       In addition, the characters "-" and "_" have been removed 
# 	       to ensure that the IDs do not exceed 11 characters when 
# 	       preceded by "US1". For example, the CoCoRaHS ID 
# 	       "AZ-MR-156" becomes "US1AZMR0156" in GHCN-Daily
#            C = U.S. Cooperative Network identification number (last six 
#                characters of the GHCN-Daily ID)
# 	   E = Identification number used in the ECA&D non-blended
# 	       dataset
# 	   M = World Meteorological Organization ID (last five
# 	       characters of the GHCN-Daily ID)
# 	   N = Identification number used in data supplied by a 
# 	       National Meteorological or Hydrological Center
# 	   R = U.S. Interagency Remote Automatic Weather Station (RAWS)
# 	       identifier
# 	   S = U.S. Natural Resources Conservation Service SNOwpack
# 	       TELemtry (SNOTEL) station identifier
#            W = WBAN identification number (last five characters of the 
#                GHCN-Daily ID)

# LATITUDE   is latitude of the station (in decimal degrees).

# LONGITUDE  is the longitude of the station (in decimal degrees).

# ELEVATION  is the elevation of the station (in meters, missing = -999.9).


# STATE      is the U.S. postal code for the state (for U.S. stations only).

# NAME       is the name of the station.

# GSN FLAG   is a flag that indicates whether the station is part of the GCOS
#            Surface Network (GSN). The flag is assigned by cross-referencing 
#            the number in the WMOID field with the official list of GSN 
#            stations. There are two possible values:

#            Blank = non-GSN station or WMO Station number not available
#            GSN   = GSN station 

# HCN/      is a flag that indicates whether the station is part of the U.S.
# CRN FLAG  Historical Climatology Network (HCN).  There are three possible 
#           values:

#            Blank = Not a member of the U.S. Historical Climatology 
# 	           or U.S. Climate Reference Networks
#            HCN   = U.S. Historical Climatology Network station
# 	   CRN   = U.S. Climate Reference Network or U.S. Regional Climate 
# 	           Network Station

# WMO ID     is the World Meteorological Organization (WMO) number for the
#            station.  If the station has no WMO number (or one has not yet 
# 	   been matched to this station), then the field is blank.

# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
giss = pd.read_fwf('data/v3.temperature.inv.txt',skiprows = 39, header = None,
                  colspecs=[(0,3),(3,8),(8,11), (12,44),(44,49), (52,58), (58,63), (63,67), (67,68), (69,73), (73,75), (75, 77), (78,79), (79,81), (81,82),(82,84), (84,100), (100,102), (103,106)])
colnames = ['icc country code', 'WMO ID', '3 digit modifier', 'name','lat', 'lon', 'elevation', 'TELe', 'P', 'Pop', 'Tp', 'V', 'Lo', 'Co', 'Airport', 'ds', 'Vege', 'bi', 'BI']
giss.columns = colnames

# LEGEND  
# ======
# icc  =3 digit country code; the first digit represents WMO region/continent
# WMO_#=5 digit WMO station number
# ...  =3 digit modifier; 000 means the station is probably the WMO
#       station; 001, etc. mean the station is near that WMO station
# Name =30 character station name
# Lat  =latitude in degrees, negative = South of Equator
# Lon  =longitude in degrees, negative = West of Greenwich (England)
# Elev =station elevation in meters, missing is -999
# TEle =station elevation interpolated from TerrainBase gridded data set
# P    =R if rural (not associated with a town of >10,000 population)
#       S if associated with a small town (10,000-50,000 population)
#       U if associated with an urban area (>50,000 population)
# Pop  =population of the small town or urban area in 1000s
#       If rural, no analysis:  -9.
# Tp   =general topography around the station:  FL flat; HI hilly,
#       MT mountain top; MV mountainous valley or at least not on the top
#       of a mountain.
# V    =general vegetation near the station based on Operational
#       Navigation Charts;  MA marsh; FO forested; IC ice; DE desert;
#       CL clear or open;  xx information not provided
# Lo   =CO if station is within 30 km from the coast
#       LA if station is next to a large (> 25 km**2) lake
#       no if neither of the above
#       Note: Stations which are both CO and LA will be marked CO
# Co   =distance in km to the coast if Lo=CO, else -9
# A    =A if the station is at an airport; else x
# ds   =distance in km from the airport to its associated
#       small town or urban center (not relevant for rural airports
#       or non airport stations in which case ds=-9)
# Vege =gridded vegetation for the 0.5x0.5 degree grid point closest
#       to the station from a gridded vegetation data base. 16 characters.
# bi   =brightness index    A=dark B=dim C=bright   (comment added by R.Ruedy)
# BI   =brightness index    0=dark -> 256 =bright   (based on satellite night light data)

# %% [markdown]
# see: http://stackoverflow.com/questions/35296935/python-calculate-lots-of-distances-quickly

# %%
# subset the GHCN station list with the list of available stations
currentstations = ulmo.ncdc.ghcn_daily.get_stations(start_year=1985, end_year = 2016, elements = ['TMIN', 'TMAX', 'AWND'], as_dataframe=True, update=False)
currentGHCNstations = np.intersect1d(currentstations.id, ghcn.index.values) #ghcn['GHCN ID'].values)
ghcnSubset = ghcn.set_index('GHCN ID').loc[currentstations.id.values]

# at this point, ghcn must have the station id set as the index

# %%
ghcn = ghcn.set_index('GHCN ID').loc[currentstations.id.values]

# %%
# compute distances between all stations
#tree = scipy.spatial.cKDTree(giss[['lon', 'lat']].values, leafsize=100)
# query the closest point 
#closestInd = tree.query(giss[['lon', 'lat']].values[11,:], k =2, distance_upper_bound=6)[1][1]

# %%
atlas = pd.read_csv('data/sampleAtlas.csv') # derived  from http://www.naturalearthdata.com/downloads/10m-cultural-vectors/10m-populated-places/
atlas = pd.read_csv('data/world_cities.csv')
tree = scipy.spatial.cKDTree(ghcn[['lon', 'lat']].values, leafsize=100)
#import sys
#sys.path.append('/../cityheat/Bmore/2015/')
#sys.path.append('/Users/annascott2/mountpoint/cityheat/Bmore/2015/')
#import spatialfunctions
atlas = atlas[atlas['pop']> 500000]

# %%
atlas = pd.read_csv('data/world_cities.csv')

# %%
atlas = atlas[~atlas['country'].str.contains('United States')] # do non-US countries

# %%
#atlas = atlas[atlas['country'].str.contains('United States')]

# %%
brightness_threshold = 25 # this is the urban/rural threshold delimiter, difference between urban and rural
outFile = 'worldghcnpairs_stationlengths.csv'
pairs = []
#for i in range(793, atlas.shape[0]): 
for i in range(0, atlas.shape[0]):
    lat = atlas.iloc[i]['lat']
    lon = atlas.iloc[i]['lng']
    city = atlas.iloc[i]['city']
    closeststations = tree.query([lon,lat], k =15, distance_upper_bound=1)

    # Make sure the closest stations are within a finite distance
    closestInds = closeststations[1][~np.isinf(closeststations[0])]
    # make sure that there are stations 
    if closestInds.shape[0] > 0 : 
        urban = ghcn.Brightness[closestInds].argmax()
        rural = ghcn.Brightness[closestInds].argmin()
        #         if urban != rural: 
        urban_data = ulmo.ncdc.ghcn_daily.get_data(urban, as_dataframe=True, update=False)
        rural_data = ulmo.ncdc.ghcn_daily.get_data(rural, as_dataframe=True, update=False)

        number_urban_stations = (ghcn.Brightness[closestInds] >= brightness_threshold).sum() # number of urban stations is equivalent to brightness over 30
        number_rural_stations = (ghcn.Brightness[closestInds] < brightness_threshold).sum() # number of rural stations is equivalent to brightness over 30
        delta_brightness = 30
        break_value = -1

        iii = 1
        while ('TMAX' not in urban_data.keys() or 'TMIN' not in urban_data.keys()) or (urban_data['TMAX'].index[0].to_timestamp().to_datetime() > startdate) or (urban_data['TMAX'].index[-1].to_timestamp().to_datetime() < enddate) : 
            # check if there's enough suitable urban stations to check the next one, ignoring the current one 
            if iii > number_urban_stations-1 : 
                print 'no suitable urban station for %s'%city
                urban = break_value
                break 
            # find the next brightest
            print 'finding the next urban station for %s'%city
            urban = ghcn.Brightness[closestInds][(-ghcn.Brightness[closestInds].values).argsort()].index[iii]
            urban_data = ulmo.ncdc.ghcn_daily.get_data(urban, as_dataframe=True, update=False)
            print urban, urban_data['TMAX'].index[0], urban_data['TMAX'].index[-1], ghcn.Brightness[urban], urban_data.keys()
            iii = iii+1    

        # if no urban station found, don't bother to pair with rural 
        if urban != break_value : 
            # check rural data station different from urban has TMIN, TMAX, a long enough record, and is rural enough compared to urban (delta_brightness)
            iii = 1
            enlarge_circle = 0 # number of times we can try increasing search radius
            while (urban ==rural) or ('TMAX' not in rural_data.keys() and 'TMIN' not in rural_data.keys()) and (rural_data['TMIN'].index[0].to_timestamp().to_datetime() > startdate or rural_data['TMIN'].index[-1].to_timestamp().to_datetime() < enddate) or (ghcn.Brightness[urban]-ghcn.Brightness[rural]<delta_brightness): 
                print 'finding the next rural station for %s'%city

                # if we can't find any suitable stations, try enlarging the search radius, but only try this once
                if iii > number_rural_stations-1 : 
                    if enlarge_circle > 0 : 
                        rural = break_value
                        break #break when we've already used up all the search
                    else: 
                        # find 25 closest stations within 1.5 degree circle
                        closeststations1 = tree.query([lon,lat], k =35, distance_upper_bound=1.5 ) 
                        # eliminate the ones we've already search 
                        new_stations = np.setdiff1d(closeststations1[1], closeststations[1])
                        # Make sure that we've actually found new stations, otherwise break
                        if new_stations.shape[0] >0 : 
                            # Make sure the closest stations are within a finite distance
                            closestInds1 = closeststations1[1][~np.isinf(closeststations1[0])]
                            # Eliminate repeat stations
                            closestInds = np.intersect1d(new_stations, closestInds1)
                            # reset counter, number of rural stations
                            iii = 0
                            number_rural_stations = (ghcn.Brightness[closestInds] < brightness_threshold).sum()
                        else: 
                            rural = break_value
                            break
                        # reset list of rural stations
                    print 'increasing search radius'
                    enlarge_circle = enlarge_circle+1
                    
                # find the next dimmest
                rural = ghcn.Brightness[closestInds][(ghcn.Brightness[closestInds].values).argsort()].index[iii]
                rural_data = ulmo.ncdc.ghcn_daily.get_data(rural, as_dataframe=True, update=False)
                #print rural, rural_data['TMIN'].index[0], rural_data['TMIN'].index[-1], ghcn.Brightness[rural], rural_data.keys()
                iii = iii+1
        else: 
            rural = break_value
    # else condition for not being any stations
    else: 
        urban = break_value 
        rural = break_value
            
    # save out if we've found a good pairing
    if (urban != break_value) and (rural != break_value) : 
        print 'Found a pair for %s'%city
        frames.append([city, urban, #['GHCN ID'],
                       ghcn.loc[urban].lat, 
                       ghcn.loc[urban].lon, 
                       ghcn.loc[urban].Brightness, 
                       rural, #['GHCN ID'],
                       ghcn.loc[rural].lat, 
                       ghcn.loc[rural].lon, 

                       ghcn.loc[rural].Brightness])
    else : 
        print 'No pair found for %s'%city
        frames.append([city, np.nan, #['GHCN ID'],
                       np.nan,
                       np.nan,
                       np.nan, 
                       np.nan, #['GHCN ID'],
                       np.nan,
                       np.nan,
                       np.nan])

    # periodiically save out results
    if i%50 ==0: 
        pairs = pd.DataFrame(frames, columns = ['City', 'Urban station', 
                                          'Urban Lat', 'Urban Lon','Urban brightness', 
                                          'Rural station', 
                                          'Rural Lat', 'Rural Lon','Rural brightness'])
        pairs.to_csv(outFile)
        
pairs = pd.DataFrame(frames, columns = ['City', 'Urban station', 
                                  'Urban Lat', 'Urban Lon','Urban brightness', 
                                  'Rural station', 
                                  'Rural Lat', 'Rural Lon','Rural brightness'])
pairs.to_csv(outFile)
# Out:
# no suitable urban station for Kandahar
# No pair found for Kandahar
# no suitable urban station for Kabul
# No pair found for Kabul
# finding the next urban station for Tirana
# ALM00013615 1973-04-01 2016-08-31 51.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# Found a pair for Tirana
# Found a pair for Constantine
# finding the next urban station for Oran
# AGM00060452 1985-02-01 2016-08-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Oran
# AGM00060520 1995-10-01 2016-08-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next urban station for Oran
# AGM00060490 1957-01-01 2016-08-31 46.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# Found a pair for Oran
# Found a pair for Algiers
# No pair found for Huambo
# finding the next rural station for Luanda
# No pair found for Luanda
# finding the next rural station for Tucumán
# increasing search radius
# finding the next rural station for Tucumán
# No pair found for Tucumán
# finding the next rural station for Rosario
# increasing search radius
# finding the next rural station for Rosario
# No pair found for Rosario
# finding the next rural station for Mendoza
# increasing search radius
# Found a pair for Mendoza
# finding the next rural station for Mar del Plata
# No pair found for Mar del Plata
# finding the next rural station for Córdoba
# increasing search radius
# finding the next rural station for Córdoba
# No pair found for Córdoba
# Found a pair for Buenos Aires
# finding the next urban station for Yerevan
# AM000037704 1973-01-01 2016-08-31 56.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# Found a pair for Yerevan
# finding the next urban station for Newcastle
# ASN00061390 1998-07-01 2016-07-31 63.0 ['TMIN', 'DATX', 'TMAX', 'MDTX', 'DATN', 'MDTN', 'DAPR', 'DWPR', 'PRCP', 'MDPR']
# finding the next urban station for Newcastle
# ASN00061388 1997-06-01 2016-07-31 58.0 ['TMIN', 'DATX', 'TMAX', 'MDTX', 'DATN', 'MDTN', 'DAPR', 'DWPR', 'PRCP', 'MDPR']
# finding the next urban station for Newcastle
# ASN00061078 1942-09-01 2016-08-31 45.0 ['TAVG', 'TMIN', 'DATX', 'TMAX', 'MDTX', 'DAPR', 'DWPR', 'PRCP', 'MDPR']
# Found a pair for Newcastle
# Found a pair for Adelaide
# finding the next urban station for Brisbane
# ASN00040913 1999-12-01 2016-07-31 63.0 ['TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Brisbane
# ASN00040223 1949-06-01 2016-08-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# Found a pair for Brisbane
# finding the next urban station for Perth
# ASN00009151 1986-05-01 2000-08-31 63.0 ['TMIN', 'DATX', 'TMAX', 'MDTX', 'DATN', 'MDTN', 'DAPR', 'DWPR', 'PRCP', 'MDPR']
# finding the next urban station for Perth
# ASN00009225 1993-11-01 2016-07-31 63.0 ['TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Perth
# ASN00009161 1971-08-01 1987-02-28 63.0 ['TMIN', 'DATX', 'TMAX', 'MDTX', 'DATN', 'MDTN', 'DAPR', 'DWPR', 'PRCP', 'MDPR']
# finding the next urban station for Perth
# ASN00009192 1983-03-01 1999-05-31 63.0 ['TMIN', 'DATX', 'TMAX', 'MDTX', 'DATN', 'MDTN', 'DAPR', 'DWPR', 'PRCP', 'MDPR']
# finding the next urban station for Perth
# ASN00009250 1997-11-01 2001-01-31 63.0 ['TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Perth
# ASN00009021 1944-06-01 2016-08-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# Found a pair for Perth
# Found a pair for Melbourne
# finding the next rural station for Sydney
# increasing search radius
# Found a pair for Sydney
# finding the next rural station for Vienna
# increasing search radius
# Found a pair for Vienna
# finding the next urban station for Baku
# AJ000037923 1959-01-01 2016-08-31 32.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next rural station for Baku
# finding the next rural station for Baku
# increasing search radius
# finding the next rural station for Baku
# finding the next rural station for Baku
# finding the next rural station for Baku
# No pair found for Baku
# finding the next rural station for Khulna
# finding the next rural station for Khulna
# increasing search radius
# finding the next rural station for Khulna
# No pair found for Khulna
# Found a pair for Rajshahi
# Found a pair for Dhaka
# Found a pair for Chittagong
# Found a pair for Minsk
# Found a pair for Antwerpen
# Found a pair for Brussels
# Found a pair for Cotonou
# finding the next rural station for Cochabamba
# increasing search radius
# finding the next rural station for Cochabamba
# No pair found for Cochabamba
# finding the next rural station for La Paz
# No pair found for La Paz
# Found a pair for Santa Cruz
# Found a pair for Sarajevo
# finding the next rural station for Nova Iguacu
# increasing search radius
# finding the next rural station for Nova Iguacu
# No pair found for Nova Iguacu
# finding the next rural station for Duque de Caxias
# increasing search radius
# finding the next rural station for Duque de Caxias
# No pair found for Duque de Caxias
# finding the next rural station for Niteroi
# increasing search radius
# finding the next rural station for Niteroi
# No pair found for Niteroi
# finding the next rural station for Santo Andre
# increasing search radius
# finding the next rural station for Santo Andre
# No pair found for Santo Andre
# finding the next urban station for Sao Jose dos Campos
# BR00E3-1520 1978-04-01 1982-07-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Sao Jose dos Campos
# BR00E3-0070 1973-02-01 1996-09-30 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Sao Jose dos Campos
# BR00E3-0520 1973-04-01 2015-12-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next rural station for Sao Jose dos Campos
# increasing search radius
# Found a pair for Sao Jose dos Campos
# no suitable urban station for Jaboatao
# No pair found for Jaboatao
# finding the next urban station for Olinda
# BR039402250 1975-05-01 2002-06-30 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# no suitable urban station for Olinda
# No pair found for Olinda
# no suitable urban station for Novo Hamburgo
# No pair found for Novo Hamburgo
# finding the next urban station for Joinville
# BR002548005 1973-02-01 1992-12-31 61.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Joinville
# BR002649005 1993-01-01 1997-04-30 35.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'MDPR']
# no suitable urban station for Joinville
# No pair found for Joinville
# no suitable urban station for Vitória
# No pair found for Vitória
# finding the next urban station for Joao Pessoa
# BRM00082900 1974-06-01 1997-03-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# no suitable urban station for Joao Pessoa
# No pair found for Joao Pessoa
# No pair found for Natal
# finding the next urban station for Aracaju
# BR001036026 1996-08-01 1996-08-31 30.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'MDPR']
# no suitable urban station for Aracaju
# No pair found for Aracaju
# finding the next rural station for Vila Velha
# No pair found for Vila Velha
# finding the next rural station for Santos
# increasing search radius
# finding the next rural station for Santos
# No pair found for Santos
# no suitable urban station for São Luís
# No pair found for São Luís
# finding the next urban station for Belo Horizonte
# BRM00083566 2002-01-01 2015-12-31 62.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Belo Horizonte
# BRM00083587 1977-06-01 2006-03-31 62.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# no suitable urban station for Belo Horizonte
# No pair found for Belo Horizonte
# no suitable urban station for Cuiaba
# No pair found for Cuiaba
# finding the next urban station for Teresina
# BR037041370 1973-02-01 2015-12-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next rural station for Teresina
# increasing search radius
# finding the next rural station for Teresina
# No pair found for Teresina
# Found a pair for Maceio
# no suitable urban station for Vila Velha
# No pair found for Vila Velha
# finding the next urban station for Natal
# BR038192160 1978-05-01 1993-07-31 34.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# no suitable urban station for Natal
# No pair found for Natal
# finding the next urban station for Campinas
# BR00E3-0070 1973-02-01 1996-09-30 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Campinas
# BR00E3-1520 1978-04-01 1982-07-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Campinas
# BR00E3-0520 1973-04-01 2015-12-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# Found a pair for Campinas
# finding the next urban station for Sorocaba
# BR00E3-0520 1973-04-01 2015-12-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next rural station for Sorocaba
# increasing search radius
# finding the next rural station for Sorocaba
# No pair found for Sorocaba
# finding the next urban station for Ribeirao Preto
# BR002047016 1973-05-01 1999-02-28 62.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Ribeirao Preto
# BR00C4-0170 1990-06-01 1996-09-30 41.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# no suitable urban station for Ribeirao Preto
# No pair found for Ribeirao Preto
# no suitable urban station for Manaus
# No pair found for Manaus
# no suitable urban station for Campo Grande
# No pair found for Campo Grande
# finding the next urban station for Florianopolis
# BR002649005 1993-01-01 1997-04-30 35.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'MDPR']
# no suitable urban station for Florianopolis
# No pair found for Florianopolis
# finding the next urban station for Belem
# BRM00082193 1973-04-01 2015-12-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next rural station for Belem
# increasing search radius
# Found a pair for Belem
# no suitable urban station for Brasilia
# No pair found for Brasilia
# no suitable urban station for Porto Alegre
# No pair found for Porto Alegre
# finding the next urban station for Curitiba
# BR002548005 1973-02-01 1992-12-31 61.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Curitiba
# BR002450000 1992-06-01 1992-06-30 61.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# no suitable urban station for Curitiba
# No pair found for Curitiba
# no suitable urban station for Fortaleza
# No pair found for Fortaleza
# no suitable urban station for Salvador
# No pair found for Salvador
# finding the next urban station for Goiania
# BR001548003 1989-11-01 2001-10-31 50.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# no suitable urban station for Goiania
# No pair found for Goiania
# finding the next urban station for Recife
# BR039402250 1975-05-01 2002-06-30 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# no suitable urban station for Recife
# No pair found for Recife
# finding the next rural station for Rio de Janeiro
# increasing search radius
# finding the next rural station for Rio de Janeiro
# No pair found for Rio de Janeiro
# finding the next urban station for Sao Paulo
# BR00E3-0520 1973-04-01 2015-12-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next rural station for Sao Paulo
# increasing search radius
# finding the next rural station for Sao Paulo
# No pair found for Sao Paulo
# finding the next rural station for Sofia
# increasing search radius
# finding the next rural station for Sofia
# No pair found for Sofia
# finding the next rural station for Ouagadougou
# increasing search radius
# Found a pair for Ouagadougou
# no suitable urban station for Phnom Penh
# No pair found for Phnom Penh
# finding the next rural station for Douala
# increasing search radius
# finding the next rural station for Douala
# No pair found for Douala
# No pair found for Yaounde
# finding the next urban station for Hamilton
# CA006153298 1960-03-01 1993-08-31 63.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Hamilton
# CA006155PM4 1983-10-01 1987-04-30 63.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Hamilton
# CA006153300 1950-04-01 1997-10-31 62.0 ['TMIN', 'TMAX', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Hamilton
# CA006151064 1951-04-01 1999-09-30 62.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Hamilton
# CA006155PD4 1990-04-01 2006-10-31 62.0 ['TMIN', 'TMAX', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Hamilton
# CA006151061 1992-12-01 2016-08-31 60.0 ['TAVG', 'WDFG', 'TMAX', 'TMIN', 'WSFG']
# finding the next urban station for Hamilton
# CA006153301 1997-11-01 2016-08-31 58.0 ['TAVG', 'TMIN', 'TMAX', 'WDFG', 'SNOW', 'WSFG', 'SNWD', 'PRCP']
# finding the next urban station for Hamilton
# CA006133047 1910-01-01 1985-08-31 58.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Hamilton
# CA006153194 1959-11-01 2011-12-31 55.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Hamilton
# CA006153193 2011-12-01 2016-08-31 55.0 ['TAVG', 'TMIN', 'TMAX', 'WDFG', 'SNOW', 'WSFG', 'SNWD', 'PRCP']
# finding the next urban station for Hamilton
# CA006155183 1951-03-01 2006-04-30 41.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Hamilton
# CA00615EAQG 1993-10-01 1997-07-31 36.0 ['TMAX', 'PRCP', 'TMIN', 'SNOW', 'SNWD']
# finding the next urban station for Hamilton
# CA006150060 1994-06-01 2008-12-31 32.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# no suitable urban station for Hamilton
# No pair found for Hamilton
# finding the next urban station for Winnipeg
# CA00502I002 1996-03-01 1999-02-28 63.0 ['TMAX', 'PRCP', 'TMIN', 'SNOW', 'SNWD']
# finding the next urban station for Winnipeg
# CA005023226 2008-07-01 2013-10-31 63.0 ['TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Winnipeg
# CA005023222 1938-01-01 2008-07-31 63.0 ['TMAX', 'PRCP', 'TMIN', 'SNOW', 'SNWD']
# finding the next urban station for Winnipeg
# CA005023224 1994-07-01 1997-05-31 63.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Winnipeg
# CA005023261 1957-01-01 2013-10-31 63.0 ['TAVG', 'TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Winnipeg
# CA00502S001 1996-10-01 2016-08-31 62.0 ['TAVG', 'TMIN', 'TMAX', 'WDFG', 'SNOW', 'WSFG', 'SNWD', 'PRCP']
# finding the next urban station for Winnipeg
# CA0050232KJ 1985-10-01 1988-03-31 62.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Winnipeg
# CA0050225DP 1976-03-01 1985-08-31 54.0 ['TMAX', 'PRCP', 'TMIN', 'SNOW', 'SNWD']
# finding the next urban station for Winnipeg
# CA005022043 1961-06-01 1992-01-31 44.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Winnipeg
# CA005022788 1959-12-01 1991-09-30 30.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# no suitable urban station for Winnipeg
# No pair found for Winnipeg
# finding the next urban station for Calgary
# CA003031093 1881-10-01 2012-07-31 63.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Calgary
# CA003031092 2012-07-01 2016-08-31 63.0 ['TAVG', 'TMIN', 'TMAX', 'WDFG', 'SNOW', 'WSFG', 'SNWD', 'PRCP']
# finding the next urban station for Calgary
# CA003031094 1999-05-01 2016-07-31 63.0 ['TAVG', 'TMIN', 'TMAX', 'WDFG', 'SNOW', 'WSFG', 'SNWD', 'PRCP']
# finding the next urban station for Calgary
# CA003031875 1993-06-01 2016-08-31 63.0 ['TAVG', 'TMIN', 'TMAX', 'WDFG', 'SNOW', 'WSFG', 'SNWD', 'PRCP']
# finding the next urban station for Calgary
# CA00303M9JM 1990-05-01 2016-08-31 63.0 ['TAVG', 'TMIN', 'TMAX', 'SNOW', 'SNWD', 'PRCP']
# finding the next urban station for Calgary
# CA003031676 1991-01-01 2004-03-31 57.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Calgary
# CA00303F0PP 1984-12-01 2012-08-31 47.0 ['TMAX', 'PRCP', 'TMIN', 'SNOW', 'SNWD']
# finding the next urban station for Calgary
# CA003036077 2012-08-01 2012-09-30 47.0 ['TMAX', 'PRCP', 'SNOW', 'SNWD']
# finding the next urban station for Calgary
# CA003031524 1974-07-01 1985-05-31 43.0 ['TMIN', 'TMAX', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Calgary
# CA003036084 1990-08-01 1992-05-31 38.0 ['TMIN', 'TMAX', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# no suitable urban station for Calgary
# No pair found for Calgary
# Found a pair for Ottawa
# finding the next urban station for Québec
# CA007011309 1971-09-01 1991-01-31 63.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Québec
# CA007010565 1999-09-01 2013-11-30 63.0 ['TMIN', 'TMAX', 'WDFG', 'SNOW', 'WSFG', 'PRCP']
# finding the next urban station for Québec
# CA007012232 1971-10-01 1993-03-31 63.0 ['TMIN', 'TMAX', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Québec
# CA007010566 1982-07-01 1985-05-31 63.0 ['TMIN', 'TMAX', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Québec
# CA00701Q004 1997-11-01 2016-08-31 63.0 ['TAVG', 'TMIN', 'TMAX', 'WDFG', 'SNOW', 'WSFG', 'SNWD', 'PRCP']
# finding the next urban station for Québec
# CA007017BFN 1972-06-01 1996-12-31 63.0 ['TMAX', 'PRCP', 'TMIN', 'SNOW', 'SNWD']
# finding the next urban station for Québec
# CA007018762 1985-08-01 1988-01-31 62.0 ['TMAX', 'PRCP', 'TMIN', 'SNOW', 'SNWD']
# finding the next urban station for Québec
# CA00701LF83 1988-09-01 1991-06-30 62.0 ['TMAX', 'PRCP', 'TMIN', 'SNOW', 'SNWD']
# finding the next urban station for Québec
# CA007027391 1968-09-01 1985-01-31 62.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Québec
# CA00701S001 1992-12-01 2016-08-31 62.0 ['TAVG', 'TMIN', 'TMAX', 'WDFG', 'SNOW', 'WSFG', 'SNWD', 'PRCP']
# finding the next urban station for Québec
# CA007016294 1943-03-01 1995-09-30 62.0 ['TMAX', 'PRCP', 'TMIN', 'SNOW', 'SNWD']
# finding the next urban station for Québec
# CA007024254 1978-12-01 2016-04-30 49.0 ['TAVG', 'TMIN', 'TMAX', 'SNOW', 'SNWD', 'PRCP']
# finding the next rural station for Québec
# increasing search radius
# Found a pair for Québec
# finding the next urban station for Edmonton
# CA003012209 1996-03-01 2016-08-31 63.0 ['TAVG', 'TMIN', 'TMAX', 'WDFG', 'SNOW', 'WSFG', 'SNWD', 'PRCP']
# finding the next urban station for Edmonton
# CA003012208 1937-10-01 2015-03-31 63.0 ['TAVG', 'TMIN', 'TMAX', 'SNOW', 'SNWD', 'PRCP']
# finding the next rural station for Edmonton
# increasing search radius
# Found a pair for Edmonton
# finding the next urban station for Montréal
# CA007025280 1871-07-01 1993-03-31 63.0 ['TMAX', 'PRCP', 'TMIN', 'SNOW', 'SNWD']
# finding the next urban station for Montréal
# CA007025267 1971-01-01 1992-06-30 63.0 ['TMAX', 'PRCP', 'TMIN', 'SNOW', 'SNWD']
# finding the next urban station for Montréal
# CA007025260 1956-03-01 1985-05-31 63.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Montréal
# CA007025257 1948-05-01 1989-10-31 63.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Montréal
# CA00702S006 2002-12-01 2016-08-31 63.0 ['TAVG', 'TMIN', 'TMAX', 'WDFG', 'SNOW', 'WSFG', 'SNWD', 'PRCP']
# finding the next urban station for Montréal
# CA007025250 1941-09-01 2016-08-31 63.0 ['TAVG', 'TMIN', 'TMAX', 'SNOW', 'SNWD', 'PRCP']
# finding the next rural station for Montréal
# increasing search radius
# Found a pair for Montréal
# finding the next urban station for Vancouver
# CA001105210 2013-10-01 2013-10-31 63.0 ['TMAX', 'PRCP', 'TMIN', 'SNOW', 'SNWD']
# finding the next urban station for Vancouver
# CA001108446 1958-01-01 2016-08-31 62.0 ['TAVG', 'TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next rural station for Vancouver
# increasing search radius
# Found a pair for Vancouver
# finding the next urban station for Toronto
# CA006158350 1840-03-01 2003-06-30 63.0 ['TMIN', 'TMAX', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Toronto
# CA0061584J2 1981-08-01 1988-11-30 63.0 ['TMAX', 'TMIN', 'SNWD']
# finding the next urban station for Toronto
# CA006158751 2007-05-01 2015-07-31 63.0 ['TAVG', 'TMIN', 'TMAX', 'SNOW', 'SNWD', 'PRCP']
# finding the next urban station for Toronto
# CA00615S001 1994-11-01 2016-08-31 63.0 ['TAVG', 'TMIN', 'TMAX', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Toronto
# CA006158740 1965-05-01 1988-06-30 63.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Toronto
# CA006158520 1959-07-01 1994-12-31 63.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Toronto
# CA006152953 1974-07-01 1994-05-31 63.0 ['TMIN', 'TMAX', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Toronto
# CA006158763 1994-11-01 1995-07-31 63.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Toronto
# CA00615HMAK 1986-05-01 2015-05-31 63.0 ['TAVG', 'TMIN', 'TMAX', 'WDFG', 'SNOW', 'WSFG', 'SNWD', 'PRCP']
# finding the next urban station for Toronto
# CA006154950 1983-11-01 1990-01-31 63.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Toronto
# CA006157012 1959-06-01 2014-02-28 63.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Toronto
# CA006158665 1957-05-01 2006-03-31 60.0 ['TMIN', 'TMAX', 'SNOW', 'SNWD', 'PRCP', 'MDPR']
# finding the next urban station for Toronto
# CA006158667 2006-01-01 2014-07-31 60.0 ['TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next urban station for Toronto
# CA006158578 1994-12-01 1998-02-28 35.0 ['TMAX', 'PRCP', 'TMIN']
# no suitable urban station for Toronto
# No pair found for Toronto
# finding the next rural station for Bangui
# increasing search radius
# finding the next rural station for Bangui
# No pair found for Bangui
# finding the next rural station for Ndjamena
# No pair found for Ndjamena
# finding the next rural station for Concepcion
# increasing search radius
# Found a pair for Concepcion
# finding the next urban station for Santiago
# CIM00085574 1973-01-01 2016-08-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next rural station for Santiago
# increasing search radius
# finding the next rural station for Santiago
# No pair found for Santiago
# finding the next rural station for Yangquan
# increasing search radius
# finding the next rural station for Yangquan
# No pair found for Yangquan
# finding the next rural station for Shiyan
# No pair found for Shiyan
# No pair found for Shashi
# finding the next rural station for Zhucheng
# increasing search radius
# finding the next rural station for Zhucheng
# No pair found for Zhucheng
# finding the next rural station for Xinyi
# increasing search radius
# finding the next rural station for Xinyi
# No pair found for Xinyi
# finding the next rural station for Yangzhou
# No pair found for Yangzhou
# finding the next rural station for Beihai
# increasing search radius
# Found a pair for Beihai
# finding the next rural station for Hechi
# increasing search radius
# finding the next rural station for Hechi
# No pair found for Hechi
# finding the next rural station for Zhangzhou
# increasing search radius
# finding the next rural station for Zhangzhou
# No pair found for Zhangzhou
# finding the next rural station for Maanshan
# increasing search radius
# finding the next rural station for Maanshan
# No pair found for Maanshan
# finding the next rural station for Yangjiang
# No pair found for Yangjiang
# finding the next rural station for Qingyuan
# increasing search radius
# finding the next rural station for Qingyuan
# No pair found for Qingyuan
# finding the next rural station for Jiangmen
# increasing search radius
# finding the next rural station for Jiangmen
# No pair found for Jiangmen
# No pair found for Maoming
# No pair found for Jincheng
# No pair found for Changzhi
# finding the next urban station for Xiangtan
# CHM00057679 1951-01-01 2009-12-31 60.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# no suitable urban station for Xiangtan
# No pair found for Xiangtan
# finding the next rural station for Zigong
# increasing search radius
# finding the next rural station for Zigong
# No pair found for Zigong
# No pair found for Zhanyi
# finding the next urban station for Cangzhou
# CHM00054527 1954-01-01 2016-08-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next rural station for Cangzhou
# increasing search radius
# finding the next rural station for Cangzhou
# No pair found for Cangzhou
# No pair found for Baoding
# finding the next rural station for Xiangtai
# increasing search radius
# finding the next rural station for Xiangtai
# No pair found for Xiangtai
# finding the next urban station for Puyang
# CHM00053898 1951-01-01 2016-08-31 60.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# Found a pair for Puyang
# finding the next rural station for Rizhao
# increasing search radius
# finding the next rural station for Rizhao
# No pair found for Rizhao
# No pair found for Shangrao
# finding the next rural station for Taizhou
# increasing search radius
# finding the next rural station for Taizhou
# No pair found for Taizhou
# finding the next rural station for Shuyang
# No pair found for Shuyang
# finding the next rural station for Lianyungang
# No pair found for Lianyungang
# No pair found for Liuzhou
# finding the next rural station for Xingyi
# No pair found for Xingyi
# finding the next rural station for Anshun
# increasing search radius
# Found a pair for Anshun
# no suitable urban station for Zunyi
# No pair found for Zunyi
# No pair found for Wanzhou
# finding the next rural station for Huaibei
# increasing search radius
# finding the next rural station for Huaibei
# No pair found for Huaibei
# finding the next rural station for Wuhu
# increasing search radius
# finding the next rural station for Wuhu
# No pair found for Wuhu
# finding the next rural station for Luan
# increasing search radius
# finding the next rural station for Luan
# No pair found for Luan
# finding the next rural station for Bengbu
# increasing search radius
# finding the next rural station for Bengbu
# No pair found for Bengbu
# finding the next rural station for Foshan
# increasing search radius
# finding the next rural station for Foshan
# No pair found for Foshan
# No pair found for Shihezi
# finding the next rural station for Haikou
# No pair found for Haikou
# No pair found for Baoji
# No pair found for Linfen
# finding the next rural station for Yuci
# increasing search radius
# finding the next rural station for Yuci
# No pair found for Yuci
# finding the next rural station for Datong
# increasing search radius
# finding the next rural station for Datong
# No pair found for Datong
# finding the next rural station for Jianmen
# No pair found for Jianmen
# finding the next rural station for Yichang
# No pair found for Yichang
# finding the next rural station for Xiantao
# No pair found for Xiantao
# No pair found for Huangshi
# finding the next urban station for Zhuzhou
# CHM00057687 1987-01-01 2016-03-31 60.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# no suitable urban station for Zhuzhou
# No pair found for Zhuzhou
# finding the next rural station for Yongzhou
# No pair found for Yongzhou
# finding the next urban station for Yiyang
# CHM00057679 1951-01-01 2009-12-31 60.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Yiyang
# CHM00057662 1951-01-01 2016-07-31 59.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next rural station for Yiyang
# No pair found for Yiyang
# finding the next rural station for Changde
# increasing search radius
# finding the next rural station for Changde
# No pair found for Changde
# No pair found for Leshan
# finding the next rural station for Luzhou
# increasing search radius
# finding the next rural station for Luzhou
# No pair found for Luzhou
# finding the next rural station for Yibin
# No pair found for Yibin
# finding the next rural station for Qinhuangdao
# No pair found for Qinhuangdao
# finding the next rural station for Langfang
# increasing search radius
# finding the next rural station for Langfang
# No pair found for Langfang
# finding the next rural station for Zhangjiakou
# increasing search radius
# finding the next rural station for Zhangjiakou
# No pair found for Zhangjiakou
# finding the next rural station for Tangshan
# increasing search radius
# finding the next rural station for Tangshan
# No pair found for Tangshan
# finding the next rural station for Anyang
# increasing search radius
# finding the next rural station for Anyang
# No pair found for Anyang
# finding the next rural station for Jiaozuo
# increasing search radius
# finding the next rural station for Jiaozuo
# No pair found for Jiaozuo
# finding the next rural station for Kaifeng
# increasing search radius
# Found a pair for Kaifeng
# Found a pair for Shangqiu
# No pair found for Pingdingshan
# finding the next rural station for Xinyang
# No pair found for Xinyang
# finding the next rural station for Xinxiang
# No pair found for Xinxiang
# No pair found for Luoyang
# Found a pair for Liaoyang
# Found a pair for Dandong
# finding the next rural station for Yingkow
# increasing search radius
# finding the next rural station for Yingkow
# No pair found for Yingkow
# finding the next rural station for Jinzhou
# increasing search radius
# finding the next rural station for Jinzhou
# No pair found for Jinzhou
# finding the next rural station for Fuxin
# increasing search radius
# finding the next rural station for Fuxin
# No pair found for Fuxin
# Found a pair for Benxi
# Found a pair for Fushun
# finding the next rural station for Jining
# increasing search radius
# Found a pair for Jining
# finding the next rural station for Weifang
# increasing search radius
# finding the next rural station for Weifang
# No pair found for Weifang
# finding the next rural station for Taian
# increasing search radius
# finding the next rural station for Taian
# No pair found for Taian
# no suitable urban station for Heze
# No pair found for Heze
# finding the next rural station for Xinyu
# increasing search radius
# finding the next rural station for Xinyu
# No pair found for Xinyu
# finding the next rural station for Ganzhou
# increasing search radius
# finding the next rural station for Ganzhou
# No pair found for Ganzhou
# No pair found for Jiujiang
# No pair found for Changzhou
# finding the next rural station for Zhenjiang
# increasing search radius
# finding the next rural station for Zhenjiang
# No pair found for Zhenjiang
# finding the next urban station for Nantong
# CHM00058251 1953-01-01 2016-03-31 62.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next rural station for Nantong
# increasing search radius
# finding the next rural station for Nantong
# No pair found for Nantong
# finding the next urban station for Jiaxing
# CHM00058362 1991-01-01 2016-03-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Jiaxing
# CHM00058457 1951-01-01 2015-08-31 62.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next rural station for Jiaxing
# No pair found for Jiaxing
# finding the next rural station for Huzhou
# increasing search radius
# finding the next rural station for Huzhou
# No pair found for Huzhou
# finding the next rural station for Shaoxing
# increasing search radius
# finding the next rural station for Shaoxing
# No pair found for Shaoxing
# finding the next rural station for Jinhua
# increasing search radius
# finding the next rural station for Jinhua
# No pair found for Jinhua
# finding the next rural station for Siping
# increasing search radius
# finding the next rural station for Siping
# No pair found for Siping
# finding the next rural station for Hegang
# No pair found for Hegang
# finding the next rural station for Mudangiang
# No pair found for Mudangiang
# finding the next rural station for Xuanzhou
# No pair found for Xuanzhou
# finding the next urban station for Zhuhai
# CHM00045004 1992-08-01 2000-03-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Zhuhai
# CHM00059287 1951-01-01 2016-03-31 57.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next rural station for Zhuhai
# No pair found for Zhuhai
# finding the next urban station for Xianyang
# CHM00057131 2006-01-01 2016-03-31 61.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# no suitable urban station for Xianyang
# No pair found for Xianyang
# finding the next rural station for Xiangfan
# No pair found for Xiangfan
# finding the next rural station for Suining
# increasing search radius
# finding the next rural station for Suining
# No pair found for Suining
# No pair found for Lingyuan
# finding the next rural station for Yichun
# increasing search radius
# finding the next rural station for Yichun
# No pair found for Yichun
# finding the next rural station for Yancheng
# No pair found for Yancheng
# finding the next rural station for Fuyang
# No pair found for Fuyang
# finding the next rural station for Xiamen
# No pair found for Xiamen
# finding the next rural station for Nanchong
# increasing search radius
# finding the next rural station for Nanchong
# No pair found for Nanchong
# finding the next rural station for Neijiang
# increasing search radius
# finding the next rural station for Neijiang
# No pair found for Neijiang
# No pair found for Nanyang
# finding the next rural station for Jinxi
# increasing search radius
# finding the next rural station for Jinxi
# No pair found for Jinxi
# No pair found for Yantai
# finding the next rural station for Zaozhuang
# No pair found for Zaozhuang
# finding the next urban station for Suzhou
# CHM00058362 1991-01-01 2016-03-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# no suitable urban station for Suzhou
# No pair found for Suzhou
# finding the next rural station for Xuzhou
# increasing search radius
# finding the next rural station for Xuzhou
# No pair found for Xuzhou
# No pair found for Wuxi
# No pair found for Jilin
# finding the next urban station for Tianshui
# CHM00057014 2004-01-01 2016-08-31 59.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# no suitable urban station for Tianshui
# No pair found for Tianshui
# finding the next rural station for Yulin
# increasing search radius
# finding the next rural station for Yulin
# No pair found for Yulin
# finding the next rural station for Lupanshui
# increasing search radius
# finding the next rural station for Lupanshui
# No pair found for Lupanshui
# finding the next rural station for Quanzhou
# increasing search radius
# finding the next rural station for Quanzhou
# No pair found for Quanzhou
# finding the next rural station for Hefei
# increasing search radius
# finding the next rural station for Hefei
# No pair found for Hefei
# finding the next rural station for Suzhou
# increasing search radius
# finding the next rural station for Suzhou
# No pair found for Suzhou
# No pair found for Zhanjiang
# finding the next rural station for Shaoguan
# No pair found for Shaoguan
# No pair found for Ankang
# No pair found for Yueyang
# No pair found for Hengyang
# No pair found for Mianyang
# finding the next rural station for Baoshan
# No pair found for Baoshan
# finding the next rural station for Shijianzhuang
# No pair found for Shijianzhuang
# finding the next rural station for Handan
# increasing search radius
# finding the next rural station for Handan
# No pair found for Handan
# Found a pair for Anshan
# finding the next rural station for Dalian
# No pair found for Dalian
# finding the next rural station for Qingdao
# increasing search radius
# finding the next rural station for Qingdao
# No pair found for Qingdao
# finding the next rural station for Linyi
# increasing search radius
# finding the next rural station for Linyi
# No pair found for Linyi
# No pair found for Huaiyin
# finding the next urban station for Wenzhou
# CHM00058752 2001-01-01 2016-03-31 60.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# no suitable urban station for Wenzhou
# No pair found for Wenzhou
# finding the next rural station for Ningbo
# increasing search radius
# Found a pair for Ningbo
# finding the next rural station for Tongliao
# increasing search radius
# Found a pair for Tongliao
# finding the next rural station for Hohhot
# No pair found for Hohhot
# finding the next rural station for Chifeng
# No pair found for Chifeng
# No pair found for Jiamusi
# finding the next rural station for Daqing
# increasing search radius
# finding the next rural station for Daqing
# No pair found for Daqing
# Found a pair for Jixi
# finding the next rural station for Xining
# increasing search radius
# Found a pair for Xining
# finding the next rural station for Guilin
# No pair found for Guilin
# finding the next rural station for Huainan
# increasing search radius
# finding the next rural station for Huainan
# No pair found for Huainan
# finding the next rural station for Shantou
# increasing search radius
# finding the next rural station for Shantou
# No pair found for Shantou
# finding the next rural station for Yinchuan
# increasing search radius
# Found a pair for Yinchuan
# no suitable urban station for Pingxiang
# No pair found for Pingxiang
# finding the next rural station for Qiqihar
# No pair found for Qiqihar
# finding the next urban station for Shenzhen
# CHM00045005 1946-09-01 1992-06-30 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Shenzhen
# CHM00059287 1951-01-01 2016-03-31 57.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next rural station for Shenzhen
# increasing search radius
# finding the next rural station for Shenzhen
# No pair found for Shenzhen
# finding the next rural station for Zibo
# increasing search radius
# finding the next rural station for Zibo
# No pair found for Zibo
# Found a pair for Lanzhou
# Found a pair for Nanning
# finding the next rural station for Guiyang
# increasing search radius
# finding the next rural station for Guiyang
# No pair found for Guiyang
# finding the next urban station for Chongqing
# CHM00057516 1951-01-01 2016-03-31 59.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next rural station for Chongqing
# increasing search radius
# finding the next rural station for Chongqing
# No pair found for Chongqing
# finding the next rural station for Fuzhou
# increasing search radius
# Found a pair for Fuzhou
# finding the next rural station for Guangzhou
# increasing search radius
# finding the next rural station for Guangzhou
# No pair found for Guangzhou
# finding the next urban station for Dongguan
# CHM00045005 1946-09-01 1992-06-30 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Dongguan
# CHM00059287 1951-01-01 2016-03-31 57.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next rural station for Dongguan
# increasing search radius
# finding the next rural station for Dongguan
# No pair found for Dongguan
# finding the next urban station for Xian
# CHM00057131 2006-01-01 2016-03-31 61.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# no suitable urban station for Xian
# No pair found for Xian
# finding the next rural station for Taiyuan
# increasing search radius
# finding the next rural station for Taiyuan
# No pair found for Taiyuan
# finding the next rural station for Wuhan
# No pair found for Wuhan
# finding the next urban station for Changsha
# CHM00057679 1951-01-01 2009-12-31 60.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# no suitable urban station for Changsha
# No pair found for Changsha
# finding the next rural station for Kunming
# increasing search radius
# Found a pair for Kunming
# finding the next rural station for Zhengzhou
# increasing search radius
# finding the next rural station for Zhengzhou
# No pair found for Zhengzhou
# finding the next rural station for Shenyeng
# increasing search radius
# Found a pair for Shenyeng
# finding the next rural station for Jinan
# increasing search radius
# finding the next rural station for Jinan
# No pair found for Jinan
# finding the next rural station for Tianjin
# increasing search radius
# finding the next rural station for Tianjin
# No pair found for Tianjin
# finding the next rural station for Nanchang
# increasing search radius
# finding the next rural station for Nanchang
# No pair found for Nanchang
# finding the next rural station for Nanjing
# No pair found for Nanjing
# finding the next rural station for Hangzhou
# No pair found for Hangzhou
# finding the next rural station for Changchun
# increasing search radius
# finding the next rural station for Changchun
# No pair found for Changchun
# No pair found for Baotou
# finding the next rural station for Harbin
# increasing search radius
# Found a pair for Harbin
# finding the next rural station for Urumqi
# No pair found for Urumqi
# finding the next urban station for Chengdu
# CHM00056187 2004-01-01 2016-03-31 43.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# no suitable urban station for Chengdu
# No pair found for Chengdu
# finding the next rural station for Beijing
# increasing search radius
# finding the next rural station for Beijing
# No pair found for Beijing
# finding the next urban station for Shanghai
# CHM00058362 1991-01-01 2016-03-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# no suitable urban station for Shanghai
# No pair found for Shanghai
# finding the next rural station for Soledad
# No pair found for Soledad
# Found a pair for Pereira
# finding the next rural station for Bucaramanga
# increasing search radius
# Found a pair for Bucaramanga
# Found a pair for Cucuta
# finding the next rural station for Barranquilla
# No pair found for Barranquilla
# finding the next rural station for Cartagena
# increasing search radius
# finding the next rural station for Cartagena
# No pair found for Cartagena
# finding the next urban station for Medellin
# COM00080112 1985-12-01 2016-07-31 59.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# no suitable urban station for Medellin
# No pair found for Medellin
# finding the next rural station for Cali
# increasing search radius
# finding the next rural station for Cali
# No pair found for Cali
# finding the next rural station for Bogota
# increasing search radius
# Found a pair for Bogota
# finding the next rural station for Pointe-Noire
# increasing search radius
# Found a pair for Pointe-Noire
# Found a pair for Brazzaville
# No pair found for Kisangani
# no suitable urban station for Kananga
# No pair found for Kananga
# finding the next rural station for Mbuji-Mayi
# increasing search radius
# finding the next rural station for Mbuji-Mayi
# No pair found for Mbuji-Mayi
# no suitable urban station for Lubumbashi
# No pair found for Lubumbashi
# Found a pair for Kinshasa
# Found a pair for San Jose
# Found a pair for Zagreb
# finding the next rural station for Santiago de Cuba
# No pair found for Santiago de Cuba
# finding the next rural station for Havana
# No pair found for Havana
# finding the next urban station for Prague
# EZM00011518 1940-01-01 2016-07-31 59.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# Found a pair for Prague
# finding the next urban station for København
# SWE00137644 1961-01-01 1995-07-31 63.0 ['TMAX', 'PRCP', 'TMIN']
# finding the next urban station for København
# SWE00137534 1990-01-01 2016-03-31 63.0 ['TMAX', 'PRCP', 'TMIN']
# finding the next urban station for København
# SWE00137536 1955-01-01 1989-12-31 63.0 ['TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next urban station for København
# SWE00137636 1995-08-01 2016-03-31 62.0 ['TMAX', 'PRCP', 'TMIN']
# finding the next urban station for København
# SWE00135202 1986-07-01 1992-12-31 61.0 ['TMAX', 'TMIN']
# finding the next urban station for København
# SWE00137718 1998-03-01 2016-02-29 37.0 ['TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next urban station for København
# SWE00137732 1951-01-01 2016-03-31 33.0 ['TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next rural station for København
# finding the next rural station for København
# finding the next rural station for København
# finding the next rural station for København
# finding the next rural station for København
# finding the next rural station for København
# finding the next rural station for København
# increasing search radius
# finding the next rural station for København
# finding the next rural station for København
# finding the next rural station for København
# finding the next rural station for København
# finding the next rural station for København
# finding the next rural station for København
# finding the next rural station for København
# finding the next rural station for København
# finding the next rural station for København
# finding the next rural station for København
# finding the next rural station for København
# finding the next rural station for København
# finding the next rural station for København
# No pair found for København
# No pair found for Djibouti
# no suitable urban station for Santiago
# No pair found for Santiago
# finding the next rural station for Santo Domingo
# increasing search radius
# finding the next rural station for Santo Domingo
# finding the next rural station for Santo Domingo
# No pair found for Santo Domingo
# no suitable urban station for Quito
# No pair found for Quito
# No pair found for Guayaquil
# No pair found for El Mansura
# No pair found for El Giza
# No pair found for Bur Said
# no suitable urban station for Luxor
# No pair found for Luxor
# finding the next rural station for Alexandria
# No pair found for Alexandria
# No pair found for Cairo
# finding the next rural station for San Salvador
# No pair found for San Salvador
# no suitable urban station for Asmara
# No pair found for Asmara
# Found a pair for Addis Ababa
# finding the next urban station for Helsinki
# FIE00142101 1959-05-01 2016-08-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# Found a pair for Helsinki
# finding the next rural station for Nice
# increasing search radius
# finding the next rural station for Nice
# No pair found for Nice
# Found a pair for Toulouse
# Found a pair for Lille
# finding the next rural station for Bordeaux
# increasing search radius
# Found a pair for Bordeaux
# finding the next urban station for Marseille
# FR000007650 1921-01-01 2016-08-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next rural station for Marseille
# increasing search radius
# finding the next rural station for Marseille
# No pair found for Marseille
# finding the next rural station for Lyon
# increasing search radius
# Found a pair for Lyon
# finding the next rural station for Paris
# increasing search radius
# Found a pair for Paris
# Found a pair for Libreville
# Found a pair for Tbilisi
# Found a pair for Dortmund
# Found a pair for Duisburg
# Found a pair for Wuppertal
# Found a pair for Essen
# Found a pair for Düsseldorf
# Found a pair for Mannheim
# finding the next urban station for Hannover
# GMM00010348 1936-07-01 2003-08-31 53.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next urban station for Hannover
# GME00102244 1935-01-01 2016-05-31 51.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# Found a pair for Hannover
# Found a pair for Leipzig
# Found a pair for Stuttgart
# Found a pair for Bremen
# Found a pair for Nürnberg
# Found a pair for Cologne
# Found a pair for Dresden
# Found a pair for Frankfurt
# Found a pair for Hamburg
# Found a pair for Munich
# Found a pair for Berlin
# Found a pair for Kumasi
# Found a pair for Accra
# finding the next rural station for Thessaloniki
# increasing search radius
# Found a pair for Thessaloniki
# Found a pair for Athens
# No pair found for Guatemala
# finding the next rural station for Conakry
# increasing search radius
# finding the next rural station for Conakry
# No pair found for Conakry
# No pair found for Port-au-Prince
# finding the next rural station for San Pedro Sula
# increasing search radius
# finding the next rural station for San Pedro Sula
# No pair found for San Pedro Sula
# finding the next rural station for Tegucigalpa
# No pair found for Tegucigalpa
# finding the next urban station for Hong Kong
# CHM00045004 1992-08-01 2000-03-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Hong Kong
# MCM00045011 1952-01-01 2016-08-31 54.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next rural station for Hong Kong
# increasing search radius
# finding the next rural station for Hong Kong
# No pair found for Hong Kong
# Found a pair for Budapest
# finding the next rural station for Kalyan
# increasing search radius
# Found a pair for Kalyan
# no suitable urban station for Ajmer
# No pair found for Ajmer
# finding the next rural station for Raurkela
# increasing search radius
# finding the next rural station for Raurkela
# No pair found for Raurkela
# finding the next rural station for Sangli
# increasing search radius
# Found a pair for Sangli
# no suitable urban station for Malegaon
# No pair found for Malegaon
# finding the next urban station for Jhansi
# IN011150300 1957-07-01 2016-04-30 37.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next rural station for Jhansi
# increasing search radius
# finding the next rural station for Jhansi
# No pair found for Jhansi
# finding the next rural station for Bareilly
# increasing search radius
# Found a pair for Bareilly
# Found a pair for Dehra Dun
# finding the next urban station for Haora
# IN024141500 1944-01-01 2016-07-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next rural station for Haora
# increasing search radius
# Found a pair for Haora
# no suitable urban station for Siliguri
# No pair found for Siliguri
# finding the next rural station for Tiruppur
# increasing search radius
# Found a pair for Tiruppur
# Found a pair for Bhavnagar
# finding the next rural station for Warangal
# increasing search radius
# finding the next rural station for Warangal
# No pair found for Warangal
# finding the next rural station for Bhiwandi
# increasing search radius
# Found a pair for Bhiwandi
# finding the next rural station for Amravati
# increasing search radius
# finding the next rural station for Amravati
# No pair found for Amravati
# finding the next rural station for Gorakhpur
# increasing search radius
# ...
# finding the next rural station for Rostov
# finding the next rural station for Rostov
# increasing search radius
# finding the next rural station for Rostov
# No pair found for Rostov
# Found a pair for Krasnodar
# finding the next urban station for Ryazan
# RSM00027730 1925-01-01 2013-12-31 30.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# no suitable urban station for Ryazan
# No pair found for Ryazan
# Found a pair for Voronezh
# no suitable urban station for Chelyabinsk
# No pair found for Chelyabinsk
# finding the next rural station for Orenburg
# increasing search radius
# finding the next rural station for Orenburg
# No pair found for Orenburg
# no suitable urban station for Saratov
# No pair found for Saratov
# finding the next urban station for Ulyanovsk
# RSM00027697 1974-10-01 2016-04-30 38.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next rural station for Ulyanovsk
# increasing search radius
# finding the next rural station for Ulyanovsk
# No pair found for Ulyanovsk
# Found a pair for Omsk
# no suitable urban station for Novokuznetsk
# No pair found for Novokuznetsk
# Found a pair for Khabarovsk
# finding the next rural station for Nizhny Novgorod
# increasing search radius
# Found a pair for Nizhny Novgorod
# Found a pair for Volgograd
# Found a pair for Ufa
# Found a pair for Yekaterinburg
# finding the next urban station for Samara
# RSM00027995 1904-01-01 2016-05-31 30.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next rural station for Samara
# increasing search radius
# finding the next rural station for Samara
# finding the next rural station for Samara
# finding the next rural station for Samara
# finding the next rural station for Samara
# No pair found for Samara
# finding the next rural station for Kazan
# increasing search radius
# Found a pair for Kazan
# finding the next rural station for Barnaul
# increasing search radius
# finding the next rural station for Barnaul
# finding the next rural station for Barnaul
# finding the next rural station for Barnaul
# No pair found for Barnaul
# finding the next urban station for Novosibirsk
# RSM00029638 1958-01-01 2013-12-31 48.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Novosibirsk
# RSM00029626 1948-02-01 1990-12-31 37.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next urban station for Novosibirsk
# RSM00029631 1955-07-01 2016-08-31 26.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next rural station for Novosibirsk
# increasing search radius
# finding the next rural station for Novosibirsk
# No pair found for Novosibirsk
# Found a pair for Irkutsk
# Found a pair for Krasnoyarsk
# finding the next rural station for Vladivostok
# increasing search radius
# Found a pair for Vladivostok
# Found a pair for Perm
# Found a pair for St. Petersburg
# finding the next rural station for Moscow
# increasing search radius
# finding the next rural station for Moscow
# No pair found for Moscow
# finding the next rural station for Kigali
# No pair found for Kigali
# finding the next rural station for At Taif
# increasing search radius
# finding the next rural station for At Taif
# No pair found for At Taif
# No pair found for Al Hillah
# finding the next rural station for Ad Damman
# increasing search radius
# finding the next rural station for Ad Damman
# No pair found for Ad Damman
# finding the next rural station for Al Hufuf
# increasing search radius
# finding the next rural station for Al Hufuf
# No pair found for Al Hufuf
# finding the next rural station for Medina
# increasing search radius
# finding the next rural station for Medina
# No pair found for Medina
# finding the next rural station for Tabuk
# No pair found for Tabuk
# finding the next rural station for Jeddah
# increasing search radius
# finding the next rural station for Jeddah
# No pair found for Jeddah
# finding the next rural station for Makkah
# No pair found for Makkah
# finding the next urban station for Riyadh
# SAM00040437 1984-01-01 2016-08-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next rural station for Riyadh
# No pair found for Riyadh
# finding the next rural station for Dakar
# increasing search radius
# finding the next rural station for Dakar
# No pair found for Dakar
# finding the next rural station for Belgrade
# increasing search radius
# Found a pair for Belgrade
# Found a pair for Singapore
# No pair found for Mogadishu
# finding the next rural station for Benoni
# increasing search radius
# finding the next rural station for Benoni
# No pair found for Benoni
# finding the next rural station for Vereeniging
# No pair found for Vereeniging
# Found a pair for Pietermaritzburg
# finding the next urban station for Pretoria
# SFM00068368 1974-11-01 2016-08-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next rural station for Pretoria
# increasing search radius
# finding the next rural station for Pretoria
# No pair found for Pretoria
# Found a pair for Port Elizabeth
# Found a pair for Durban
# finding the next rural station for Johannesburg
# increasing search radius
# finding the next rural station for Johannesburg
# No pair found for Johannesburg
# Found a pair for Cape Town
# finding the next rural station for Cheongju
# increasing search radius
# finding the next rural station for Cheongju
# No pair found for Cheongju
# finding the next rural station for Ansan
# increasing search radius
# Found a pair for Ansan
# finding the next rural station for Changwon
# increasing search radius
# Found a pair for Changwon
# finding the next rural station for Jeonju
# increasing search radius
# finding the next rural station for Jeonju
# No pair found for Jeonju
# finding the next rural station for Puch'on
# increasing search radius
# Found a pair for Puch'on
# finding the next rural station for Songnam
# increasing search radius
# finding the next rural station for Songnam
# No pair found for Songnam
# finding the next rural station for Goyang
# increasing search radius
# Found a pair for Goyang
# finding the next rural station for Suwon
# increasing search radius
# finding the next rural station for Suwon
# No pair found for Suwon
# finding the next rural station for Ulsan
# increasing search radius
# Found a pair for Ulsan
# finding the next rural station for Daegu
# increasing search radius
# finding the next rural station for Daegu
# No pair found for Daegu
# finding the next rural station for Incheon
# increasing search radius
# Found a pair for Incheon
# finding the next rural station for Daejeon
# increasing search radius
# finding the next rural station for Daejeon
# No pair found for Daejeon
# finding the next rural station for Gwangju
# increasing search radius
# finding the next rural station for Gwangju
# No pair found for Gwangju
# Found a pair for Busan
# finding the next rural station for Seoul
# increasing search radius
# Found a pair for Seoul
# finding the next rural station for Malaga
# increasing search radius
# Found a pair for Malaga
# Found a pair for Zaragoza
# Found a pair for Bilbao
# finding the next rural station for Seville
# increasing search radius
# Found a pair for Seville
# Found a pair for Valencia
# finding the next rural station for Barcelona
# increasing search radius
# finding the next rural station for Barcelona
# No pair found for Barcelona
# Found a pair for Madrid
# finding the next rural station for Omdurman
# No pair found for Omdurman
# finding the next rural station for Khartoum
# No pair found for Khartoum
# Found a pair for Göteborg
# finding the next urban station for Stockholm
# SWM00002485 1961-01-01 2016-03-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# Found a pair for Stockholm
# Found a pair for Basel
# Found a pair for Zürich
# finding the next rural station for Geneva
# increasing search radius
# Found a pair for Geneva
# finding the next rural station for Hims
# increasing search radius
# Found a pair for Hims
# finding the next rural station for Aleppo
# increasing search radius
# finding the next rural station for Aleppo
# No pair found for Aleppo
# Found a pair for Damascus
# No pair found for Zhongli
# No pair found for Hsinchu
# No pair found for New Taipei
# No pair found for Tainan
# No pair found for Taichung
# No pair found for Kaohsiung
# No pair found for Taipei
# Found a pair for Dushanbe
# Found a pair for Dar es Salaam
# finding the next rural station for Bangkok
# increasing search radius
# finding the next rural station for Bangkok
# No pair found for Bangkok
# Found a pair for Lome
# finding the next rural station for Tunis
# increasing search radius
# Found a pair for Tunis
# finding the next rural station for Icel
# increasing search radius
# finding the next rural station for Icel
# No pair found for Icel
# finding the next rural station for Tarsus
# increasing search radius
# finding the next rural station for Tarsus
# No pair found for Tarsus
# finding the next urban station for Diyarbakir
# TUM00017280 1963-01-01 2016-07-31 47.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next rural station for Diyarbakir
# increasing search radius
# finding the next rural station for Diyarbakir
# No pair found for Diyarbakir
# finding the next rural station for Antalya
# No pair found for Antalya
# no suitable urban station for Kayseri
# No pair found for Kayseri
# finding the next urban station for Gaziantep
# TUM00017260 1973-01-01 2016-07-31 31.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next rural station for Gaziantep
# increasing search radius
# finding the next rural station for Gaziantep
# No pair found for Gaziantep
# Found a pair for Izmir
# finding the next urban station for Bursa
# TUM00017116 1973-01-01 2016-07-31 62.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next rural station for Bursa
# increasing search radius
# finding the next rural station for Bursa
# No pair found for Bursa
# finding the next rural station for Samsun
# increasing search radius
# finding the next rural station for Samsun
# No pair found for Samsun
# finding the next rural station for Konya
# No pair found for Konya
# finding the next rural station for Adana
# increasing search radius
# finding the next rural station for Adana
# No pair found for Adana
# no suitable urban station for Ankara
# No pair found for Ankara
# finding the next urban station for Istanbul
# TUM00017116 1973-01-01 2016-07-31 62.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next rural station for Istanbul
# increasing search radius
# finding the next rural station for Istanbul
# No pair found for Istanbul
# finding the next rural station for Ashgabat
# increasing search radius
# Found a pair for Ashgabat
# No pair found for Kampala
# Found a pair for Kryvyy Rih
# finding the next rural station for Zaporizhzhya
# finding the next rural station for Zaporizhzhya
# finding the next rural station for Zaporizhzhya
# finding the next rural station for Zaporizhzhya
# finding the next rural station for Zaporizhzhya
# finding the next rural station for Zaporizhzhya
# finding the next rural station for Zaporizhzhya
# increasing search radius
# finding the next rural station for Zaporizhzhya
# finding the next rural station for Zaporizhzhya
# finding the next rural station for Zaporizhzhya
# finding the next rural station for Zaporizhzhya
# finding the next rural station for Zaporizhzhya
# finding the next rural station for Zaporizhzhya
# finding the next rural station for Zaporizhzhya
# No pair found for Zaporizhzhya
# Found a pair for Lvov
# Found a pair for Odessa
# no suitable urban station for Dnipropetrovsk
# No pair found for Dnipropetrovsk
# finding the next urban station for Donetsk
# UPM00034712 1937-01-01 2016-08-31 53.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# Found a pair for Donetsk
# finding the next urban station for Kharkiv
# UPM00034300 1936-01-01 2016-08-31 57.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# Found a pair for Kharkiv
# Found a pair for Kiev
# finding the next rural station for Sharjah
# increasing search radius
# finding the next rural station for Sharjah
# No pair found for Sharjah
# finding the next rural station for Abu Dhabi
# increasing search radius
# finding the next rural station for Abu Dhabi
# No pair found for Abu Dhabi
# finding the next rural station for Dubai
# increasing search radius
# finding the next rural station for Dubai
# No pair found for Dubai
# finding the next urban station for Sheffield
# UKM00003257 1973-01-01 2016-07-31 28.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next rural station for Sheffield
# increasing search radius
# finding the next rural station for Sheffield
# No pair found for Sheffield
# no suitable urban station for Nottingham
# No pair found for Nottingham
# finding the next rural station for Newcastle
# No pair found for Newcastle
# no suitable urban station for Liverpool
# No pair found for Liverpool
# No pair found for Cardiff
# finding the next urban station for Leeds
# UKM00003257 1973-01-01 2016-07-31 28.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# finding the next rural station for Leeds
# increasing search radius
# finding the next rural station for Leeds
# No pair found for Leeds
# no suitable urban station for Manchester
# No pair found for Manchester
# finding the next urban station for Birmingham
# UK000056225 1853-01-01 2001-04-30 62.0 ['TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Birmingham
# UKM00003334 1973-01-01 2008-01-31 57.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN', 'SNWD']
# no suitable urban station for Birmingham
# No pair found for Birmingham
# No pair found for Glasgow
# finding the next rural station for London
# increasing search radius
# Found a pair for London
# finding the next rural station for Montevideo
# increasing search radius
# Found a pair for Montevideo
# Found a pair for Namangan
# Found a pair for Samarqand
# Found a pair for Tashkent
# finding the next rural station for Puerto la Cruz
# increasing search radius
# finding the next rural station for Puerto la Cruz
# No pair found for Puerto la Cruz
# finding the next rural station for Barquisimeto
# increasing search radius
# Found a pair for Barquisimeto
# finding the next urban station for Maracay
# VEM00080416 1973-05-01 2007-07-31 63.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Maracay
# VE000080413 1959-01-01 2016-07-31 62.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# Found a pair for Maracay
# finding the next urban station for Valencia
# VE000080413 1959-01-01 2016-07-31 62.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# Found a pair for Valencia
# Found a pair for Ciudad Guayana
# finding the next rural station for Maracaibo
# increasing search radius
# finding the next rural station for Maracaibo
# No pair found for Maracaibo
# finding the next urban station for Caracas
# VEM00080415 1973-01-01 2016-04-30 62.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next rural station for Caracas
# increasing search radius
# Found a pair for Caracas
# finding the next rural station for Vinh
# increasing search radius
# finding the next rural station for Vinh
# No pair found for Vinh
# finding the next rural station for Qui Nhon
# No pair found for Qui Nhon
# finding the next rural station for Hue
# increasing search radius
# finding the next rural station for Hue
# No pair found for Hue
# no suitable urban station for Bien Hoa
# No pair found for Bien Hoa
# No pair found for Can Tho
# finding the next urban station for Haiphong
# VMM00048820 1958-12-01 2012-09-30 53.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Haiphong
# VMM00048826 1974-09-01 2016-08-31 43.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next rural station for Haiphong
# increasing search radius
# finding the next rural station for Haiphong
# No pair found for Haiphong
# finding the next rural station for Da Nang
# No pair found for Da Nang
# finding the next urban station for Hanoi
# VMM00048820 1958-12-01 2012-09-30 53.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next urban station for Hanoi
# VMM00048826 1974-09-01 2016-08-31 43.0 ['TAVG', 'TMAX', 'PRCP', 'TMIN']
# finding the next rural station for Hanoi
# increasing search radius
# finding the next rural station for Hanoi
# No pair found for Hanoi
# no suitable urban station for Ho Chi Minh City
# No pair found for Ho Chi Minh City
# No pair found for Al Hudaydah
# No pair found for Taizz
# No pair found for Aden
# No pair found for Sanaa
# no suitable urban station for Lusaka
# No pair found for Lusaka
# finding the next rural station for Harare
# finding the next rural station for Harare
# increasing search radius
# finding the next rural station for Harare
# finding the next rural station for Harare
# No pair found for Harare
# no suitable urban station for Bulawayo
# No pair found for Bulawayo

# %%
i
# Out:
# 796

# %%
atlas.shape
# Out:
# (797, 9)

# %%
outFile
# Out:
# 'worldghcnpairs_stationlengths.csv'

# %%
results = pd.read_csv(outFile)

# %%
good_results = results[~np.isnan(results['Urban Lat'])]

# %%
results.shape
# Out:
# (1956, 10)

# %%
good_results.shape
# Out:
# (706, 10)

# %%
good_results[good_results['Urban station'].str.contains('US')]
# Out:
#       Unnamed: 0              City Urban station  Urban Lat  Urban Lon  \
# 886          886         Arlington   USC00410337     32.757    -97.073
# 890          890        Long Beach   USW00023129     33.811   -118.146
# 917          917              Mesa   USC00028499     33.425   -111.921
# 918          918         Arlington   USC00410337     32.757    -97.073
# 919          919            Irvine   USC00047888     33.744   -117.866
# 920          920         New Haven   USC00065077     41.407    -72.903
# 921          921   Fort Lauderdale   USC00083168     26.140    -80.106
# 922          922        Long Beach   USW00023129     33.811   -118.146
# 923          923          Hartford   USW00014752     41.736    -72.650
# 924          924        Providence   USW00014765     41.721    -71.432
# 925          925        Birmingham   USW00013876     33.565    -86.745
# 926          926    St. Petersburg   USW00012842     27.961    -82.540
# 927          927    Virginia Beach   USW00013769     36.816    -76.033
# 928          928           Oakland   USW00023230     37.721   -122.220
# 929          929   West Palm Beach   USW00012844     26.684    -80.099
# 930          930        Louisville   USW00093821     38.181    -85.739
# 931          931         Charlotte   USW00013881     35.223    -80.955
# 932          932          Columbus   USC00331783     39.904    -82.920
# 933          933    San Bernardino   USC00047470     33.951   -117.388
# 934          934        Bridgeport   USC00061762     41.400    -73.416
# 935          935          St. Paul   USW00014927     44.931    -93.055
# 936          936            Tucson   USW00023160     32.131   -110.955
# 937          937            Fresno   USW00093193     36.780   -119.719
# 938          938       Albuquerque   USW00023050     35.041   -106.615
# 939          939       Kansas City   USW00013988     39.120    -94.596
# 940          940             Tulsa   USW00013968     36.199    -95.887
# 941          941         Ft. Worth   USW00093904     32.816    -97.350
# 942          942            Austin   USW00013958     30.320    -97.760
# 943          943           El Paso   USW00023044     31.811   -106.375
# 944          944           Orlando   USW00012841     28.545    -81.333
# ...          ...               ...           ...        ...        ...
# 959          959        Cincinnati   USW00093812     39.103    -84.418
# 960          960         Nashville   USW00013897     36.118    -86.689
# 961          961           Memphis   USW00013893     35.056    -89.986
# 962          962           Norfolk   USW00013750     36.950    -76.283
# 963          963         Milwaukee   USW00014839     42.955    -87.904
# 964          964           Buffalo   USW00014733     42.948    -78.736
# 965          965        Pittsburgh   USC00360861     40.391    -79.859
# 966          966       Minneapolis   USW00014922     44.883    -93.228
# 967          967          Honolulu   USC00519397     21.271   -157.816
# 968          968           Seattle   USW00024234     47.530   -122.300
# 969          969           Phoenix   USW00023183     33.427   -112.003
# 970          970         San Diego   USW00023188     32.733   -117.183
# 971          971         St. Louis   USC00237452     38.629    -90.270
# 972          972       New Orleans   USW00012930     29.916    -90.130
# 973          973            Dallas   USW00013960     32.851    -96.855
# 975          975             Tampa   USW00012842     27.961    -82.540
# 976          976      Philadelphia   USW00013739     39.868    -75.231
# 977          977           Detroit   USW00014822     42.409    -83.010
# 978          978     San Francisco   USW00023272     37.770   -122.426
# 979          979            Denver   USW00023062     39.763   -104.869
# 980          980           Houston   USW00012960     29.980    -95.360
# 981          981             Miami   USC00083909     25.817    -80.285
# 982          982           Atlanta   USW00013874     33.630    -84.441
# 983          983           Chicago   USC00111577     41.737    -87.777
# 984          984       Los Angeles   USW00093134     34.051   -118.235
# 985          985  Washington, D.C.   USC00186350     38.913    -76.970
# 986          986          New York   USW00094728     40.778    -73.969
# 1689        1689     Ciudad Juárez   USW00023044     31.811   -106.375
# 1693        1693          Mexicali   USC00042713     32.766   -115.561
# 1699        1699           Tijuana   USC00041758     32.640   -117.085
#
#       Urban brightness Rural station  Rural Lat  Rural Lon  Rural brightness
# 886               63.0   USC00413133     32.533    -96.660              46.0
# 890               63.0   USC00046175     33.602   -117.880              60.0
# 917               63.0   USC00028214     33.557   -111.535               7.0
# 918               63.0   USR0000TLBJ     33.172    -97.375               8.0
# 919               63.0   USC00047836     33.531   -117.552              11.0
# 920               60.0   USC00060808     41.120    -73.080               7.0
# 921               63.0   USC00088368     26.470    -80.640               4.0
# 922               63.0   USW00023191     33.405   -118.415               4.0
# 923               62.0   USC00193167     42.066    -72.900               8.0
# 924               62.0   USC00375270     41.856    -71.733              12.0
# 925               63.0   USC00010505     33.452    -87.357               7.0
# 926               63.0   USC00083153     27.570    -82.137               4.0
# 927               63.0   USC00440385     36.661    -75.911               5.0
# 928               63.0   USR0000CTRA     37.833   -122.066              13.0
# 929               63.0   USC00087758     26.856    -80.300               7.0
# 930               63.0   USC00157950     38.001    -85.308               5.0
# 931               63.0   USC00389625     34.938    -81.225              10.0
# 932               63.0   USC00333987     40.116    -83.483               7.0
# 933               63.0   USR0000CBPI     34.319   -117.013               5.0
# 934               60.0   USC00060808     41.120    -73.080               7.0
# 935               63.0   USC00212738     44.611    -93.185              21.0
# 936               63.0   USR0000ACAR     32.440   -110.849               4.0
# 937               62.0   USR0000CFAN     36.883   -119.465               4.0
# 938               62.0   USC00295968     34.624   -106.310               3.0
# 939               63.0   USC00234850     38.880    -94.335              28.0
# 940               62.0   USC00345522     36.174    -96.443               6.0
# 941               63.0   USC00413289     32.847    -97.476              27.0
# 942               63.0   USR0000TBEL     30.566    -98.038               4.0
# 943               63.0   USW00003074     32.613   -106.741               3.0
# 944               63.0   USC00083026     28.042    -81.037               5.0
# ...                ...           ...        ...        ...               ...
# 959               62.0   USR0000KCRI     38.769    -84.601              18.0
# 960               62.0   USC00403636     36.340    -86.827              16.0
# 961               63.0   USC00033821     35.687    -90.096               9.0
# 962               63.0   USC00448837     36.595    -76.438               5.0
# 963               62.0   USC00479050     43.368    -88.085              20.0
# 964               63.0   USC00301623     42.663    -78.683              17.0
# 965               61.0   USC00365212     40.458    -79.450              10.0
# 966               63.0   USC00211390     45.322    -93.284              27.0
# 967               62.0   USC00516222     21.350   -157.766              13.0
# 968               63.0   USC00459021     47.372   -122.702              15.0
# 969               63.0   USC00024829     33.336   -112.147              29.0
# 970               63.0   USC00043914     33.237   -116.761               4.0
# 971               63.0   USW00053904     38.928    -90.428              11.0
# 972               63.0   USC00167096     29.789    -90.428              12.0
# 973               63.0   USR0000TLBJ     33.172    -97.375               8.0
# 975               63.0   USC00083153     27.570    -82.137               4.0
# 976               63.0   USC00281038     39.500    -75.166              19.0
# 977               63.0   CA00613CC60     42.033    -82.900              26.0
# 978               63.0   USR0000CSVA     37.562   -122.436               9.0
# 979               63.0   USC00057249     39.428   -105.070               8.0
# 980               63.0   USC00410586     29.914    -94.990              15.0
# 981               63.0   USC00087005     25.938    -80.440              31.0
# 982               63.0   USC00090603     34.332    -84.470              14.0
# 983               63.0   USC00125174     41.264    -87.417              15.0
# 984               63.0   USC00046006     34.230   -118.071              14.0
# 985               63.0   USC00186770     38.683    -76.666              15.0
# 986               63.0   USC00287865     40.463    -74.005              15.0
# 1689              63.0   USW00003074     32.613   -106.741               3.0
# 1693              63.0   USC00043489     32.883   -114.866               4.0
# 1699              63.0   MX000002069     32.380   -116.650               9.0
#
# [74 rows x 10 columns]

# %%
# # calculate the brightness index for all stations
# from osgeo import ogr, osr
# import os
# from shapely.geometry import Point
# import shapely.geometry
# import shapely.wkt
# from cartopy.feature import ShapelyFeature
# from cartopy.io.shapereader import Reader
# import gdal

# # rasterfile = 'data/F182013.v4/F182013.v4c_web.stable_lights.avg_vis.tif'
# # layer = gdal.Open(rasterfile)
# # gt =layer.GetGeoTransform()
# # bands = layer.RasterCount
# # src = layer.GetRasterBand(1)
# X = ghcnSubset['lon']
# Y = ghcnSubset['lat']

# %%
# #rasterfile = 'data/F182013.v4/F182013.v4c_web.stable_lights.avg_vis.tif'
# rasterfile = 'data/F182013.v4/F182013.v4c_web.avg_vis.tif'
# layer = gdal.Open(rasterfile)
# gt =layer.GetGeoTransform()
# bands = layer.RasterCount
# src = layer.GetRasterBand(1)

# BI = np.zeros(X.shape)
# i = 0 
# for x,y in zip(X,Y): 
#     rasterx = int((x - gt[0]) / gt[1])
#     rastery = int((y - gt[3]) / gt[5])
#     BI[i] = src.ReadAsArray(rasterx,rastery, win_xsize=1, win_ysize=1)
#     i = i+1

# #np.save('brightnessGHCNsubset.npy', BI)
# #BI = np.load('data/brightnessGHCN.npy')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-0f6e5b3aad17> in <module>()
#       2 rasterfile = 'data/F182013.v4/F182013.v4c_web.avg_vis.tif'
#       3 layer = gdal.Open(rasterfile)
# ----> 4 gt =layer.GetGeoTransform()
#       5 bands = layer.RasterCount
#       6 src = layer.GetRasterBand(1)
#
# AttributeError: 'NoneType' object has no attribute 'GetGeoTransform'
