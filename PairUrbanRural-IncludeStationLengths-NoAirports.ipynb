# %%
# import libraries
# %matplotlib inline
import numpy as np
#import csv
import matplotlib.pyplot as plt
import pandas as pd
import glob
import ulmo
import os
import scipy.spatial

# %%
ghcn = pd.read_fwf('data/ghcnd-stations.txt', colspecs = [(0,11), (12,19), (21,29), (31,36),(38,40), (41,70), (72,74),(76,78),(80,85)], header = None) 
colnames = ['GHCN ID', 'lat', 'lon', 'elevation', 'state', 'name', 'gsn flag', 'HCN/CRN FLAG', 'WMO ID']
ghcn.columns = colnames

# append the brightness index 
BI = np.load('data/brightnessGHCN.npy')
ghcn['Brightness'] = BI
# from http://www1.ncdc.noaa.gov/pub/data/ghcn/daily/readme.txt
# FORMAT OF "ghcnd-stations.txt"
#
# ------------------------------
# Variable   Columns   Type
# ------------------------------
# ID            1-11   Character
# LATITUDE     13-20   Real
# LONGITUDE    22-30   Real
# ELEVATION    32-37   Real
# STATE        39-40   Character
# NAME         42-71   Character
# GSN FLAG     73-75   Character
# HCN/CRN FLAG 77-79   Character
# WMO ID       81-85   Character
# ------------------------------

# These variables have the following definitions:

# ID         is the station identification code.  Note that the first two
#            characters denote the FIPS  country code, the third character 
#            is a network code that identifies the station numbering system 
#            used, and the remaining eight characters contain the actual 
#            station ID. 

#            See "ghcnd-countries.txt" for a complete list of country codes.
# 	   See "ghcnd-states.txt" for a list of state/province/territory codes.

#            The network code  has the following five values:

#            0 = unspecified (station identified by up to eight 
# 	       alphanumeric characters)
# 	   1 = Community Collaborative Rain, Hail,and Snow (CoCoRaHS)
# 	       based identification number.  To ensure consistency with
# 	       with GHCN Daily, all numbers in the original CoCoRaHS IDs
# 	       have been left-filled to make them all four digits long. 
# 	       In addition, the characters "-" and "_" have been removed 
# 	       to ensure that the IDs do not exceed 11 characters when 
# 	       preceded by "US1". For example, the CoCoRaHS ID 
# 	       "AZ-MR-156" becomes "US1AZMR0156" in GHCN-Daily
#            C = U.S. Cooperative Network identification number (last six 
#                characters of the GHCN-Daily ID)
# 	   E = Identification number used in the ECA&D non-blended
# 	       dataset
# 	   M = World Meteorological Organization ID (last five
# 	       characters of the GHCN-Daily ID)
# 	   N = Identification number used in data supplied by a 
# 	       National Meteorological or Hydrological Center
# 	   R = U.S. Interagency Remote Automatic Weather Station (RAWS)
# 	       identifier
# 	   S = U.S. Natural Resources Conservation Service SNOwpack
# 	       TELemtry (SNOTEL) station identifier
#            W = WBAN identification number (last five characters of the 
#                GHCN-Daily ID)

# LATITUDE   is latitude of the station (in decimal degrees).

# LONGITUDE  is the longitude of the station (in decimal degrees).

# ELEVATION  is the elevation of the station (in meters, missing = -999.9).


# STATE      is the U.S. postal code for the state (for U.S. stations only).

# NAME       is the name of the station.

# GSN FLAG   is a flag that indicates whether the station is part of the GCOS
#            Surface Network (GSN). The flag is assigned by cross-referencing 
#            the number in the WMOID field with the official list of GSN 
#            stations. There are two possible values:

#            Blank = non-GSN station or WMO Station number not available
#            GSN   = GSN station 

# HCN/      is a flag that indicates whether the station is part of the U.S.
# CRN FLAG  Historical Climatology Network (HCN).  There are three possible 
#           values:

#            Blank = Not a member of the U.S. Historical Climatology 
# 	           or U.S. Climate Reference Networks
#            HCN   = U.S. Historical Climatology Network station
# 	   CRN   = U.S. Climate Reference Network or U.S. Regional Climate 
# 	           Network Station

# WMO ID     is the World Meteorological Organization (WMO) number for the
#            station.  If the station has no WMO number (or one has not yet 
# 	   been matched to this station), then the field is blank.

# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
giss = pd.read_fwf('data/v3.temperature.inv.txt',skiprows = 39, header = None,
                  colspecs=[(0,3),(3,8),(8,11), (12,44),(44,49), (52,58), (58,63), (63,67), (67,68), (69,73), (73,75), (75, 77), (78,79), (79,81), (81,82),(82,84), (84,100), (100,102), (103,106)])
colnames = ['icc country code', 'WMO ID', '3 digit modifier', 'name','lat', 'lon', 'elevation', 'TELe', 'P', 'Pop', 'Tp', 'V', 'Lo', 'Co', 'Airport', 'ds', 'Vege', 'bi', 'BI']
giss.columns = colnames

# LEGEND  
# ======
# icc  =3 digit country code; the first digit represents WMO region/continent
# WMO_#=5 digit WMO station number
# ...  =3 digit modifier; 000 means the station is probably the WMO
#       station; 001, etc. mean the station is near that WMO station
# Name =30 character station name
# Lat  =latitude in degrees, negative = South of Equator
# Lon  =longitude in degrees, negative = West of Greenwich (England)
# Elev =station elevation in meters, missing is -999
# TEle =station elevation interpolated from TerrainBase gridded data set
# P    =R if rural (not associated with a town of >10,000 population)
#       S if associated with a small town (10,000-50,000 population)
#       U if associated with an urban area (>50,000 population)
# Pop  =population of the small town or urban area in 1000s
#       If rural, no analysis:  -9.
# Tp   =general topography around the station:  FL flat; HI hilly,
#       MT mountain top; MV mountainous valley or at least not on the top
#       of a mountain.
# V    =general vegetation near the station based on Operational
#       Navigation Charts;  MA marsh; FO forested; IC ice; DE desert;
#       CL clear or open;  xx information not provided
# Lo   =CO if station is within 30 km from the coast
#       LA if station is next to a large (> 25 km**2) lake
#       no if neither of the above
#       Note: Stations which are both CO and LA will be marked CO
# Co   =distance in km to the coast if Lo=CO, else -9
# A    =A if the station is at an airport; else x
# ds   =distance in km from the airport to its associated
#       small town or urban center (not relevant for rural airports
#       or non airport stations in which case ds=-9)
# Vege =gridded vegetation for the 0.5x0.5 degree grid point closest
#       to the station from a gridded vegetation data base. 16 characters.
# bi   =brightness index    A=dark B=dim C=bright   (comment added by R.Ruedy)
# BI   =brightness index    0=dark -> 256 =bright   (based on satellite night light data)

# %% [markdown]
# see: http://stackoverflow.com/questions/35296935/python-calculate-lots-of-distances-quickly

# %%
# subset the GHCN station list with the list of available stations
currentstations = ulmo.ncdc.ghcn_daily.get_stations(start_year=1985, end_year = 2016, elements = ['TMIN', 'TMAX', 'AWND'], as_dataframe=True, update=False)
currentGHCNstations = np.intersect1d(currentstations.id, ghcn.index.values) #ghcn['GHCN ID'].values)
ghcnSubset = ghcn.set_index('GHCN ID').loc[currentstations.id.values]
# at this point, ghcn must have the station id set as the index

# %%
#ghcn = ghcn[ghcn.index.str.contains('US')] # subset to US stations

# %%
ghcn_noairport = ghcn[~ghcn.name.str.contains('INTL')]
ghcn_noairport = ghcn_noairport[~ghcn_noairport.name.str.contains(' AP')]
ghcn_noairport = ghcn_noairport[~ghcn_noairport.name.str.contains('AIRPORT')]

# %%
ghcn = ghcn_noairport.set_index('GHCN ID').loc[currentstations.id.values]
ghcn
# Out:
#                 lat      lon  elevation state                  name gsn flag  \
# GHCN ID
# AE000041196  25.333   55.517       34.0   NaN   SHARJAH INTER. AIRP       GS
# AEM00041194     NaN      NaN        NaN   NaN                   NaN      NaN
# AEM00041217     NaN      NaN        NaN   NaN                   NaN      NaN
# AEM00041218     NaN      NaN        NaN   NaN                   NaN      NaN
# AF000040930  35.317   69.017     3366.0   NaN          NORTH-SALANG       GS
# AFM00040938  34.210   62.228      977.0   NaN                 HERAT      NaN
# AFM00040948     NaN      NaN        NaN   NaN                   NaN      NaN
# AFM00040990     NaN      NaN        NaN   NaN                   NaN      NaN
# AG000060390  36.716    3.250       24.0   NaN    ALGER-DAR EL BEIDA       GS
# AG000060590  30.566    2.866      397.0   NaN              EL-GOLEA       GS
# AG000060611  28.050    9.633      561.0   NaN             IN-AMENAS       GS
# AG000060680  22.800    5.433     1362.0   NaN           TAMANRASSET       GS
# AGE00147708  36.720    4.050      222.0   NaN            TIZI OUZOU      NaN
# AGE00147710  36.750    5.100        9.0   NaN  BEJAIA-BOUGIE (PORT)      NaN
# AGE00147716  35.100   -1.850       83.0   NaN   NEMOURS (GHAZAOUET)      NaN
# AGE00147718  34.850    5.720      125.0   NaN                BISKRA      NaN
# AGE00147719  33.799    2.890      767.0   NaN              LAGHOUAT      NaN
# AGM00060351  36.795    5.874       11.0   NaN                 JIJEL      NaN
# AGM00060353  36.817    5.883        6.0   NaN            JIJEL-PORT      NaN
# AGM00060355  36.933    6.950        7.0   NaN                SKIKDA      NaN
# AGM00060360  36.822    7.809        4.0   NaN                ANNABA      NaN
# AGM00060367  36.900    8.450       13.0   NaN               EL-KALA      NaN
# AGM00060369  36.767    3.100       12.0   NaN            ALGER-PORT      NaN
# AGM00060387  36.917    3.950        8.0   NaN                DELLYS      NaN
# AGM00060402  36.712    5.070        6.0   NaN               SOUMMAM      NaN
# AGM00060403  36.467    7.467      228.0   NaN                GUELMA      NaN
# AGM00060405  36.500    7.717      111.0   NaN            BOUCHEGOUF      NaN
# AGM00060410  36.500    1.333       18.0   NaN                 TENES      NaN
# AGM00060415  36.317    3.533      748.0   NaN            AIN-BESSAM      NaN
# AGM00060417  36.383    3.883      560.0   NaN                BOUIRA      NaN
# ...             ...      ...        ...   ...                   ...      ...
# WF000917530 -13.233 -176.167       27.0   NaN   HIHIFO (ILE WALLIS)       GS
# WFM00091754 -14.317 -178.117       36.0   NaN   FUTUNA ISL/MAOPOOPO      NaN
# WIM00060096  23.700  -15.867       10.0   NaN   VILLA CISNEROS(MIL)      NaN
# WQW00041606  19.283  166.650        4.0    UM           WAKE ISLAND      NaN
# WZ004455110 -26.533   31.300      641.0   NaN   MANZINI/MATSAPA AIR      NaN
# ZA000067441 -11.750   24.433     1363.0   NaN            MWINILUNGA       GS
# ZA000067475 -10.217   31.133     1384.0   NaN                KASAMA       GS
# ZA000067581 -13.550   32.583     1032.0   NaN               CHIPATA       GS
# ZA000067633 -15.250   23.150     1053.0   NaN                 MONGU       GS
# ZA000067743 -17.817   25.817      986.0   NaN           LIVINGSTONE       GS
# ZAM00067663 -14.450   28.467     1207.0   NaN        KABWE/MILLIKEN      NaN
# ZI000067755 -17.617   27.333      617.0   NaN                 BINGA      NaN
# ZI000067761 -16.517   28.883      518.0   NaN                KARIBA      NaN
# ZI000067765 -16.833   29.617     1344.0   NaN                 KAROI      NaN
# ZI000067775 -17.917   31.133     1480.0   NaN      HARARE (KUTSAGA)       GS
# ZI000067779 -16.783   31.583      966.0   NaN          MOUNT DARWIN      NaN
# ZI000067781 -17.417   32.217     1244.0   NaN                MUTOKO      NaN
# ZI000067789 -17.033   30.850     1480.0   NaN                MVURWI      NaN
# ZI000067843 -18.100   25.850     1062.0   NaN        VICTORIA FALLS      NaN
# ZI000067853 -18.633   27.000     1077.0   NaN   HWANGE NATIONAL PAR      NaN
# ZI000067861 -18.217   28.933     1282.0   NaN                 GOKWE      NaN
# ZI000067865 -18.933   29.833     1215.0   NaN                KWEKWE      NaN
# ZI000067867 -19.450   29.850     1429.0   NaN                 GWERU      NaN
# ZI000067889 -18.283   32.750     1880.0   NaN                WYANGA      NaN
# ZI000067965     NaN      NaN        NaN   NaN                   NaN      NaN
# ZI000067969 -21.050   29.367      861.0   NaN        WEST NICHOLSON      NaN
# ZI000067975 -20.067   30.867     1095.0   NaN              MASVINGO      NaN
# ZI000067977 -21.017   31.583      430.0   NaN         BUFFALO RANGE      NaN
# ZI000067983 -20.200   32.616     1132.0   NaN              CHIPINGE       GS
# ZI000067991 -22.217   30.000      457.0   NaN            BEITBRIDGE      NaN
#
#             HCN/CRN FLAG   WMO ID  Brightness
# GHCN ID
# AE000041196          NaN  41196.0        63.0
# AEM00041194          NaN      NaN         NaN
# AEM00041217          NaN      NaN         NaN
# AEM00041218          NaN      NaN         NaN
# AF000040930          NaN  40930.0         4.0
# AFM00040938          NaN  40938.0        19.0
# AFM00040948          NaN      NaN         NaN
# AFM00040990          NaN      NaN         NaN
# AG000060390          NaN  60390.0        63.0
# AG000060590          NaN  60590.0        47.0
# AG000060611          NaN  60611.0        24.0
# AG000060680          NaN  60680.0        22.0
# AGE00147708          NaN  60395.0        62.0
# AGE00147710          NaN  60401.0        47.0
# AGE00147716          NaN  60517.0        52.0
# AGE00147718          NaN  60525.0        63.0
# AGE00147719          NaN  60545.0        61.0
# AGM00060351          NaN  60351.0        56.0
# AGM00060353          NaN  60353.0        57.0
# AGM00060355          NaN  60355.0        29.0
# AGM00060360          NaN  60360.0        52.0
# AGM00060367          NaN  60367.0        47.0
# AGM00060369          NaN  60369.0        55.0
# AGM00060387          NaN  60387.0         8.0
# AGM00060402          NaN  60402.0        54.0
# AGM00060403          NaN  60403.0        54.0
# AGM00060405          NaN  60405.0        30.0
# AGM00060410          NaN  60410.0        19.0
# AGM00060415          NaN  60415.0         6.0
# AGM00060417          NaN  60417.0        63.0
# ...                  ...      ...         ...
# WF000917530          NaN  91753.0         4.0
# WFM00091754          NaN  91754.0         4.0
# WIM00060096          NaN  60096.0         4.0
# WQW00041606          NaN  91246.0         4.0
# WZ004455110          NaN  68396.0        20.0
# ZA000067441          NaN  67441.0         8.0
# ZA000067475          NaN  67475.0         8.0
# ZA000067581          NaN  67581.0        12.0
# ZA000067633          NaN  67633.0        36.0
# ZA000067743          NaN  67743.0        25.0
# ZAM00067663          NaN  67663.0        48.0
# ZI000067755          NaN  67755.0         5.0
# ZI000067761          NaN  67761.0         6.0
# ZI000067765          NaN  67765.0         5.0
# ZI000067775          NaN  67775.0        10.0
# ZI000067779          NaN  67779.0         8.0
# ZI000067781          NaN  67781.0         8.0
# ZI000067789          NaN  67789.0         9.0
# ZI000067843          NaN  67843.0         8.0
# ZI000067853          NaN  67853.0         4.0
# ZI000067861          NaN  67861.0        13.0
# ZI000067865          NaN  67865.0        17.0
# ZI000067867          NaN  67867.0         8.0
# ZI000067889          NaN  67889.0         3.0
# ZI000067965          NaN      NaN         NaN
# ZI000067969          NaN  67969.0         4.0
# ZI000067975          NaN  67975.0         5.0
# ZI000067977          NaN  67977.0         4.0
# ZI000067983          NaN  67983.0         9.0
# ZI000067991          NaN  67991.0        37.0
#
# [23063 rows x 9 columns]

# %%
# compute distances between all stations
#tree = scipy.spatial.cKDTree(giss[['lon', 'lat']].values, leafsize=100)
# query the closest point 
#closestInd = tree.query(giss[['lon', 'lat']].values[11,:], k =2, distance_upper_bound=6)[1][1]

# %%
atlas = pd.read_csv('data/sampleAtlas.csv') # derived  from http://www.naturalearthdata.com/downloads/10m-cultural-vectors/10m-populated-places/
atlas = pd.read_csv('data/world_cities.csv')
tree = scipy.spatial.cKDTree(ghcn[['lon', 'lat']].values, leafsize=100)
#import sys
#sys.path.append('/../cityheat/Bmore/2015/')
#sys.path.append('/Users/annascott2/mountpoint/cityheat/Bmore/2015/')
#import spatialfunctions
atlas = atlas[atlas['pop']> 500000]

# %%
#atlas = pd.read_csv('data/world_cities.csv')

# %%
atlas = atlas[atlas['country'].str.contains('United States')] # do non-US countries

# %%
#atlas = atlas[atlas['country'].str.contains('United States')].set_index('city')

# %%
brightness_threshold = 25 # this is the urban/rural threshold delimiter, difference between urban and rural
#outFile = 'worldghcnpairs_stationlengths.csv'
outFile = 'USpairs_stationlengths_stationavailability75_noairport.csv'
pairs = []
frames = []
startdate = np.datetime64('1985-06-01')
enddate = np.datetime64('2015-08-30')

# %%
#for i in range(793, atlas.shape[0]): 

data_availability_thresh = .75
for i in range(23, atlas.shape[0]):
    lat = atlas.iloc[i]['lat']
    lon = atlas.iloc[i]['lng']
    city = atlas.iloc[i]['city_ascii']
    print(city)
    closeststations = tree.query([lon,lat], k =15, distance_upper_bound=1)

    # Make sure the closest stations are within a finite distance
    closestInds = closeststations[1][~np.isinf(closeststations[0])]
    # make sure that there are stations 
    if closestInds.shape[0] > 0 : 
        urban = ghcn.Brightness[closestInds].argmax()
        rural = ghcn.Brightness[closestInds].argmin()
        #         if urban != rural: 
        urban_data = ulmo.ncdc.ghcn_daily.get_data(urban, as_dataframe=True, update=False)
        rural_data = ulmo.ncdc.ghcn_daily.get_data(rural, as_dataframe=True, update=False)

        number_urban_stations = (ghcn.Brightness[closestInds] >= brightness_threshold).sum() # number of urban stations is equivalent to brightness over 30
        number_rural_stations = (ghcn.Brightness[closestInds] < brightness_threshold).sum() # number of rural stations is equivalent to brightness over 30
        delta_brightness = 30
        break_value = -1

        iii = 1
#        while ('TMAX' not in urban_data.keys() or 'TMIN' not in urban_data.keys()) or (urban_data['TMAX'].index[0].to_timestamp().to_datetime() > startdate) or (urban_data['TMAX'].index[-1].to_timestamp().to_datetime() < enddate) : 
        while ('TMAX' not in urban_data.keys()) or ('TMIN' not in urban_data.keys()) or (urban_data['TMAX'].index[0].to_timestamp() > startdate) or (urban_data['TMAX'].index[-1].to_timestamp() < enddate) or ((~np.isnan(urban_data['TMIN'].set_index(urban_data['TMIN'].index.to_timestamp())['1985-06-01':'2015-08-31'].value.values.astype(float))).sum()/(365*30.+90.) < data_availability_thresh) : 
        # check if there's enough suitable urban stations to check the next one, ignoring the current one 
            if iii > number_urban_stations-1 : 
                print('no suitable urban station for %s'%city) 
                urban = break_value
                break 
            # find the next brightestcity
            print 'finding the next urban station for %s'%city
            urban = ghcn.Brightness[closestInds][(-ghcn.Brightness[closestInds].values).argsort()].index[iii]
            urban_data = ulmo.ncdc.ghcn_daily.get_data(urban, as_dataframe=True, update=False)
            #print urban, urban_data['TMIN'].index[0], urban_data['TMIN'].index[-1], ghcn.Brightness[urban], urban_data.keys(), (~np.isnan(urban_data['TMIN'].set_index(urban_data['TMIN'].index.to_timestamp())['1985-06-01':'2015-08-31'].value.values.astype(float))).sum()/(365.*30.+90.)
            iii = iii+1    

        # if no urban station found, don't bother to pair with rural 
        if urban != break_value : 
            # check rural data station different from urban has TMIN, TMAX, a long enough record, and is rural enough compared to urban (delta_brightness)
            iii = 1
            enlarge_circle = 0 # number of times we can try increasing search radius
            while (urban ==rural) or ('TMAX' not in rural_data.keys() and 'TMIN' not in rural_data.keys()) or (rural_data['TMIN'].index[0].to_timestamp() > startdate) or (rural_data['TMIN'].index[-1].to_timestamp() < enddate) or (ghcn.Brightness[urban]-ghcn.Brightness[rural]<delta_brightness) or ((~np.isnan(rural_data['TMIN'].set_index(rural_data['TMIN'].index.to_timestamp())['1985-06-01':'2015-08-31'].value.values.astype(float))).sum()/(365*30.+90) < data_availability_thresh): 
                print 'finding the next rural station for %s'%city

                # if we can't find any suitable stations, try enlarging the search radius, but only try this once
                if iii > number_rural_stations-1 : 
                    if enlarge_circle > 0 : 
                        rural = break_value
                        break #break when we've already used up all the search
                    else: 
                        # find 25 closest stations within 1.5 degree circle
                        closeststations1 = tree.query([lon,lat], k =35, distance_upper_bound=1.5 ) 
                        # eliminate the ones we've already search 
                        new_stations = np.setdiff1d(closeststations1[1], closeststations[1])
                        # Make sure that we've actually found new stations, otherwise break
                        if new_stations.shape[0] >0 : 
                            # Make sure the closest stations are within a finite distance
                            closestInds1 = closeststations1[1][~np.isinf(closeststations1[0])]
                            # Eliminate repeat stations
                            closestInds = np.intersect1d(new_stations, closestInds1)
                            # reset counter, number of rural stations
                            iii = 0
                            number_rural_stations = (ghcn.Brightness[closestInds] < brightness_threshold).sum()
                        else: 
                            rural = break_value
                            break
                        # reset list of rural stations
                    print 'increasing search radius'
                    enlarge_circle = enlarge_circle+1
                    
                # find the next dimmest
                rural = ghcn.Brightness[closestInds][(ghcn.Brightness[closestInds].values).argsort()].index[iii]
                rural_data = ulmo.ncdc.ghcn_daily.get_data(rural, as_dataframe=True, update=False)
                print rural, rural_data['TMIN'].index[0], rural_data['TMIN'].index[-1], ghcn.Brightness[rural], rural_data.keys(), (~np.isnan(rural_data['TMIN'].set_index(rural_data['TMIN'].index.to_timestamp())['1985-06-01':'2015-08-31'].value.values.astype(float))).sum()/(365*30.+90)
                iii = iii+1
        else: 
            rural = break_value
    # else condition for not being any stations
    else: 
        urban = break_value 
        rural = break_value
            
    # save out if we've found a good pairing
    if (urban != break_value) and (rural != break_value) : 
        print('Found a pair for %s'%city)
        print('Urban start/end is: %s to %s'%(urban_data['TMAX'].index[0].to_timestamp().to_datetime(),  urban_data['TMAX'].index[-1].to_timestamp().to_datetime()))
        print('Rural start/end is: %s to %s'%(rural_data['TMAX'].index[0].to_timestamp().to_datetime(),  rural_data['TMAX'].index[-1].to_timestamp().to_datetime()))
        frames.append([city, urban, #['GHCN ID'],
                       ghcn.loc[urban].lat, 
                       ghcn.loc[urban].lon, 
                       ghcn.loc[urban].Brightness,
                       urban_data['TMAX'].index[0].to_timestamp().to_datetime(), urban_data['TMAX'].index[-1].to_timestamp().to_datetime(), 
                       rural, #['GHCN ID'],
                       ghcn.loc[rural].lat, 
                       ghcn.loc[rural].lon, 
                       ghcn.loc[rural].Brightness, 
                        rural_data['TMAX'].index[0].to_timestamp().to_datetime(), rural_data['TMAX'].index[-1].to_timestamp().to_datetime(),])
    else : 
        print 'No pair found for %s'%city
        frames.append([city, np.nan, #['GHCN ID'],
                       np.nan,
                       np.nan,
                       np.nan, 
                       np.nan, #['GHCN ID'],
                       np.nan,
                       np.nan,
                       np.nan, np.nan, np.nan, np.nan, np.nan])

    # periodiically save out results
    if i%50 ==0: 
        pairs = pd.DataFrame(frames, columns = ['City', 'Urban station', 
                                          'Urban Lat', 'Urban Lon','Urban brightness', 'Urban start', 'Urban end',
                                          'Rural station', 
                                          'Rural Lat', 'Rural Lon','Rural brightness', 'Rural start', 'Rural end'])

        pairs.to_csv(outFile)
        
# pairs = pd.DataFrame(frames, columns = ['City', 'Urban station', 
#                                   'Urban Lat', 'Urban Lon','Urban brightness', 
#                                   'Rural station', 
#                                   'Rural Lat', 'Rural Lon','Rural brightness'])

pairs = pd.DataFrame(frames, columns = ['City', 'Urban station', 
                                          'Urban Lat', 'Urban Lon','Urban brightness', 'Urban start', 'Urban end',
                                          'Rural station', 
                                          'Rural Lat', 'Rural Lon','Rural brightness', 'Rural start', 'Rural end'])

pairs.to_csv(outFile)
pairs[(~np.isnan(pairs['Urban Lat'])) & (pairs['Rural start']<startdate)].to_csv(outFile)
# Out:
# Tulsa
# finding the next urban station for Tulsa
# finding the next urban station for Tulsa
# finding the next urban station for Tulsa
# finding the next urban station for Tulsa
# finding the next rural station for Tulsa
# USC00341902 1984-05-01 2000-10-31 7.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.449003623188
# finding the next rural station for Tulsa
# USC00344098 1949-04-01 1951-04-30 8.0 ['PRCP', 'TMIN', 'SNWD', 'TOBS', 'WT14', 'EVAP', 'SNOW', 'WT11', 'TMAX', 'DAPR', 'DAEV', 'WT08', 'MDEV', 'WT04', 'WDMV', 'DAWM', 'MDWM', 'WT01', 'MDPR', 'WT03'] 0.0
# finding the next rural station for Tulsa
# USC00346670 1910-01-01 2011-10-31 8.0 ['WT18', 'WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'WT16', 'WT03', 'SNWD', 'WT11', 'WT05', 'WT04', 'WT07', 'PRCP', 'WT01', 'MDPR', 'DASF'] 0.589673913043
# finding the next rural station for Tulsa
# USC00344289 1948-03-01 2007-06-30 12.0 ['WT18', 'WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'WT09', 'WT08', 'SNWD', 'WT11', 'WT05', 'WT04', 'WT16', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.00471014492754
# finding the next rural station for Tulsa
# USC00344812 1957-08-01 2016-10-31 16.0 ['PRCP', 'TMIN', 'SNWD', 'TOBS', 'EVAP', 'MNPN', 'MDSF', 'MXPN', 'SNOW', 'TMAX', 'DAPR', 'DAEV', 'MDEV', 'WDMV', 'DAWM', 'MDWM', 'MDPR', 'DASF'] 0.718297101449
# finding the next rural station for Tulsa
# USC00346729 1956-09-01 2016-10-31 18.0 ['PRCP', 'TMIN', 'SNWD', 'TOBS', 'EVAP', 'MDSF', 'SNOW', 'WT11', 'TMAX', 'DAPR', 'DAEV', 'MDEV', 'WT04', 'WDMV', 'DAWM', 'MDWM', 'MDPR', 'DASF'] 0.36856884058
# finding the next rural station for Tulsa
# increasing search radius
# USC00344393 1946-06-01 2016-11-30 4.0 ['TMIN', 'MNPN', 'SNWD', 'WT11', 'DAPR', 'DAEV', 'WT08', 'WT05', 'WT04', 'WT06', 'WT01', 'MDPR', 'WT03', 'TOBS', 'EVAP', 'WT09', 'MXPN', 'MDEV', 'DAWM', 'DASF', 'TMAX', 'MDSF', 'SNOW', 'WT10', 'MDWM', 'WT16', 'WT14', 'WDMV', 'WT18', 'PRCP'] 0.636503623188
# finding the next rural station for Tulsa
# USC00344975 1970-09-01 2004-02-29 5.0 ['PRCP', 'TMIN', 'SNWD', 'TOBS', 'EVAP', 'MNPN', 'MDSF', 'MXPN', 'SNOW', 'TMAX', 'DAPR', 'DAEV', 'MDEV', 'WT04', 'WDMV', 'DAWM', 'MDWM', 'WT01', 'MDPR', 'DASF', 'WT06'] 0.556612318841
# finding the next rural station for Tulsa
# USC00341685 2009-12-01 2016-10-31 5.0 ['TMIN', 'TOBS', 'SX32', 'TMAX', 'SNOW', 'DAPR', 'SN32', 'SNWD', 'PRCP', 'MDPR'] 0.190036231884
# finding the next rural station for Tulsa
# USC00349445 1900-04-01 2007-06-30 5.0 ['WT18', 'WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'WT16', 'WT03', 'SNWD', 'WT11', 'WT05', 'WT04', 'WT07', 'PRCP', 'WT01', 'MDPR', 'DASF', 'WT08'] 0.698460144928
# finding the next rural station for Tulsa
# USC00349203 1895-06-01 2011-02-28 5.0 ['TMIN', 'SNWD', 'DAPR', 'WT09', 'WT08', 'WT05', 'WT04', 'WT07', 'WT06', 'WT01', 'MDPR', 'WT03', 'TOBS', 'DASF', 'TMAX', 'MDSF', 'SNOW', 'WT11', 'WT16', 'WT14', 'WT18', 'PRCP'] 0.63740942029
# finding the next rural station for Tulsa
# USC00342993 1912-02-01 2002-01-31 5.0 ['WT18', 'WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'WT16', 'WT08', 'SNWD', 'WT11', 'WT05', 'WT04', 'WT07', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.511956521739
# finding the next rural station for Tulsa
# USC00340028 2005-01-01 2012-05-31 6.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'SNWD', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.228260869565
# finding the next rural station for Tulsa
# USC00343286 1946-06-01 2016-11-30 6.0 ['TMIN', 'SNWD', 'MDWM', 'DAPR', 'DAEV', 'WT08', 'WT05', 'WT04', 'WT07', 'WT06', 'WT01', 'MDPR', 'WT03', 'TOBS', 'EVAP', 'MDEV', 'DAWM', 'TMAX', 'SNOW', 'WT11', 'WT16', 'WT14', 'WDMV', 'PRCP'] 0.367934782609
# finding the next rural station for Tulsa
# USC00343884 1960-10-01 2001-12-31 6.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'WT09', 'WT03', 'SNWD', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'DASF', 'WT08'] 0.546829710145
# finding the next rural station for Tulsa
# USC00347390 1959-04-01 2016-12-31 6.0 ['WT18', 'WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'WT09', 'SNWD', 'WT11', 'WT05', 'WT04', 'WT16', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.978260869565
# Found a pair for Tulsa
# Urban start/end is: 1900-04-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1959-04-01 00:00:00 to 2016-12-31 00:00:00
# Ft. Worth
# finding the next urban station for Ft. Worth
# finding the next rural station for Ft. Worth
# increasing search radius
# USR0000TLBJ 2000-01-01 2016-09-30 8.0 ['TAVG', 'TMAX', 'TMIN'] 0.515398550725
# finding the next rural station for Ft. Worth
# USC00410518 1965-04-01 2016-12-31 9.0 ['PRCP', 'TMIN', 'SNWD', 'TOBS', 'EVAP', 'MNPN', 'MXPN', 'SNOW', 'TMAX', 'DAPR', 'DAEV', 'MDEV', 'WDMV', 'DAWM', 'MDWM', 'MDPR'] 0.974184782609
# Found a pair for Ft. Worth
# Urban start/end is: 1946-09-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1965-04-01 00:00:00 to 2016-12-31 00:00:00
# Austin
# finding the next urban station for Austin
# finding the next rural station for Austin
# USW00023907 2008-02-01 2016-10-31 4.0 ['TMAX', 'PRCP', 'TMIN'] 0.249365942029
# finding the next rural station for Austin
# USC00411541 2001-10-01 2013-12-31 5.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.397373188406
# finding the next rural station for Austin
# USC00417497 1965-05-01 2000-12-31 12.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.464945652174
# finding the next rural station for Austin
# increasing search radius
# USR0000TBIR 2001-05-01 2016-11-30 4.0 ['TAVG', 'TMAX', 'TMIN'] 0.470199275362
# finding the next rural station for Austin
# USC00413686 1980-07-01 2016-12-31 5.0 ['PRCP', 'TMIN', 'SNWD', 'TOBS', 'EVAP', 'MNPN', 'MXPN', 'SNOW', 'TMAX', 'DAPR', 'DAEV', 'MDEV', 'WDMV', 'DAWM', 'MDWM', 'WT01', 'MDPR', 'WT03'] 0.944927536232
# Found a pair for Austin
# Urban start/end is: 1938-06-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1980-07-01 00:00:00 to 2016-12-31 00:00:00
# El Paso
# finding the next urban station for El Paso
# finding the next urban station for El Paso
# finding the next urban station for El Paso
# finding the next rural station for El Paso
# USC00294426 1914-06-01 2016-12-31 3.0 ['TMIN', 'SNWD', 'WT11', 'DAPR', 'DAEV', 'WT08', 'WT05', 'WT04', 'WT07', 'WT01', 'MDPR', 'WT03', 'TOBS', 'EVAP', 'MDEV', 'DAWM', 'DASF', 'TMAX', 'MDSF', 'SNOW', 'MDWM', 'WT16', 'WDMV', 'WT18', 'PRCP'] 0.866576086957
# Found a pair for El Paso
# Urban start/end is: 1959-04-01 00:00:00 to 2016-08-31 00:00:00
# Rural start/end is: 1914-06-01 00:00:00 to 2016-12-31 00:00:00
# Orlando
# finding the next urban station for Orlando
# finding the next urban station for Orlando
# finding the next rural station for Orlando
# USR0000FCEN 2003-02-01 2016-11-30 6.0 ['TAVG', 'TMAX', 'TMIN'] 0.370471014493
# finding the next rural station for Orlando
# USC00081641 1948-07-01 2016-12-31 11.0 ['WT11', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'WT08', 'SNWD', 'WT05', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.958876811594
# Found a pair for Orlando
# Urban start/end is: 1892-01-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1948-07-01 00:00:00 to 2016-12-31 00:00:00
# Jacksonville
# finding the next rural station for Jacksonville
# USC00082915 1892-01-01 2016-12-31 5.0 ['WT11', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'WT16', 'SNWD', 'WT05', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.936322463768
# Found a pair for Jacksonville
# Urban start/end is: 1944-07-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1892-01-01 00:00:00 to 2016-12-31 00:00:00
# Indianapolis
# finding the next urban station for Indianapolis
# finding the next urban station for Indianapolis
# finding the next rural station for Indianapolis
# increasing search radius
# USR0000IHAR 2002-07-01 2016-11-30 5.0 ['TAVG', 'TMAX', 'TMIN'] 0.421467391304
# finding the next rural station for Indianapolis
# USC00129905 1992-06-01 2017-01-31 7.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.715760869565
# finding the next rural station for Indianapolis
# USC00128784 1971-08-01 2016-12-31 9.0 ['TMIN', 'SN52', 'SN12', 'MNPN', 'SNWD', 'WT11', 'TOBS', 'DAPR', 'SX52', 'WT05', 'WT04', 'WT06', 'WT01', 'MDPR', 'WT03', 'SX12', 'SX32', 'EVAP', 'MXPN', 'DAWM', 'WESF', 'TMAX', 'SNOW', 'MDWM', 'SN32', 'WDMV', 'WESD', 'PRCP'] 0.878713768116
# Found a pair for Indianapolis
# Urban start/end is: 1948-01-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1971-08-01 00:00:00 to 2016-12-31 00:00:00
# Richmond
# finding the next urban station for Richmond
# Found a pair for Richmond
# Urban start/end is: 1916-10-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1959-01-01 00:00:00 to 2016-11-30 00:00:00
# Baltimore
# finding the next urban station for Baltimore
# finding the next urban station for Baltimore
# finding the next urban station for Baltimore
# finding the next urban station for Baltimore
# finding the next urban station for Baltimore
# finding the next urban station for Baltimore
# finding the next rural station for Baltimore
# increasing search radius
# USC00189030 1940-07-01 1996-11-30 10.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.377989130435
# finding the next rural station for Baltimore
# USC00185934 1988-03-01 2016-08-31 13.0 ['WT06', 'TMIN', 'SNWD', 'SX32', 'TOBS', 'TMAX', 'WDFG', 'SNOW', 'WSFG', 'WT11', 'SN32', 'AWND', 'WT04', 'WT05', 'WESD', 'PRCP', 'WT01', 'WT03'] 0.909692028986
# finding the next rural station for Baltimore
# USC00364019 1919-09-01 1999-03-31 14.0 ['WT18', 'WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'WT09', 'WT03', 'SNWD', 'WT11', 'WT05', 'WT04', 'WT16', 'PRCP', 'WT01', 'MDPR', 'DASF', 'WT08'] 0.445923913043
# finding the next rural station for Baltimore
# USC00186770 1917-01-01 1998-02-28 15.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'WT08', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.41259057971
# finding the next rural station for Baltimore
# USC00363665 1993-08-01 2016-11-30 16.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'WT11', 'DAPR', 'SNWD', 'WT04', 'WT05', 'WESD', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.726902173913
# finding the next rural station for Baltimore
# USC00182060 1936-01-01 2016-10-31 18.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'WT03', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'DASF', 'WT08'] 0.830253623188
# Found a pair for Baltimore
# Urban start/end is: 1941-05-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1936-01-01 00:00:00 to 2016-10-31 00:00:00
# San Jose
# finding the next urban station for San Jose
# finding the next urban station for San Jose
# Found a pair for San Jose
# Urban start/end is: 1945-03-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1948-07-01 00:00:00 to 2016-12-31 00:00:00
# Sacramento
# finding the next rural station for Sacramento
# USR0000CPIL 1993-04-01 2016-10-31 7.0 ['TAVG', 'TMAX', 'TMIN'] 0.73731884058
# finding the next rural station for Sacramento
# USC00044712 1975-08-01 2016-10-31 7.0 ['TMIN', 'TOBS', 'EVAP', 'MNPN', 'MXPN', 'SNOW', 'MDWM', 'SNWD', 'WDMV', 'DAWM', 'PRCP', 'WT01', 'TMAX'] 0.985507246377
# Found a pair for Sacramento
# Urban start/end is: 1877-07-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1975-08-01 00:00:00 to 2016-10-31 00:00:00
# Las Vegas
# finding the next urban station for Las Vegas
# finding the next urban station for Las Vegas
# finding the next urban station for Las Vegas
# finding the next urban station for Las Vegas
# no suitable urban station for Las Vegas
# No pair found for Las Vegas
# Portland
# finding the next urban station for Portland
# finding the next rural station for Portland
# USR0000OEAG 2002-02-01 2016-10-31 12.0 ['TAVG', 'TMAX', 'TMIN'] 0.444836956522
# finding the next rural station for Portland
# USC00357466 1976-08-01 2015-05-31 19.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.837047101449
# finding the next rural station for Portland
# increasing search radius
# USR0000OHOR 1985-05-01 2017-01-31 3.0 ['TAVG', 'TMAX', 'TMIN'] 0.975634057971
# Found a pair for Portland
# Urban start/end is: 1891-08-01 00:00:00 to 2016-09-30 00:00:00
# Rural start/end is: 1985-05-01 00:00:00 to 2017-01-31 00:00:00
# Salt Lake City
# finding the next urban station for Salt Lake City
# finding the next urban station for Salt Lake City
# finding the next urban station for Salt Lake City
# finding the next urban station for Salt Lake City
# finding the next urban station for Salt Lake City
# finding the next urban station for Salt Lake City
# finding the next rural station for Salt Lake City
# USS0011J64S 1988-06-01 2016-09-30 8.0 ['TAVG', 'TMIN', 'TOBS', 'TMAX', 'SNWD', 'WESD', 'PRCP'] 0.892300724638
# finding the next rural station for Salt Lake City
# USS0011J69S 1999-09-01 2016-10-31 10.0 ['TAVG', 'WSFI', 'TMIN', 'SNWD', 'TOBS', 'TMAX', 'AWND', 'WESD', 'PRCP', 'AWDR'] 0.516757246377
# finding the next rural station for Salt Lake City
# USS0011J68S 1999-08-01 2016-10-31 11.0 ['TAVG', 'WSFI', 'TMIN', 'SNWD', 'TOBS', 'TMAX', 'AWND', 'WESD', 'PRCP', 'AWDR'] 0.530253623188
# finding the next rural station for Salt Lake City
# USS0011J12S 2003-11-01 2016-10-31 11.0 ['TAVG', 'TMIN', 'TOBS', 'TMAX', 'SNWD', 'WESD', 'PRCP'] 0.388858695652
# finding the next rural station for Salt Lake City
# USC00425892 1935-10-01 2016-11-30 18.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'WT16', 'DAPR', 'WT09', 'WT03', 'SNWD', 'WT11', 'WT05', 'WT04', 'WT07', 'PRCP', 'WT01', 'MDPR', 'DASF', 'WT08'] 0.814945652174
# Found a pair for Salt Lake City
# Urban start/end is: 1941-09-01 00:00:00 to 2016-09-30 00:00:00
# Rural start/end is: 1927-07-01 00:00:00 to 2016-11-30 00:00:00
# Omaha
# Found a pair for Omaha
# Urban start/end is: 1948-01-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1968-10-01 00:00:00 to 2016-12-31 00:00:00
# Oklahoma City
# finding the next urban station for Oklahoma City
# finding the next urban station for Oklahoma City
# finding the next urban station for Oklahoma City
# finding the next urban station for Oklahoma City
# finding the next urban station for Oklahoma City
# finding the next urban station for Oklahoma City
# finding the next urban station for Oklahoma City
# no suitable urban station for Oklahoma City
# No pair found for Oklahoma City
# San Antonio
# finding the next urban station for San Antonio
# finding the next rural station for San Antonio
# USW00012971 1996-07-01 2016-10-31 10.0 ['TSUN', 'TMIN', 'SNWD', 'PGTM', 'WV03', 'WT09', 'WT08', 'WT05', 'WT04', 'WT07', 'WT06', 'WT01', 'WSF5', 'WT03', 'WT02', 'WT22', 'FMTM', 'AWND', 'WSF2', 'TAVG', 'WT19', 'TMAX', 'SNOW', 'WT13', 'WT11', 'WT16', 'WT17', 'WT14', 'WDF2', 'WT18', 'PRCP', 'WDF5'] 0.627355072464
# finding the next rural station for San Antonio
# USC00416273 2010-09-01 2016-10-31 10.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'WT11', 'DAPR', 'SNWD', 'WT04', 'WT05', 'WESD', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.165398550725
# finding the next rural station for San Antonio
# USC00415454 1976-12-01 2007-07-31 14.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.727807971014
# finding the next rural station for San Antonio
# USC00417215 1941-11-01 2016-10-31 19.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'WT08', 'SNWD', 'WT11', 'WT05', 'WT04', 'WT07', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.946739130435
# Found a pair for San Antonio
# Urban start/end is: 1893-01-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1941-11-01 00:00:00 to 2016-10-31 00:00:00
# Raleigh
# finding the next rural station for Raleigh
# USC00316122 2003-04-01 2016-10-31 14.0 ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'PRCP', 'MDPR'] 0.31231884058
# finding the next rural station for Raleigh
# increasing search radius
# USC00311429 2011-01-01 2016-09-30 7.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.154076086957
# finding the next rural station for Raleigh
# USC00317656 1972-11-01 2016-10-31 7.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'WT09', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.995108695652
# Found a pair for Raleigh
# Urban start/end is: 1892-01-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1972-11-01 00:00:00 to 2016-10-31 00:00:00
# Cleveland
# finding the next urban station for Cleveland
# finding the next rural station for Cleveland
# USC00333780 1893-06-01 2016-11-30 11.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'WT10', 'DAPR', 'WT09', 'WT08', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.985960144928
# Found a pair for Cleveland
# Urban start/end is: 1938-05-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1893-06-01 00:00:00 to 2016-11-30 00:00:00
# Cincinnati
# finding the next rural station for Cincinnati
# USR0000KCRI 2003-03-01 2016-09-30 18.0 ['TAVG', 'TMAX', 'TMIN'] 0.359148550725
# finding the next rural station for Cincinnati
# increasing search radius
# USC00337120 1959-04-01 2005-12-31 6.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'WT03', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'DASF'] 0.662137681159
# finding the next rural station for Cincinnati
# USC00152776 2015-05-01 2015-12-31 6.0 ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'SNWD', 'PRCP'] 0.00869565217391
# finding the next rural station for Cincinnati
# USC00339361 1916-11-01 2016-10-31 8.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'WT09', 'WT03', 'SNWD', 'WT11', 'WT05', 'WT04', 'WT07', 'PRCP', 'WT01', 'MDPR', 'DASF', 'WT08'] 0.986865942029
# Found a pair for Cincinnati
# Urban start/end is: 1970-08-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1916-11-01 00:00:00 to 2016-10-31 00:00:00
# Nashville
# finding the next urban station for Nashville
# finding the next urban station for Nashville
# finding the next urban station for Nashville
# finding the next urban station for Nashville
# finding the next rural station for Nashville
# increasing search radius
# USC00401640 2006-06-01 2016-09-30 6.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'SNWD', 'WT05', 'WT04', 'PRCP', 'MDPR', 'WT03'] 0.293206521739
# finding the next rural station for Nashville
# USC00150020 2003-05-01 2003-10-31 7.0 ['WT11', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT05', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.0138586956522
# finding the next rural station for Nashville
# USC00400669 1997-09-01 2016-11-30 9.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.560507246377
# finding the next rural station for Nashville
# USC00406180 2005-02-01 2016-10-31 9.0 ['WT11', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT05', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.327083333333
# finding the next rural station for Nashville
# USC00401720 2004-05-01 2016-10-31 10.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.363768115942
# finding the next rural station for Nashville
# USC00402711 2001-10-01 2012-01-31 10.0 ['WT11', 'TMIN', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'SNWD', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.265851449275
# finding the next rural station for Nashville
# USC00406454 1954-06-01 2016-11-30 12.0 ['PRCP', 'TMIN', 'SNWD', 'TOBS', 'EVAP', 'MNPN', 'MXPN', 'SNOW', 'TMAX', 'DAPR', 'DAEV', 'MDEV', 'WDMV', 'DAWM', 'MDWM', 'MDPR'] 0.0
# finding the next rural station for Nashville
# USC00405118 2004-04-01 2016-11-30 12.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'WT05', 'WT04', 'PRCP', 'MDPR', 'WT03'] 0.35018115942
# finding the next rural station for Nashville
# USC00401663 1971-05-01 2016-12-31 13.0 ['TMIN', 'MNPN', 'SNWD', 'MDWM', 'DAPR', 'DAEV', 'WT05', 'WT04', 'WT06', 'WT01', 'MDPR', 'WT03', 'TOBS', 'EVAP', 'MXPN', 'MDEV', 'DAWM', 'TMAX', 'SNOW', 'WT11', 'WDMV', 'PRCP'] 0.935235507246
# Found a pair for Nashville
# Urban start/end is: 1893-01-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1971-05-01 00:00:00 to 2016-12-31 00:00:00
# Memphis
# finding the next urban station for Memphis
# finding the next urban station for Memphis
# finding the next urban station for Memphis
# finding the next urban station for Memphis
# finding the next urban station for Memphis
# finding the next urban station for Memphis
# finding the next urban station for Memphis
# finding the next rural station for Memphis
# USC00033821 1959-05-01 2016-12-31 9.0 ['TMIN', 'SX01', 'SX02', 'SNWD', 'TOBS', 'DAPR', 'DAEV', 'WT05', 'WT04', 'WT06', 'WT01', 'SN01', 'WT03', 'SX31', 'SX32', 'SN02', 'EVAP', 'MDEV', 'DAWM', 'DASF', 'TMAX', 'MDSF', 'SNOW', 'MDPR', 'WT10', 'MDWM', 'SN32', 'SN31', 'WDMV', 'PRCP'] 0.995380434783
# Found a pair for Memphis
# Urban start/end is: 1962-03-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1959-05-01 00:00:00 to 2016-12-31 00:00:00
# Norfolk
# finding the next urban station for Norfolk
# finding the next rural station for Norfolk
# USR0000VGDR 1997-12-01 2016-10-31 5.0 ['TAVG', 'TMAX', 'TMIN'] 0.558605072464
# finding the next rural station for Norfolk
# USC00440385 1953-12-01 2016-12-31 5.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'WT03', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'DASF'] 0.764583333333
# Found a pair for Norfolk
# Urban start/end is: 1945-02-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1953-12-01 00:00:00 to 2016-12-31 00:00:00
# Milwaukee
# finding the next urban station for Milwaukee
# finding the next urban station for Milwaukee
# finding the next urban station for Milwaukee
# finding the next urban station for Milwaukee
# finding the next urban station for Milwaukee
# finding the next rural station for Milwaukee
# increasing search radius
# USC00478316 1995-01-01 2016-10-31 13.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'WT11', 'SNWD', 'WT04', 'WT05', 'WESD', 'PRCP', 'WT01', 'WT03'] 0.670561594203
# finding the next rural station for Milwaukee
# USC00473661 2001-07-01 2016-11-30 15.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.464402173913
# finding the next rural station for Milwaukee
# USC00473116 2001-07-01 2016-08-31 22.0 ['TMIN', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'SNWD', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.341213768116
# finding the next rural station for Milwaukee
# No pair found for Milwaukee
# Buffalo
# finding the next urban station for Buffalo
# finding the next rural station for Buffalo
# USC00301625 2005-03-01 2016-10-31 18.0 ['WESF', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'WT11', 'SNWD', 'WT04', 'WT05', 'WESD', 'PRCP', 'WT01', 'WT06', 'WT03'] 0.338858695652
# finding the next rural station for Buffalo
# USC00308910 1949-01-01 2016-12-31 18.0 ['WT06', 'TMIN', 'WT18', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'WT11', 'DAPR', 'WT09', 'WT03', 'SNWD', 'WT04', 'WT05', 'WESD', 'WT16', 'PRCP', 'WT01', 'MDPR', 'DASF'] 0.96856884058
# Found a pair for Buffalo
# Urban start/end is: 1938-05-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1949-01-01 00:00:00 to 2016-12-31 00:00:00
# Pittsburgh
# finding the next urban station for Pittsburgh
# finding the next urban station for Pittsburgh
# finding the next urban station for Pittsburgh
# finding the next urban station for Pittsburgh
# finding the next rural station for Pittsburgh
# increasing search radius
# USC00364835 2008-02-01 2010-04-30 5.0 ['TMIN', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'WT11', 'SNWD', 'WT05', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.0332427536232
# finding the next rural station for Pittsburgh
# USC00365212 1989-07-01 2016-07-31 10.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'WT11', 'DAPR', 'SNWD', 'WT04', 'WT05', 'WESD', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.727083333333
# finding the next rural station for Pittsburgh
# USC00362942 1943-07-01 2016-12-31 11.0 ['TMIN', 'MNPN', 'SNWD', 'WT11', 'DAPR', 'DAEV', 'WT08', 'WT04', 'WT06', 'WT01', 'MDPR', 'WT03', 'TOBS', 'EVAP', 'WT09', 'MXPN', 'MDEV', 'DAWM', 'DASF', 'TMAX', 'MDSF', 'SNOW', 'MDWM', 'WT14', 'WDMV', 'WESD', 'PRCP'] 0.978079710145
# Found a pair for Pittsburgh
# Urban start/end is: 1959-05-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1943-07-01 00:00:00 to 2016-12-31 00:00:00
# Minneapolis
# finding the next urban station for Minneapolis
# finding the next urban station for Minneapolis
# finding the next urban station for Minneapolis
# finding the next urban station for Minneapolis
# finding the next urban station for Minneapolis
# finding the next rural station for Minneapolis
# USC00212738 2011-01-01 2011-02-28 21.0 ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'SNWD', 'PRCP'] 0.00298913043478
# finding the next rural station for Minneapolis
# increasing search radius
# USR0000MSHE 2002-11-01 2017-01-31 6.0 ['TAVG', 'TMAX', 'TMIN'] 0.418387681159
# finding the next rural station for Minneapolis
# USC00217502 1961-02-01 2016-12-31 7.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'WT11', 'DAPR', 'WT03', 'SNWD', 'WT04', 'WT05', 'WESD', 'PRCP', 'WT01', 'MDPR', 'DASF'] 0.971557971014
# Found a pair for Minneapolis
# Urban start/end is: 1981-10-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1961-02-01 00:00:00 to 2016-12-31 00:00:00
# Honolulu
# finding the next urban station for Honolulu
# finding the next urban station for Honolulu
# finding the next rural station for Honolulu
# USC00516222 2006-01-01 2009-03-31 13.0 ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'PRCP', 'MDPR'] 0.0890398550725
# finding the next rural station for Honolulu
# USC00519526 1951-06-01 2016-11-30 17.0 ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'PRCP', 'MDPR'] 0.0
# finding the next rural station for Honolulu
# USC00519281 2008-06-01 2016-10-31 23.0 ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'PRCP', 'MDPR'] 0.238858695652
# finding the next rural station for Honolulu
# USC00519523 1969-09-01 2016-12-31 24.0 ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'PRCP', 'MDPR', 'WT03'] 0.983061594203
# Found a pair for Honolulu
# Urban start/end is: 1965-01-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1969-09-01 00:00:00 to 2016-12-31 00:00:00
# Seattle
# finding the next urban station for Seattle
# finding the next urban station for Seattle
# finding the next rural station for Seattle
# USC00454486 1916-04-01 2016-11-30 15.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'WT09', 'WT08', 'SNWD', 'WT11', 'WT05', 'WT04', 'WT07', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.959963768116
# Found a pair for Seattle
# Urban start/end is: 1982-03-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1915-01-01 00:00:00 to 2016-11-30 00:00:00
# Phoenix
# finding the next urban station for Phoenix
# finding the next urban station for Phoenix
# finding the next urban station for Phoenix
# finding the next rural station for Phoenix
# increasing search radius
# USC00022109 1929-01-01 2016-12-31 3.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.975452898551
# Found a pair for Phoenix
# Urban start/end is: 1953-01-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1930-07-01 00:00:00 to 2016-12-31 00:00:00
# San Diego
# finding the next urban station for San Diego
# finding the next rural station for San Diego
# increasing search radius
# USC00043914 1942-09-01 2016-12-31 4.0 ['WT11', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'WT08', 'SNWD', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.9875
# Found a pair for San Diego
# Urban start/end is: 1939-07-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1942-09-01 00:00:00 to 2016-12-31 00:00:00
# St. Louis
# Found a pair for St. Louis
# Urban start/end is: 1968-08-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1974-04-01 00:00:00 to 2016-11-30 00:00:00
# New Orleans
# finding the next urban station for New Orleans
# finding the next urban station for New Orleans
# finding the next rural station for New Orleans
# USC00165624 1984-05-01 2011-01-31 13.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.658152173913
# finding the next rural station for New Orleans
# increasing search radius
# USC00163331 1998-09-01 2002-04-30 6.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'WT11', 'SNWD', 'WT04', 'PRCP', 'WT03'] 0.114039855072
# finding the next rural station for New Orleans
# USR0000MHCK 2002-12-01 2016-11-30 12.0 ['TAVG', 'TMAX', 'TMIN'] 0.416576086957
# finding the next rural station for New Orleans
# USC00163327 1956-09-01 1997-10-31 13.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.404528985507
# finding the next rural station for New Orleans
# USW00012884 1965-02-01 2016-10-31 19.0 ['TSUN', 'TMIN', 'WDFG', 'SNWD', 'PGTM', 'ACMH', 'WT09', 'ACSH', 'WT05', 'WSF1', 'WSF2', 'WT01', 'WSF5', 'WT03', 'WT02', 'WSFG', 'FMTM', 'AWND', 'WT04', 'WT07', 'TAVG', 'WT19', 'WT18', 'WT08', 'TMAX', 'SNOW', 'MDPR', 'WT13', 'WT11', 'WT16', 'WDF2', 'WDF1', 'PRCP', 'WDF5'] 0.562137681159
# finding the next rural station for New Orleans
# USC00162534 1893-01-01 2017-01-31 20.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'WT11', 'WT10', 'DAPR', 'WT16', 'WT03', 'SNWD', 'WT04', 'WT05', 'WESD', 'PRCP', 'WT01', 'MDPR', 'DASF', 'WT08'] 0.999637681159
# Found a pair for New Orleans
# Urban start/end is: 1893-01-01 00:00:00 to 2016-11-30 00:00:00
# Rural start/end is: 1893-01-01 00:00:00 to 2017-01-31 00:00:00
# Dallas
# finding the next rural station for Dallas
# increasing search radius
# USR0000TLBJ 2000-01-01 2016-09-30 8.0 ['TAVG', 'TMAX', 'TMIN'] 0.515398550725
# finding the next rural station for Dallas
# USC00414708 2002-09-01 2008-10-31 8.0 ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'WT11', 'SNWD', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.127173913043
# finding the next rural station for Dallas
# USC00410518 1965-04-01 2016-12-31 9.0 ['PRCP', 'TMIN', 'SNWD', 'TOBS', 'EVAP', 'MNPN', 'MXPN', 'SNOW', 'TMAX', 'DAPR', 'DAEV', 'MDEV', 'WDMV', 'DAWM', 'MDWM', 'MDPR'] 0.974184782609
# Found a pair for Dallas
# Urban start/end is: 1939-08-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1965-04-01 00:00:00 to 2016-12-31 00:00:00
# Boston
# finding the next rural station for Boston
# increasing search radius
# USC00192026 1970-06-01 1990-06-30 24.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.165217391304
# finding the next rural station for Boston
# No pair found for Boston
# Tampa
# finding the next rural station for Tampa
# USC00086065 1956-02-01 2016-10-31 7.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'WT16', 'SNWD', 'WT11', 'WT05', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.982518115942
# Found a pair for Tampa
# Urban start/end is: 1892-09-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1956-02-01 00:00:00 to 2016-10-31 00:00:00
# Philadelphia
# finding the next urban station for Philadelphia
# finding the next urban station for Philadelphia
# finding the next urban station for Philadelphia
# finding the next urban station for Philadelphia
# finding the next urban station for Philadelphia
# finding the next urban station for Philadelphia
# finding the next urban station for Philadelphia
# finding the next rural station for Philadelphia
# increasing search radius
# USC00280331 2011-04-01 2016-11-30 7.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT04', 'PRCP', 'WT01', 'MDPR'] 0.0893115942029
# finding the next rural station for Philadelphia
# USC00361080 1978-12-01 2016-11-30 14.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.827717391304
# Found a pair for Philadelphia
# Urban start/end is: 1915-03-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1978-12-01 00:00:00 to 2016-11-30 00:00:00
# Detroit
# finding the next urban station for Detroit
# finding the next urban station for Detroit
# finding the next rural station for Detroit
# increasing search radius
# USC00205450 1984-08-01 2006-11-30 11.0 ['WT11', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.678532608696
# finding the next rural station for Detroit
# USC00202268 1996-08-01 1999-05-31 11.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.0817028985507
# finding the next rural station for Detroit
# USC00206982 2001-11-01 2017-01-31 12.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'WT11', 'SNWD', 'WT04', 'WT05', 'WESD', 'PRCP', 'WT01', 'WT03'] 0.453442028986
# finding the next rural station for Detroit
# USC00201250 2008-07-01 2016-10-31 15.0 ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'PRCP', 'MDPR'] 0.233605072464
# finding the next rural station for Detroit
# CA006139600 1946-10-01 1986-08-31 16.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'SNWD', 'PRCP', 'MDPR'] 0.0388586956522
# finding the next rural station for Detroit
# CA006139602 1986-09-01 2001-12-31 16.0 ['TMIN', 'TMAX', 'SNOW', 'SNWD', 'PRCP', 'MDPR'] 0.494927536232
# finding the next rural station for Detroit
# USC00207103 2000-12-01 2007-08-31 18.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.214039855072
# finding the next rural station for Detroit
# No pair found for Detroit
# San Francisco
# finding the next rural station for San Francisco
# USW00023239 1945-03-01 1996-12-31 16.0 ['WT18', 'TMIN', 'SNWD', 'WT14', 'WT08', 'TMAX', 'ACMH', 'WDFG', 'SNOW', 'WSFG', 'WT16', 'ACSH', 'AWND', 'WT05', 'WT04', 'PGTM', 'PRCP', 'WT01', 'WT07', 'WT03', 'WT02'] 0.383333333333
# finding the next rural station for San Francisco
# increasing search radius
# USC00047807 1954-06-01 2007-11-30 4.0 ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'WT11', 'SNWD', 'WT05', 'WT04', 'PRCP', 'WT01', 'WT03'] 0.713858695652
# finding the next rural station for San Francisco
# USR0000CWOO 2003-05-01 2016-11-30 7.0 ['TAVG', 'TMAX', 'TMIN'] 0.295561594203
# finding the next rural station for San Francisco
# USR0000CBAR 1997-01-01 2016-11-30 7.0 ['TAVG', 'TMAX', 'TMIN'] 0.584692028986
# finding the next rural station for San Francisco
# USR0000CLAH 1990-05-01 2016-11-30 8.0 ['TAVG', 'TMAX', 'TMIN'] 0.827807971014
# finding the next rural station for San Francisco
# USR0000CTRA 1994-04-01 2016-09-30 13.0 ['TAVG', 'TMAX', 'TMIN'] 0.657155797101
# finding the next rural station for San Francisco
# No pair found for San Francisco
# Denver
# finding the next urban station for Denver
# finding the next urban station for Denver
# finding the next rural station for Denver
# increasing search radius
# USR0000CBAI 1995-03-01 2016-11-30 4.0 ['TAVG', 'TMAX', 'TMIN'] 0.607971014493
# finding the next rural station for Denver
# USR0000CCOC 2001-04-01 2016-11-30 5.0 ['TAVG', 'TMAX', 'TMIN'] 0.474365942029
# finding the next rural station for Denver
# USC00051528 1902-11-01 2017-01-31 5.0 ['TMIN', 'SNWD', 'DAPR', 'WT09', 'WT08', 'WT05', 'WT04', 'WT07', 'WT06', 'WT01', 'MDPR', 'WT03', 'TOBS', 'DASF', 'TMAX', 'MDSF', 'SNOW', 'WT11', 'WT16', 'WT14', 'WT18', 'PRCP'] 0.992119565217
# Found a pair for Denver
# Urban start/end is: 1948-01-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1902-11-01 00:00:00 to 2017-01-31 00:00:00
# Houston
# finding the next urban station for Houston
# finding the next urban station for Houston
# finding the next urban station for Houston
# finding the next urban station for Houston
# finding the next urban station for Houston
# Found a pair for Houston
# Urban start/end is: 1897-08-01 00:00:00 to 2017-01-31 00:00:00
# Rural start/end is: 1946-06-01 00:00:00 to 2016-12-31 00:00:00
# Miami
# finding the next rural station for Miami
# increasing search radius
# USC00086406 1978-06-01 2016-09-30 4.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.985507246377
# Found a pair for Miami
# Urban start/end is: 1940-10-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1978-06-01 00:00:00 to 2016-09-30 00:00:00
# Atlanta
# finding the next urban station for Atlanta
# finding the next urban station for Atlanta
# finding the next rural station for Atlanta
# increasing search radius
# USC00094688 2004-04-01 2016-11-30 5.0 ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'PRCP', 'MDPR'] 0.357065217391
# finding the next rural station for Atlanta
# USR0000GCAM 2001-11-01 2016-11-30 6.0 ['TAVG', 'TMAX', 'TMIN'] 0.429257246377
# finding the next rural station for Atlanta
# USC00094623 2001-12-01 2004-08-31 9.0 ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'PRCP', 'MDPR'] 0.0567934782609
# finding the next rural station for Atlanta
# USC00092475 1886-04-01 2000-07-31 9.0 ['WESF', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'WT11', 'DAPR', 'WT16', 'WT08', 'SNWD', 'WT04', 'WT05', 'WESD', 'PRCP', 'WT01', 'MDPR', 'WT03', 'WT06'] 0.482608695652
# finding the next rural station for Atlanta
# USC00098657 2010-12-01 2017-01-31 9.0 ['WT11', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.122010869565
# finding the next rural station for Atlanta
# USC00096340 2003-05-01 2004-10-31 18.0 ['WT11', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.0448369565217
# finding the next rural station for Atlanta
# USC00093915 1957-02-01 2001-09-30 19.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.354438405797
# finding the next rural station for Atlanta
# USC00095988 1891-11-01 2016-11-30 20.0 ['TMIN', 'WT18', 'TOBS', 'TMAX', 'SNOW', 'WT10', 'DAPR', 'WT09', 'WT08', 'SNWD', 'WT04', 'WT16', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.941032608696
# Found a pair for Atlanta
# Urban start/end is: 1891-10-01 00:00:00 to 2017-01-31 00:00:00
# Rural start/end is: 1891-11-01 00:00:00 to 2016-11-30 00:00:00
# Chicago
# finding the next urban station for Chicago
# finding the next urban station for Chicago
# finding the next urban station for Chicago
# finding the next urban station for Chicago
# finding the next urban station for Chicago
# finding the next urban station for Chicago
# finding the next urban station for Chicago
# finding the next urban station for Chicago
# finding the next urban station for Chicago
# finding the next rural station for Chicago
# increasing search radius
# USC00125174 1963-07-01 2016-12-31 15.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'WT11', 'DAPR', 'WT03', 'SNWD', 'WT04', 'WT05', 'WESD', 'PRCP', 'WT01', 'MDPR', 'DASF'] 0.998097826087
# Found a pair for Chicago
# Urban start/end is: 1981-12-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1963-07-01 00:00:00 to 2016-12-31 00:00:00
# Los Angeles
# finding the next urban station for Los Angeles
# finding the next rural station for Los Angeles
# USC00046006 1948-07-01 2016-12-31 14.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'WT03', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'DASF', 'WT08'] 0.941576086957
# Found a pair for Los Angeles
# Urban start/end is: 1906-04-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1948-07-01 00:00:00 to 2016-12-31 00:00:00
# Washington, D.C.
# finding the next rural station for Washington, D.C.
# increasing search radius
# USC00189030 1940-07-01 1996-11-30 10.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.377989130435
# finding the next rural station for Washington, D.C.
# USC00185865 1974-09-01 2016-12-31 10.0 ['WESF', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'WT11', 'DAPR', 'WT16', 'SNWD', 'WT04', 'WT05', 'WESD', 'WT18', 'PRCP', 'WT01', 'MDPR', 'WT03', 'WT06'] 0.997192028986
# Found a pair for Washington, D.C.
# Urban start/end is: 1948-08-01 00:00:00 to 2016-11-30 00:00:00
# Rural start/end is: 1974-09-01 00:00:00 to 2016-12-31 00:00:00
# New York
# finding the next rural station for New York
# increasing search radius
# USC00281582 1893-04-01 2017-01-31 25.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'WT16', 'WT03', 'SNWD', 'WT11', 'WT05', 'WT04', 'WT18', 'PRCP', 'WT01', 'MDPR', 'DASF', 'WT08'] 0.953804347826
# Found a pair for New York
# Urban start/end is: 1876-01-01 00:00:00 to 2016-08-31 00:00:00
# Rural start/end is: 1893-04-01 00:00:00 to 2017-01-31 00:00:00

# %%
city
# Out:
# 'Mesa'

# %%
i
# Out:
# 69

# %%
outFile
# Out:
# 'USpairs_stationlengths_stationavailability75_noairport.csv'

# %%
drop_cities = ['Mesa','Long Beach', 'Grand Prairie', 'Virginia Beach', 'St. Paul' ]

# %%
pairs[~np.isnan(pairs['Urban Lat'])].set_index(['City']).drop(drop_cities).to_csv(outFile)

# %%
outFile
# Out:
# 'USpairs_stationlengths_stationavailability75_noairport.csv'
