# %%
# import libraries
# %matplotlib inline
import numpy as np
#import csv
import matplotlib.pyplot as plt
import pandas as pd
import glob
import ulmo
import os
import scipy.spatial

# %%
ghcn = pd.read_fwf('data/ghcnd-stations.txt', colspecs = [(0,11), (12,19), (21,29), (31,36),(38,40), (41,70), (72,74),(76,78),(80,85)], header = None) 
colnames = ['GHCN ID', 'lat', 'lon', 'elevation', 'state', 'name', 'gsn flag', 'HCN/CRN FLAG', 'WMO ID']
ghcn.columns = colnames

# append the brightness index 
BI = np.load('data/brightnessGHCN.npy')
ghcn['Brightness'] = BI
# from http://www1.ncdc.noaa.gov/pub/data/ghcn/daily/readme.txt
# FORMAT OF "ghcnd-stations.txt"
#
# ------------------------------
# Variable   Columns   Type
# ------------------------------
# ID            1-11   Character
# LATITUDE     13-20   Real
# LONGITUDE    22-30   Real
# ELEVATION    32-37   Real
# STATE        39-40   Character
# NAME         42-71   Character
# GSN FLAG     73-75   Character
# HCN/CRN FLAG 77-79   Character
# WMO ID       81-85   Character
# ------------------------------

# These variables have the following definitions:

# ID         is the station identification code.  Note that the first two
#            characters denote the FIPS  country code, the third character 
#            is a network code that identifies the station numbering system 
#            used, and the remaining eight characters contain the actual 
#            station ID. 

#            See "ghcnd-countries.txt" for a complete list of country codes.
# 	   See "ghcnd-states.txt" for a list of state/province/territory codes.

#            The network code  has the following five values:

#            0 = unspecified (station identified by up to eight 
# 	       alphanumeric characters)
# 	   1 = Community Collaborative Rain, Hail,and Snow (CoCoRaHS)
# 	       based identification number.  To ensure consistency with
# 	       with GHCN Daily, all numbers in the original CoCoRaHS IDs
# 	       have been left-filled to make them all four digits long. 
# 	       In addition, the characters "-" and "_" have been removed 
# 	       to ensure that the IDs do not exceed 11 characters when 
# 	       preceded by "US1". For example, the CoCoRaHS ID 
# 	       "AZ-MR-156" becomes "US1AZMR0156" in GHCN-Daily
#            C = U.S. Cooperative Network identification number (last six 
#                characters of the GHCN-Daily ID)
# 	   E = Identification number used in the ECA&D non-blended
# 	       dataset
# 	   M = World Meteorological Organization ID (last five
# 	       characters of the GHCN-Daily ID)
# 	   N = Identification number used in data supplied by a 
# 	       National Meteorological or Hydrological Center
# 	   R = U.S. Interagency Remote Automatic Weather Station (RAWS)
# 	       identifier
# 	   S = U.S. Natural Resources Conservation Service SNOwpack
# 	       TELemtry (SNOTEL) station identifier
#            W = WBAN identification number (last five characters of the 
#                GHCN-Daily ID)

# LATITUDE   is latitude of the station (in decimal degrees).

# LONGITUDE  is the longitude of the station (in decimal degrees).

# ELEVATION  is the elevation of the station (in meters, missing = -999.9).


# STATE      is the U.S. postal code for the state (for U.S. stations only).

# NAME       is the name of the station.

# GSN FLAG   is a flag that indicates whether the station is part of the GCOS
#            Surface Network (GSN). The flag is assigned by cross-referencing 
#            the number in the WMOID field with the official list of GSN 
#            stations. There are two possible values:

#            Blank = non-GSN station or WMO Station number not available
#            GSN   = GSN station 

# HCN/      is a flag that indicates whether the station is part of the U.S.
# CRN FLAG  Historical Climatology Network (HCN).  There are three possible 
#           values:

#            Blank = Not a member of the U.S. Historical Climatology 
# 	           or U.S. Climate Reference Networks
#            HCN   = U.S. Historical Climatology Network station
# 	   CRN   = U.S. Climate Reference Network or U.S. Regional Climate 
# 	           Network Station

# WMO ID     is the World Meteorological Organization (WMO) number for the
#            station.  If the station has no WMO number (or one has not yet 
# 	   been matched to this station), then the field is blank.

# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
giss = pd.read_fwf('data/v3.temperature.inv.txt',skiprows = 39, header = None,
                  colspecs=[(0,3),(3,8),(8,11), (12,44),(44,49), (52,58), (58,63), (63,67), (67,68), (69,73), (73,75), (75, 77), (78,79), (79,81), (81,82),(82,84), (84,100), (100,102), (103,106)])
colnames = ['icc country code', 'WMO ID', '3 digit modifier', 'name','lat', 'lon', 'elevation', 'TELe', 'P', 'Pop', 'Tp', 'V', 'Lo', 'Co', 'Airport', 'ds', 'Vege', 'bi', 'BI']
giss.columns = colnames

# LEGEND  
# ======
# icc  =3 digit country code; the first digit represents WMO region/continent
# WMO_#=5 digit WMO station number
# ...  =3 digit modifier; 000 means the station is probably the WMO
#       station; 001, etc. mean the station is near that WMO station
# Name =30 character station name
# Lat  =latitude in degrees, negative = South of Equator
# Lon  =longitude in degrees, negative = West of Greenwich (England)
# Elev =station elevation in meters, missing is -999
# TEle =station elevation interpolated from TerrainBase gridded data set
# P    =R if rural (not associated with a town of >10,000 population)
#       S if associated with a small town (10,000-50,000 population)
#       U if associated with an urban area (>50,000 population)
# Pop  =population of the small town or urban area in 1000s
#       If rural, no analysis:  -9.
# Tp   =general topography around the station:  FL flat; HI hilly,
#       MT mountain top; MV mountainous valley or at least not on the top
#       of a mountain.
# V    =general vegetation near the station based on Operational
#       Navigation Charts;  MA marsh; FO forested; IC ice; DE desert;
#       CL clear or open;  xx information not provided
# Lo   =CO if station is within 30 km from the coast
#       LA if station is next to a large (> 25 km**2) lake
#       no if neither of the above
#       Note: Stations which are both CO and LA will be marked CO
# Co   =distance in km to the coast if Lo=CO, else -9
# A    =A if the station is at an airport; else x
# ds   =distance in km from the airport to its associated
#       small town or urban center (not relevant for rural airports
#       or non airport stations in which case ds=-9)
# Vege =gridded vegetation for the 0.5x0.5 degree grid point closest
#       to the station from a gridded vegetation data base. 16 characters.
# bi   =brightness index    A=dark B=dim C=bright   (comment added by R.Ruedy)
# BI   =brightness index    0=dark -> 256 =bright   (based on satellite night light data)

# %% [markdown]
# see: http://stackoverflow.com/questions/35296935/python-calculate-lots-of-distances-quickly

# %%
# subset the GHCN station list with the list of available stations
currentstations = ulmo.ncdc.ghcn_daily.get_stations(start_year=1985, end_year = 2016, elements = ['TMIN', 'TMAX', 'AWND'], as_dataframe=True, update=False)
currentGHCNstations = np.intersect1d(currentstations.id, ghcn.index.values) #ghcn['GHCN ID'].values)
ghcnSubset = ghcn.set_index('GHCN ID').loc[currentstations.id.values]
# at this point, ghcn must have the station id set as the index
# Out:
# /Users/annascott2/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike

# %%
#ghcn = ghcn[ghcn.index.str.contains('US')] # subset to US stations

# %%
ghcn_noairport = ghcn[~ghcn.name.str.contains('INTL')]
ghcn_noairport = ghcn_noairport[~ghcn_noairport.name.str.contains(' AP')]
ghcn_noairport = ghcn_noairport[~ghcn_noairport.name.str.contains('AIRPORT')]

# %%
ghcn = ghcn_noairport.set_index('GHCN ID').loc[currentstations.id.values]
ghcn.head()
# Out:
# /Users/annascott2/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   if __name__ == '__main__':
#                 lat     lon  elevation state                 name gsn flag  \
# GHCN ID
# AE000041196  25.333  55.517       34.0   NaN  SHARJAH INTER. AIRP       GS
# AEM00041194     NaN     NaN        NaN   NaN                  NaN      NaN
# AEM00041217     NaN     NaN        NaN   NaN                  NaN      NaN
# AEM00041218     NaN     NaN        NaN   NaN                  NaN      NaN
# AF000040930  35.317  69.017     3366.0   NaN         NORTH-SALANG       GS
#
#             HCN/CRN FLAG   WMO ID  Brightness
# GHCN ID
# AE000041196          NaN  41196.0        63.0
# AEM00041194          NaN      NaN         NaN
# AEM00041217          NaN      NaN         NaN
# AEM00041218          NaN      NaN         NaN
# AF000040930          NaN  40930.0         4.0

# %%
# compute distances between all stations
#tree = scipy.spatial.cKDTree(giss[['lon', 'lat']].values, leafsize=100)
# query the closest point 
#closestInd = tree.query(giss[['lon', 'lat']].values[11,:], k =2, distance_upper_bound=6)[1][1]

# %%
atlas = pd.read_csv('data/sampleAtlas.csv') # derived  from http://www.naturalearthdata.com/downloads/10m-cultural-vectors/10m-populated-places/
atlas = pd.read_csv('data/world_cities.csv')
tree = scipy.spatial.cKDTree(ghcn[['lon', 'lat']].values, leafsize=100)
#import sys
#sys.path.append('/../cityheat/Bmore/2015/')
#sys.path.append('/Users/annascott2/mountpoint/cityheat/Bmore/2015/')
#import spatialfunctions
atlas = atlas[atlas['country'].str.contains('United States')] # do non-US countries
atlas = atlas[atlas['pop']> 500000]
atlas.shape
# Out:
# (70, 9)

# %%
pd.read_csv('data/world_cities.csv')

# %%
70-54
# Out:
# 16

# %%
#atlas = pd.read_csv('data/world_cities.csv')

# %%
atlas.shape
# Out:
# (70, 9)

# %%
#atlas = atlas[atlas['country'].str.contains('United States')].set_index('city')

# %%
brightness_threshold = 25 # this is the urban/rural threshold delimiter, difference between urban and rural
#outFile = 'worldghcnpairs_stationlengths.csv'
outFile = 'USpairs2005-2015.csv'
pairs = []
frames = []
startdate = np.datetime64('2005-06-01')
enddate = np.datetime64('2015-08-30')

# %%
atlas
# Out:
#                   city        city_ascii        lat         lng         pop  \
# 6321              Mesa              Mesa  33.423915 -111.736084    762217.5
# 6393         Arlington     Grand Prairie  32.684761  -97.020238    545107.5
# 6571            Irvine            Irvine  33.680411 -117.829950   1611303.5
# 6689         New Haven         New Haven  41.330383  -72.900005    707883.0
# 6707   Fort Lauderdale   Fort Lauderdale  26.136065  -80.141786   1103781.5
# 6847        Long Beach        Long Beach  33.786967 -118.158044   1249195.5
# 6870          Hartford          Hartford  41.770020  -72.679967    518509.5
# 6871        Providence        Providence  41.821102  -71.414980    663726.5
# 6872        Birmingham        Birmingham  33.530006  -86.824995    670142.0
# 6875    St. Petersburg    St. Petersburg  27.770539  -82.679383    523314.5
# 6881    Virginia Beach    Virginia Beach  36.853214  -75.978319    877475.5
# 6899           Oakland           Oakland  37.768921 -122.221103    953044.0
# %%
#for i in range(793, atlas.shape[0]): 

data_availability_thresh = .75
for i in range(1, atlas.shape[0]): #range(31,32): # for baltimore
    lat = atlas.iloc[i]['lat']
    lon = atlas.iloc[i]['lng']
    city = atlas.iloc[i]['city_ascii']
    print(city)
    closeststations = tree.query([lon,lat], k =15, distance_upper_bound=1)

    # Make sure the closest stations are within a finite distance
    closestInds = closeststations[1][~np.isinf(closeststations[0])]
    # make sure that there are stations 
    if closestInds.shape[0] > 0 : 
        urban = ghcn.Brightness[closestInds].argmax()
        rural = ghcn.Brightness[closestInds].argmin()
        #         if urban != rural: 
        urban_data = ulmo.ncdc.ghcn_daily.get_data(urban, as_dataframe=True, update=False)
        rural_data = ulmo.ncdc.ghcn_daily.get_data(rural, as_dataframe=True, update=False)

        number_urban_stations = (ghcn.Brightness[closestInds] >= brightness_threshold).sum() # number of urban stations is equivalent to brightness over 30
        number_rural_stations = (ghcn.Brightness[closestInds] < brightness_threshold).sum() # number of rural stations is equivalent to brightness over 30
        delta_brightness = 30
        break_value = -1

        iii = 1
#        while ('TMAX' not in urban_data.keys() or 'TMIN' not in urban_data.keys()) or (urban_data['TMAX'].index[0].to_timestamp().to_datetime() > startdate) or (urban_data['TMAX'].index[-1].to_timestamp().to_datetime() < enddate) : 
        while ('TMAX' not in urban_data.keys()) or ('TMIN' not in urban_data.keys()) or (urban_data['TMAX'].index[0].to_timestamp() > startdate) or (urban_data['TMAX'].index[-1].to_timestamp() < enddate) or ((~np.isnan(urban_data['TMIN'].set_index(urban_data['TMIN'].index.to_timestamp())[startdate:enddate].value.values.astype(float))).sum()/(enddate-startdate).astype(float) < data_availability_thresh) :  
        # check if there's enough suitable urban stations to check the next one, ignoring the current one 
            if iii > number_urban_stations-1 : 
                print('no suitable urban station for %s'%city) 
                urban = break_value
                break 
            # find the next brightestcity
            print 'finding the next urban station for %s'%city
            urban = ghcn.Brightness[closestInds][(-ghcn.Brightness[closestInds].values).argsort()].index[iii]
            urban_data = ulmo.ncdc.ghcn_daily.get_data(urban, as_dataframe=True, update=False)
            iii = iii+1    

        # if no urban station found, don't bother to pair with rural 
        if urban != break_value : 
            # check rural data station different from urban has TMIN, TMAX, a long enough record, and is rural enough compared to urban (delta_brightness)
            iii = 1
            enlarge_circle = 0 # number of times we can try increasing search radius
            while (urban ==rural) or ('TMAX' not in rural_data.keys() and 'TMIN' not in rural_data.keys()) or (rural_data['TMIN'].index[0].to_timestamp() > startdate) or (rural_data['TMIN'].index[-1].to_timestamp() < enddate) or (ghcn.Brightness[urban]-ghcn.Brightness[rural]<delta_brightness) or ((~np.isnan(rural_data['TMIN'].set_index(rural_data['TMIN'].index.to_timestamp())[startdate:enddate].value.values.astype(float))).sum()/((enddate-startdate).astype(float)) < data_availability_thresh): 
                print 'finding the next rural station for %s'%city

                # if we can't find any suitable stations, try enlarging the search radius, but only try this once
                if iii > number_rural_stations-1 : 
                    if enlarge_circle > 0 : 
                        rural = break_value
                        break #break when we've already used up all the search
                    else: 
                        # find 25 closest stations within 1.5 degree circle
                        closeststations1 = tree.query([lon,lat], k =35, distance_upper_bound=1.5 ) 
                        # eliminate the ones we've already search 
                        new_stations = np.setdiff1d(closeststations1[1], closeststations[1])
                        # Make sure that we've actually found new stations, otherwise break
                        if new_stations.shape[0] >0 : 
                            # Make sure the closest stations are within a finite distance
                            closestInds1 = closeststations1[1][~np.isinf(closeststations1[0])]
                            # Eliminate repeat stations
                            closestInds = np.intersect1d(new_stations, closestInds1)
                            # reset counter, number of rural stations
                            iii = 0
                            number_rural_stations = (ghcn.Brightness[closestInds] < brightness_threshold).sum()
                        else: 
                            rural = break_value
                            break
                        # reset list of rural stations
                    print 'increasing search radius'
                    enlarge_circle = enlarge_circle+1
                    
                # find the next dimmest
                rural = ghcn.Brightness[closestInds][(ghcn.Brightness[closestInds].values).argsort()].index[iii]
                rural_data = ulmo.ncdc.ghcn_daily.get_data(rural, as_dataframe=True, update=False)
                print rural, rural_data['TMIN'].index[0], rural_data['TMIN'].index[-1], ghcn.Brightness[rural], rural_data.keys(), (~np.isnan(rural_data['TMIN'].set_index(rural_data['TMIN'].index.to_timestamp())[startdate:enddate].value.values.astype(float))).sum()/(enddate-startdate).astype(float)
                iii = iii+1
        else: 
            rural = break_value
    # else condition for not being any stations
    else: 
        urban = break_value 
        rural = break_value
            
    # save out if we've found a good pairing
    if (urban != break_value) and (rural != break_value) : 
        print('Found a pair for %s'%city)
        print('Urban start/end is: %s to %s'%(urban_data['TMAX'].index[0].to_timestamp().to_datetime(),  urban_data['TMAX'].index[-1].to_timestamp().to_datetime()))
        print('Rural start/end is: %s to %s'%(rural_data['TMAX'].index[0].to_timestamp().to_datetime(),  rural_data['TMAX'].index[-1].to_timestamp().to_datetime()))
        frames.append([city, urban, #['GHCN ID'],
                       ghcn.loc[urban].lat, 
                       ghcn.loc[urban].lon, 
                       ghcn.loc[urban].Brightness,
                       urban_data['TMAX'].index[0].to_timestamp().to_datetime(), urban_data['TMAX'].index[-1].to_timestamp().to_datetime(), 
                       rural, #['GHCN ID'],
                       ghcn.loc[rural].lat, 
                       ghcn.loc[rural].lon, 
                       ghcn.loc[rural].Brightness, 
                        rural_data['TMAX'].index[0].to_timestamp().to_datetime(), rural_data['TMAX'].index[-1].to_timestamp().to_datetime(),])
    else : 
        print 'No pair found for %s'%city
        frames.append([city, np.nan, #['GHCN ID'],
                       np.nan,
                       np.nan,
                       np.nan, 
                       np.nan, #['GHCN ID'],
                       np.nan,
                       np.nan,
                       np.nan, np.nan, np.nan, np.nan, np.nan])

    # periodiically save out results
    if i%50 ==0: 
        pairs = pd.DataFrame(frames, columns = ['City', 'Urban station', 
                                          'Urban Lat', 'Urban Lon','Urban brightness', 'Urban start', 'Urban end',
                                          'Rural station', 
                                          'Rural Lat', 'Rural Lon','Rural brightness', 'Rural start', 'Rural end'])

        pairs.to_csv(outFile)
        
# pairs = pd.DataFrame(frames, columns = ['City', 'Urban station', 
#                                   'Urban Lat', 'Urban Lon','Urban brightness', 
#                                   'Rural station', 
#                                   'Rural Lat', 'Rural Lon','Rural brightness'])

pairs = pd.DataFrame(frames, columns = ['City', 'Urban station', 
                                          'Urban Lat', 'Urban Lon','Urban brightness', 'Urban start', 'Urban end',
                                          'Rural station', 
                                          'Rural Lat', 'Rural Lon','Rural brightness', 'Rural start', 'Rural end'])

pairs.to_csv(outFile)
pairs[(~np.isnan(pairs['Urban Lat']))].to_csv(outFile)
# Out:
# Grand Prairie
# finding the next rural station for Grand Prairie
# increasing search radius
# USR0000TLBJ 2000-01-01 2016-09-30 8.0 ['TAVG', 'TMAX', 'TMIN'] 1.00026723677
# Found a pair for Grand Prairie
# Urban start/end is: 1893-01-01 00:00:00 to 2016-09-30 00:00:00
# Rural start/end is: 2000-01-01 00:00:00 to 2016-09-30 00:00:00
# Irvine
# finding the next urban station for Irvine
# finding the next rural station for Irvine
# USR0000CFRE 1991-07-01 2016-11-30 18.0 ['TAVG', 'TMAX', 'TMIN'] 1.00026723677
# Found a pair for Irvine
# Urban start/end is: 1916-05-01 00:00:00 to 2016-11-30 00:00:00
# Rural start/end is: 1991-07-01 00:00:00 to 2016-11-30 00:00:00
# New Haven
# finding the next urban station for New Haven
# finding the next urban station for New Haven
# finding the next urban station for New Haven
# finding the next urban station for New Haven
# finding the next urban station for New Haven
# finding the next urban station for New Haven
# finding the next urban station for New Haven
# finding the next urban station for New Haven
# finding the next rural station for New Haven
# USC00061488 1961-09-01 1999-09-30 13.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'WT03', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'DASF'] 0.0
# finding the next rural station for New Haven
# USC00069568 1949-06-01 1997-01-31 20.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'WT03', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'DASF', 'WT08'] 0.0
# finding the next rural station for New Haven
# increasing search radius
# USC00061508 2011-01-01 2016-05-31 7.0 ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WESD', 'PRCP', 'MDPR'] 0.157135221807
# finding the next rural station for New Haven
# USC00065445 1884-11-01 2016-12-31 7.0 ['TMIN', 'MNPN', 'SNWD', 'WT11', 'DAPR', 'DAEV', 'WT08', 'WT05', 'WT04', 'WT06', 'WT01', 'MDPR', 'WT03', 'TOBS', 'EVAP', 'WT09', 'MXPN', 'MDEV', 'DAWM', 'TMAX', 'SNOW', 'MDWM', 'WT16', 'WT14', 'WDMV', 'WESD', 'WT18', 'PRCP'] 1.00026723677
# Found a pair for New Haven
# Urban start/end is: 1938-03-01 00:00:00 to 2016-09-30 00:00:00
# Rural start/end is: 1884-11-01 00:00:00 to 2016-12-31 00:00:00
# Fort Lauderdale
# finding the next rural station for Fort Lauderdale
# increasing search radius
# USR0000FTEN 1992-03-01 2012-04-30 4.0 ['TAVG', 'TMAX', 'TMIN'] 0.655531801176
# finding the next rural station for Fort Lauderdale
# USR0000FCAC 1999-12-01 2016-11-30 4.0 ['TAVG', 'TMAX', 'TMIN'] 0.941207910208
# Found a pair for Fort Lauderdale
# Urban start/end is: 1952-04-01 00:00:00 to 2016-09-30 00:00:00
# Rural start/end is: 1999-12-01 00:00:00 to 2016-11-30 00:00:00
# Long Beach
# finding the next rural station for Long Beach
# increasing search radius
# USR0000CCHI 1986-02-01 2016-11-30 6.0 ['TAVG', 'TMAX', 'TMIN'] 0.993051843934
# Found a pair for Long Beach
# Urban start/end is: 1949-01-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1986-02-01 00:00:00 to 2016-11-30 00:00:00
# Hartford
# finding the next rural station for Hartford
# USC00193167 1986-05-01 1990-08-31 8.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'WT11', 'SNWD', 'WT05', 'WT04', 'PRCP', 'WT01', 'WT03'] 0.0
# finding the next rural station for Hartford
# USC00060299 2005-11-01 2016-10-31 10.0 ['WT11', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'WT16', 'SNWD', 'WT04', 'WESD', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.477284874399
# finding the next rural station for Hartford
# USC00061488 1961-09-01 1999-09-30 13.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'WT03', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'DASF'] 0.0
# finding the next rural station for Hartford
# USC00060227 1990-08-01 2016-10-31 15.0 ['WESF', 'TMIN', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'WT11', 'DAPR', 'SNWD', 'WT04', 'WT05', 'WESD', 'PRCP', 'WT01', 'MDPR', 'WT03', 'WT06'] 0.996258685195
# Found a pair for Hartford
# Urban start/end is: 1920-01-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1990-08-01 00:00:00 to 2016-10-31 00:00:00
# Providence
# finding the next urban station for Providence
# Found a pair for Providence
# Urban start/end is: 1967-11-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1974-10-01 00:00:00 to 2016-10-31 00:00:00
# Birmingham
# finding the next urban station for Birmingham
# finding the next rural station for Birmingham
# USC00010505 1957-02-01 2016-12-31 7.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.995189738108
# Found a pair for Birmingham
# Urban start/end is: 2003-12-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1957-02-01 00:00:00 to 2016-12-31 00:00:00
# St. Petersburg
# Found a pair for St. Petersburg
# Urban start/end is: 1892-09-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 2001-08-01 00:00:00 to 2016-09-30 00:00:00
# Virginia Beach
# Found a pair for Virginia Beach
# Urban start/end is: 1945-03-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1953-12-01 00:00:00 to 2016-12-31 00:00:00
# Oakland
# Found a pair for Oakland
# Urban start/end is: 1970-10-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1994-04-01 00:00:00 to 2016-09-30 00:00:00
# West Palm Beach
# Found a pair for West Palm Beach
# Urban start/end is: 2002-11-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 2002-11-01 00:00:00 to 2016-09-30 00:00:00
# Louisville
# finding the next urban station for Louisville
# finding the next rural station for Louisville
# USC00124977 2002-06-01 2012-11-30 7.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'MDPR', 'WT03'] 0.724746125067
# finding the next rural station for Louisville
# USC00121425 1962-06-01 2001-06-30 8.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'WT03', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'DASF'] 0.0
# finding the next rural station for Louisville
# USC00150630 1970-03-01 2016-12-31 11.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.67717797969
# finding the next rural station for Louisville
# USC00150955 1999-10-01 2016-10-31 12.0 ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'SNWD', 'PRCP', 'WT01', 'WT03'] 0.993051843934
# Found a pair for Louisville
# Urban start/end is: 2000-09-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1999-10-01 00:00:00 to 2016-10-31 00:00:00
# Charlotte
# finding the next rural station for Charlotte
# USC00389625 2005-04-01 2016-09-30 10.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.992784607162
# Found a pair for Charlotte
# Urban start/end is: 1890-01-01 00:00:00 to 2016-09-30 00:00:00
# Rural start/end is: 2005-04-01 00:00:00 to 2016-09-30 00:00:00
# Columbus
# finding the next urban station for Columbus
# finding the next urban station for Columbus
# finding the next rural station for Columbus
# USC00332090 1970-07-01 1987-06-30 8.0 ['TMIN', 'MNPN', 'SX01', 'SX03', 'SX02', 'SNWD', 'DAPR', 'DAEV', 'WT01', 'SN01', 'WT03', 'TOBS', 'SN03', 'SN02', 'EVAP', 'MXPN', 'MDEV', 'DAWM', 'TMAX', 'SNOW', 'MDPR', 'MDWM', 'WDMV', 'PRCP'] 0.0
# finding the next rural station for Columbus
# USC00331404 1950-12-01 2016-12-31 10.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'WT09', 'WT08', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.968198824158
# Found a pair for Columbus
# Urban start/end is: 1952-05-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1950-12-01 00:00:00 to 2016-12-31 00:00:00
# San Bernardino
# finding the next urban station for San Bernardino
# Found a pair for San Bernardino
# Urban start/end is: 1893-01-01 00:00:00 to 2016-11-30 00:00:00
# Rural start/end is: 2001-12-01 00:00:00 to 2016-11-30 00:00:00
# Bridgeport
# finding the next urban station for Bridgeport
# finding the next urban station for Bridgeport
# finding the next urban station for Bridgeport
# finding the next urban station for Bridgeport
# finding the next rural station for Bridgeport
# increasing search radius
# USC00060961 1957-05-01 1999-11-30 9.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.0
# finding the next rural station for Bridgeport
# USC00067373 1949-03-01 2003-01-31 10.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'WT03', 'SNWD', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'DASF'] 0.0
# finding the next rural station for Bridgeport
# USC00308304 1990-08-01 2007-07-31 18.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'WT11', 'SNWD', 'WT05', 'WT04', 'PRCP', 'WT01', 'WT03'] 0.211384286478
# finding the next rural station for Bridgeport
# USC00069568 1949-06-01 1997-01-31 20.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'WT03', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'DASF', 'WT08'] 0.0
# finding the next rural station for Bridgeport
# No pair found for Bridgeport
# St. Paul
# finding the next urban station for St. Paul
# finding the next urban station for St. Paul
# Found a pair for St. Paul
# Urban start/end is: 1993-09-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 2003-05-01 00:00:00 to 2016-11-30 00:00:00
# Tucson
# finding the next urban station for Tucson
# finding the next urban station for Tucson
# finding the next urban station for Tucson
# finding the next urban station for Tucson
# finding the next urban station for Tucson
# finding the next rural station for Tucson
# USR0000ASOL 1999-04-01 2016-10-31 4.0 ['TAVG', 'TMAX', 'TMIN'] 0.990112239444
# Found a pair for Tucson
# Urban start/end is: 1995-06-01 00:00:00 to 2016-08-31 00:00:00
# Rural start/end is: 1999-04-01 00:00:00 to 2016-10-31 00:00:00
# Fresno
# Found a pair for Fresno
# Urban start/end is: 1999-01-01 00:00:00 to 2016-06-30 00:00:00
# Rural start/end is: 1990-05-01 00:00:00 to 2016-09-30 00:00:00
# Albuquerque
# finding the next rural station for Albuquerque
# USC00298015 1939-01-01 2009-02-28 4.0 ['TMIN', 'SNWD', 'DAPR', 'WT09', 'WT08', 'WT05', 'WT04', 'WT07', 'WT06', 'WT01', 'MDPR', 'WT03', 'TOBS', 'DASF', 'TMAX', 'MDSF', 'SNOW', 'WT10', 'WT11', 'WT16', 'WT14', 'WT18', 'PRCP'] 0.192944949225
# finding the next rural station for Albuquerque
# USC00294366 1953-09-01 2016-10-31 5.0 ['PRCP', 'TMIN', 'SNWD', 'TOBS', 'EVAP', 'MNPN', 'MDSF', 'MXPN', 'SNOW', 'TMAX', 'DAPR', 'DAEV', 'MDEV', 'WT11', 'WDMV', 'DAWM', 'MDWM', 'MDPR', 'DASF'] 0.815873864244
# Found a pair for Albuquerque
# Urban start/end is: 1994-04-01 00:00:00 to 2016-05-31 00:00:00
# Rural start/end is: 1953-09-01 00:00:00 to 2016-10-31 00:00:00
# Kansas City
# finding the next urban station for Kansas City
# finding the next urban station for Kansas City
# finding the next rural station for Kansas City
# USC00232474 1919-11-01 1987-11-30 14.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'WT10', 'DAPR', 'WT09', 'WT03', 'SNWD', 'WT11', 'WT05', 'WT04', 'WT07', 'PRCP', 'WT01', 'MDPR', 'DASF', 'WT08'] 0.0
# finding the next rural station for Kansas City
# increasing search radius
# USC00144488 1991-11-01 1994-12-31 5.0 ['TMIN', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'WT16', 'SNWD', 'WT05', 'WT04', 'WT18', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.0
# finding the next rural station for Kansas City
# USC00146100 1958-12-01 2011-01-31 6.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.518172100481
# finding the next rural station for Kansas City
# USC00146333 1967-06-01 2017-03-31 7.0 ['PRCP', 'TMIN', 'SNWD', 'TOBS', 'EVAP', 'MNPN', 'MDSF', 'MXPN', 'SNOW', 'TMAX', 'DAPR', 'DAEV', 'MDEV', 'WT04', 'WDMV', 'DAWM', 'MDWM', 'MDPR', 'DASF', 'WT06'] 0.945750935329
# Found a pair for Kansas City
# Urban start/end is: 1990-01-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1967-06-01 00:00:00 to 2017-03-31 00:00:00
# Tulsa
# finding the next urban station for Tulsa
# finding the next urban station for Tulsa
# finding the next urban station for Tulsa
# finding the next urban station for Tulsa
# finding the next rural station for Tulsa
# USC00341902 1984-05-01 2000-10-31 7.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.0
# finding the next rural station for Tulsa
# USC00344098 1949-04-01 1951-04-30 8.0 ['PRCP', 'TMIN', 'SNWD', 'TOBS', 'WT14', 'EVAP', 'SNOW', 'WT11', 'TMAX', 'DAPR', 'DAEV', 'WT08', 'MDEV', 'WT04', 'WDMV', 'DAWM', 'MDWM', 'WT01', 'MDPR', 'WT03'] 0.0
# finding the next rural station for Tulsa
# USC00346670 1910-01-01 2011-10-31 8.0 ['WT18', 'WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'WT16', 'WT03', 'SNWD', 'WT11', 'WT05', 'WT04', 'WT07', 'PRCP', 'WT01', 'MDPR', 'DASF'] 0.173971138429
# finding the next rural station for Tulsa
# USC00344289 1948-03-01 2007-06-30 12.0 ['WT18', 'WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'WT09', 'WT08', 'SNWD', 'WT11', 'WT05', 'WT04', 'WT16', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.0138963121325
# finding the next rural station for Tulsa
# USC00344812 1957-08-01 2016-10-31 16.0 ['PRCP', 'TMIN', 'SNWD', 'TOBS', 'EVAP', 'MNPN', 'MDSF', 'MXPN', 'SNOW', 'TMAX', 'DAPR', 'DAEV', 'MDEV', 'WDMV', 'DAWM', 'MDWM', 'MDPR', 'DASF'] 0.973276322822
# Found a pair for Tulsa
# Urban start/end is: 1900-04-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1957-08-01 00:00:00 to 2016-10-31 00:00:00
# Ft. Worth
# finding the next urban station for Ft. Worth
# Found a pair for Ft. Worth
# Urban start/end is: 1946-09-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 2003-01-01 00:00:00 to 2016-09-30 00:00:00
# Austin
# Found a pair for Austin
# Urban start/end is: 2004-02-01 00:00:00 to 2016-06-30 00:00:00
# Rural start/end is: 2000-05-01 00:00:00 to 2016-09-30 00:00:00
# El Paso
# finding the next urban station for El Paso
# finding the next urban station for El Paso
# finding the next urban station for El Paso
# finding the next rural station for El Paso
# USC00294426 1914-06-01 2016-12-31 3.0 ['TMIN', 'SNWD', 'WT11', 'DAPR', 'DAEV', 'WT08', 'WT05', 'WT04', 'WT07', 'WT01', 'MDPR', 'WT03', 'TOBS', 'EVAP', 'MDEV', 'DAWM', 'DASF', 'TMAX', 'MDSF', 'SNOW', 'MDWM', 'WT16', 'WDMV', 'WT18', 'PRCP'] 0.888562266168
# Found a pair for El Paso
# Urban start/end is: 1959-04-01 00:00:00 to 2016-08-31 00:00:00
# Rural start/end is: 1914-06-01 00:00:00 to 2016-12-31 00:00:00
# Orlando
# finding the next urban station for Orlando
# finding the next urban station for Orlando
# finding the next rural station for Orlando
# USR0000FCEN 2003-02-01 2016-11-30 6.0 ['TAVG', 'TMAX', 'TMIN'] 0.888027792624
# Found a pair for Orlando
# Urban start/end is: 1892-01-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 2003-02-01 00:00:00 to 2016-11-30 00:00:00
# Jacksonville
# Found a pair for Jacksonville
# Urban start/end is: 1944-07-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 2004-12-01 00:00:00 to 2016-09-30 00:00:00
# Indianapolis
# finding the next urban station for Indianapolis
# finding the next urban station for Indianapolis
# finding the next rural station for Indianapolis
# increasing search radius
# USR0000IHAR 2002-07-01 2016-11-30 5.0 ['TAVG', 'TMAX', 'TMIN'] 0.998129342598
# Found a pair for Indianapolis
# Urban start/end is: 1948-01-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 2002-07-01 00:00:00 to 2016-11-30 00:00:00
# Richmond
# Found a pair for Richmond
# Urban start/end is: 1980-06-01 00:00:00 to 2016-09-30 00:00:00
# Rural start/end is: 1959-01-01 00:00:00 to 2016-11-30 00:00:00
# Baltimore
# finding the next urban station for Baltimore
# finding the next rural station for Baltimore
# increasing search radius
# USC00189030 1940-07-01 1996-11-30 10.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.0
# finding the next rural station for Baltimore
# USC00185934 1988-03-01 2016-08-31 13.0 ['WT06', 'TMIN', 'SNWD', 'SX32', 'TOBS', 'TMAX', 'WDFG', 'SNOW', 'WSFG', 'WT11', 'SN32', 'AWND', 'WT04', 'WT05', 'WESD', 'PRCP', 'WT01', 'WT03'] 0.999732763228
# Found a pair for Baltimore
# Urban start/end is: 1998-05-01 00:00:00 to 2017-02-28 00:00:00
# Rural start/end is: 1988-03-01 00:00:00 to 2016-08-31 00:00:00
# San Jose
# finding the next urban station for San Jose
# Found a pair for San Jose
# Urban start/end is: 1998-07-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1948-07-01 00:00:00 to 2016-12-31 00:00:00
# Sacramento
# Found a pair for Sacramento
# Urban start/end is: 1877-07-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1990-05-01 00:00:00 to 2016-09-30 00:00:00
# Las Vegas
# finding the next rural station for Las Vegas
# USC00262243 1940-04-01 2016-12-31 5.0 ['WT18', 'WT11', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'WT16', 'DAPR', 'WT09', 'WT03', 'SNWD', 'WT05', 'WT04', 'WT07', 'PRCP', 'WT01', 'MDPR', 'DASF', 'WT08'] 0.961785141635
# Found a pair for Las Vegas
# Urban start/end is: 2000-10-01 00:00:00 to 2016-06-30 00:00:00
# Rural start/end is: 1940-04-01 00:00:00 to 2016-12-31 00:00:00
# Portland
# finding the next rural station for Portland
# USR0000OEAG 2002-02-01 2016-10-31 12.0 ['TAVG', 'TMAX', 'TMIN'] 0.991982896847
# Found a pair for Portland
# Urban start/end is: 1996-04-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 2002-02-01 00:00:00 to 2016-10-31 00:00:00
# Salt Lake City
# finding the next urban station for Salt Lake City
# finding the next urban station for Salt Lake City
# finding the next urban station for Salt Lake City
# finding the next urban station for Salt Lake City
# finding the next urban station for Salt Lake City
# finding the next urban station for Salt Lake City
# Found a pair for Salt Lake City
# Urban start/end is: 1941-09-01 00:00:00 to 2016-09-30 00:00:00
# Rural start/end is: 1993-10-01 00:00:00 to 2016-10-31 00:00:00
# Omaha
# Found a pair for Omaha
# Urban start/end is: 1948-01-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1968-10-01 00:00:00 to 2016-12-31 00:00:00
# Oklahoma City
# finding the next urban station for Oklahoma City
# finding the next rural station for Oklahoma City
# USC00349346 2009-02-01 2016-10-31 6.0 ['TMIN', 'TOBS', 'SX32', 'TMAX', 'SNOW', 'DAPR', 'SN32', 'SNWD', 'PRCP', 'MDPR'] 0.641635489043
# finding the next rural station for Oklahoma City
# USC00345779 1894-01-01 2016-12-31 7.0 ['TMIN', 'SNWD', 'DAPR', 'WT09', 'WT08', 'WT05', 'WT04', 'WT07', 'WT06', 'WT01', 'MDPR', 'WT03', 'TOBS', 'DASF', 'TMAX', 'MDSF', 'SNOW', 'WT10', 'WT11', 'WT16', 'WT14', 'WT18', 'PRCP'] 0.978888295029
# Found a pair for Oklahoma City
# Urban start/end is: 1894-11-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1894-01-01 00:00:00 to 2016-12-31 00:00:00
# San Antonio
# finding the next urban station for San Antonio
# finding the next rural station for San Antonio
# USW00012971 1996-07-01 2016-10-31 10.0 ['TSUN', 'TMIN', 'SNWD', 'PGTM', 'WV03', 'WT09', 'WT08', 'WT05', 'WT04', 'WT07', 'WT06', 'WT01', 'WSF5', 'WT03', 'WT02', 'WT22', 'FMTM', 'AWND', 'WSF2', 'TAVG', 'WT19', 'TMAX', 'SNOW', 'WT13', 'WT11', 'WT16', 'WT17', 'WT14', 'WDF2', 'WT18', 'PRCP', 'WDF5'] 1.00026723677
# Found a pair for San Antonio
# Urban start/end is: 1893-01-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1996-07-01 00:00:00 to 2016-10-31 00:00:00
# Raleigh
# finding the next rural station for Raleigh
# USC00316122 2003-04-01 2016-10-31 14.0 ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'PRCP', 'MDPR'] 0.786477819348
# Found a pair for Raleigh
# Urban start/end is: 1892-01-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 2003-04-01 00:00:00 to 2016-10-31 00:00:00
# Cleveland
# finding the next urban station for Cleveland
# finding the next rural station for Cleveland
# USC00333780 1893-06-01 2016-11-30 11.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'WT10', 'DAPR', 'WT09', 'WT08', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.999732763228
# Found a pair for Cleveland
# Urban start/end is: 1938-05-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1893-06-01 00:00:00 to 2016-11-30 00:00:00
# Cincinnati
# finding the next rural station for Cincinnati
# USR0000KCRI 2003-03-01 2016-09-30 18.0 ['TAVG', 'TMAX', 'TMIN'] 0.861571352218
# Found a pair for Cincinnati
# Urban start/end is: 1970-08-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 2003-03-01 00:00:00 to 2016-09-30 00:00:00
# Nashville
# finding the next urban station for Nashville
# finding the next urban station for Nashville
# finding the next urban station for Nashville
# Found a pair for Nashville
# Urban start/end is: 2001-10-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 2000-05-01 00:00:00 to 2016-08-31 00:00:00
# Memphis
# finding the next urban station for Memphis
# finding the next rural station for Memphis
# USC00033821 1959-05-01 2016-12-31 9.0 ['TMIN', 'SX01', 'SX02', 'SNWD', 'TOBS', 'DAPR', 'DAEV', 'WT05', 'WT04', 'WT06', 'WT01', 'SN01', 'WT03', 'SX31', 'SX32', 'SN02', 'EVAP', 'MDEV', 'DAWM', 'DASF', 'TMAX', 'MDSF', 'SNOW', 'MDPR', 'WT10', 'MDWM', 'SN32', 'SN31', 'WDMV', 'PRCP'] 0.998129342598
# Found a pair for Memphis
# Urban start/end is: 1998-03-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1959-05-01 00:00:00 to 2016-12-31 00:00:00
# Norfolk
# Found a pair for Norfolk
# Urban start/end is: 2003-04-01 00:00:00 to 2016-06-30 00:00:00
# Rural start/end is: 2004-07-01 00:00:00 to 2016-07-31 00:00:00
# Milwaukee
# finding the next urban station for Milwaukee
# finding the next urban station for Milwaukee
# finding the next rural station for Milwaukee
# increasing search radius
# USC00478316 1995-01-01 2016-10-31 13.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'WT11', 'SNWD', 'WT04', 'WT05', 'WESD', 'PRCP', 'WT01', 'WT03'] 0.969802244789
# Found a pair for Milwaukee
# Urban start/end is: 2004-10-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1995-01-01 00:00:00 to 2016-10-31 00:00:00
# Buffalo
# finding the next rural station for Buffalo
# USC00301625 2005-03-01 2016-10-31 18.0 ['WESF', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'WT11', 'SNWD', 'WT04', 'WT05', 'WESD', 'PRCP', 'WT01', 'WT06', 'WT03'] 0.974879743453
# Found a pair for Buffalo
# Urban start/end is: 2004-01-01 00:00:00 to 2016-06-30 00:00:00
# Rural start/end is: 2005-03-01 00:00:00 to 2016-10-31 00:00:00
# Pittsburgh
# finding the next urban station for Pittsburgh
# finding the next urban station for Pittsburgh
# finding the next rural station for Pittsburgh
# increasing search radius
# USC00364835 2008-02-01 2010-04-30 5.0 ['TMIN', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'WT11', 'SNWD', 'WT05', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.0980758952432
# finding the next rural station for Pittsburgh
# USC00365212 1989-07-01 2016-07-31 10.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'WT11', 'DAPR', 'SNWD', 'WT04', 'WT05', 'WESD', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.753874933191
# Found a pair for Pittsburgh
# Urban start/end is: 1991-09-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1989-07-01 00:00:00 to 2016-07-31 00:00:00
# Minneapolis
# Found a pair for Minneapolis
# Urban start/end is: 1992-06-01 00:00:00 to 2016-06-30 00:00:00
# Rural start/end is: 2003-05-01 00:00:00 to 2016-11-30 00:00:00
# Honolulu
# finding the next urban station for Honolulu
# finding the next urban station for Honolulu
# finding the next rural station for Honolulu
# USC00516222 2006-01-01 2009-03-31 13.0 ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'PRCP', 'MDPR'] 0.26269374666
# finding the next rural station for Honolulu
# USC00519526 1951-06-01 2016-11-30 17.0 ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'PRCP', 'MDPR'] 0.0
# finding the next rural station for Honolulu
# USC00519281 2008-06-01 2016-10-31 23.0 ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'PRCP', 'MDPR'] 0.704436130412
# finding the next rural station for Honolulu
# USC00519523 1969-09-01 2016-12-31 24.0 ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'PRCP', 'MDPR', 'WT03'] 0.967931587386
# Found a pair for Honolulu
# Urban start/end is: 1965-01-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1969-09-01 00:00:00 to 2016-12-31 00:00:00
# Seattle
# finding the next rural station for Seattle
# USC00454486 1916-04-01 2016-11-30 15.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'WT09', 'WT08', 'SNWD', 'WT11', 'WT05', 'WT04', 'WT07', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.987707108498
# Found a pair for Seattle
# Urban start/end is: 1948-01-01 00:00:00 to 2016-09-30 00:00:00
# Rural start/end is: 1915-01-01 00:00:00 to 2016-11-30 00:00:00
# Phoenix
# finding the next urban station for Phoenix
# finding the next urban station for Phoenix
# finding the next urban station for Phoenix
# finding the next rural station for Phoenix
# increasing search radius
# USC00022109 1929-01-01 2016-12-31 3.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.975414216996
# Found a pair for Phoenix
# Urban start/end is: 1953-01-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1930-07-01 00:00:00 to 2016-12-31 00:00:00
# San Diego
# finding the next rural station for San Diego
# increasing search radius
# USC00043914 1942-09-01 2016-12-31 4.0 ['WT11', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'WT08', 'SNWD', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.994120791021
# Found a pair for San Diego
# Urban start/end is: 1998-02-01 00:00:00 to 2016-06-30 00:00:00
# Rural start/end is: 1942-09-01 00:00:00 to 2016-12-31 00:00:00
# St. Louis
# Found a pair for St. Louis
# Urban start/end is: 1968-08-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1974-04-01 00:00:00 to 2016-11-30 00:00:00
# New Orleans
# finding the next rural station for New Orleans
# USC00165624 1984-05-01 2011-01-31 13.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.23115980759
# finding the next rural station for New Orleans
# increasing search radius
# USC00163331 1998-09-01 2002-04-30 6.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'WT11', 'SNWD', 'WT04', 'PRCP', 'WT03'] 0.0
# finding the next rural station for New Orleans
# USR0000MHCK 2002-12-01 2016-11-30 12.0 ['TAVG', 'TMAX', 'TMIN'] 0.994922501336
# Found a pair for New Orleans
# Urban start/end is: 1997-09-01 00:00:00 to 2016-06-30 00:00:00
# Rural start/end is: 2002-12-01 00:00:00 to 2016-11-30 00:00:00
# Dallas
# finding the next rural station for Dallas
# increasing search radius
# USR0000TLBJ 2000-01-01 2016-09-30 8.0 ['TAVG', 'TMAX', 'TMIN'] 1.00026723677
# Found a pair for Dallas
# Urban start/end is: 1939-08-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 2000-01-01 00:00:00 to 2016-09-30 00:00:00
# Boston
# finding the next urban station for Boston
# finding the next urban station for Boston
# finding the next rural station for Boston
# increasing search radius
# USC00192026 1970-06-01 1990-06-30 24.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.0
# finding the next rural station for Boston
# No pair found for Boston
# Tampa
# Found a pair for Tampa
# Urban start/end is: 1892-09-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 2001-08-01 00:00:00 to 2016-09-30 00:00:00
# Philadelphia
# finding the next rural station for Philadelphia
# increasing search radius
# USC00280331 2011-04-01 2016-11-30 7.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT04', 'PRCP', 'WT01', 'MDPR'] 0.263228220203
# finding the next rural station for Philadelphia
# USC00361080 1978-12-01 2016-11-30 14.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.909139497595
# Found a pair for Philadelphia
# Urban start/end is: 1994-03-01 00:00:00 to 2016-06-30 00:00:00
# Rural start/end is: 1978-12-01 00:00:00 to 2016-11-30 00:00:00
# Detroit
# finding the next urban station for Detroit
# finding the next urban station for Detroit
# finding the next rural station for Detroit
# increasing search radius
# USC00205450 1984-08-01 2006-11-30 11.0 ['WT11', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.122394441475
# finding the next rural station for Detroit
# USC00202268 1996-08-01 1999-05-31 11.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.0
# finding the next rural station for Detroit
# USC00206982 2001-11-01 2017-01-31 12.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'WT11', 'SNWD', 'WT04', 'WT05', 'WESD', 'PRCP', 'WT01', 'WT03'] 0.994655264564
# Found a pair for Detroit
# Urban start/end is: 1952-08-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 2001-11-01 00:00:00 to 2017-01-31 00:00:00
# San Francisco
# Found a pair for San Francisco
# Urban start/end is: 1921-01-01 00:00:00 to 2016-08-31 00:00:00
# Rural start/end is: 1998-10-01 00:00:00 to 2016-08-31 00:00:00
# Denver
# Found a pair for Denver
# Urban start/end is: 1997-11-01 00:00:00 to 2016-06-30 00:00:00
# Rural start/end is: 1995-08-01 00:00:00 to 2016-08-31 00:00:00
# Houston
# finding the next urban station for Houston
# finding the next urban station for Houston
# Found a pair for Houston
# Urban start/end is: 2000-12-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1946-06-01 00:00:00 to 2016-12-31 00:00:00
# Miami
# finding the next rural station for Miami
# increasing search radius
# USC00086406 1978-06-01 2016-09-30 4.0 ['WT06', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.983965793693
# Found a pair for Miami
# Urban start/end is: 1940-10-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 1978-06-01 00:00:00 to 2016-09-30 00:00:00
# Atlanta
# finding the next urban station for Atlanta
# finding the next rural station for Atlanta
# increasing search radius
# USC00094688 2004-04-01 2016-11-30 5.0 ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'PRCP', 'MDPR'] 0.946819882416
# Found a pair for Atlanta
# Urban start/end is: 1994-09-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 2004-04-01 00:00:00 to 2016-11-30 00:00:00
# Chicago
# finding the next rural station for Chicago
# increasing search radius
# USC00125174 1963-07-01 2016-12-31 15.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'WT11', 'DAPR', 'WT03', 'SNWD', 'WT04', 'WT05', 'WESD', 'PRCP', 'WT01', 'MDPR', 'DASF'] 0.994922501336
# Found a pair for Chicago
# Urban start/end is: 2005-06-01 00:00:00 to 2016-10-31 00:00:00
# Rural start/end is: 1963-07-01 00:00:00 to 2016-12-31 00:00:00
# Los Angeles
# finding the next urban station for Los Angeles
# Found a pair for Los Angeles
# Urban start/end is: 1906-04-01 00:00:00 to 2016-12-31 00:00:00
# Rural start/end is: 2002-11-01 00:00:00 to 2016-11-30 00:00:00
# Washington, D.C.
# finding the next rural station for Washington, D.C.
# increasing search radius
# USC00189030 1940-07-01 1996-11-30 10.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'SNOW', 'DAPR', 'SNWD', 'WT11', 'WT05', 'WT04', 'PRCP', 'WT01', 'MDPR', 'WT03'] 0.0
# finding the next rural station for Washington, D.C.
# USC00185865 1974-09-01 2016-12-31 10.0 ['WESF', 'TMIN', 'TOBS', 'TMAX', 'SNOW', 'WT11', 'DAPR', 'WT16', 'SNWD', 'WT04', 'WT05', 'WESD', 'WT18', 'PRCP', 'WT01', 'MDPR', 'WT03', 'WT06'] 0.989845002672
# Found a pair for Washington, D.C.
# Urban start/end is: 1948-08-01 00:00:00 to 2016-11-30 00:00:00
# Rural start/end is: 1974-09-01 00:00:00 to 2016-12-31 00:00:00
# New York
# finding the next rural station for New York
# increasing search radius
# USC00281582 1893-04-01 2017-01-31 25.0 ['WT06', 'TMIN', 'WT14', 'TOBS', 'TMAX', 'MDSF', 'SNOW', 'DAPR', 'WT16', 'WT03', 'SNWD', 'WT11', 'WT05', 'WT04', 'WT18', 'PRCP', 'WT01', 'MDPR', 'DASF', 'WT08'] 0.871993586317
# Found a pair for New York
# Urban start/end is: 1876-01-01 00:00:00 to 2016-08-31 00:00:00
# Rural start/end is: 1893-04-01 00:00:00 to 2017-01-31 00:00:00

# %%
outFile
# Out:
# 'USpairs2005-2015.csv'

# %%
pairs
# Out:
#                 City Urban station  Urban Lat  Urban Lon  Urban brightness  \
# 0               Mesa   USC00022782     33.419   -111.644              63.0
# 1      Grand Prairie   USC00410337     32.757    -97.073              63.0
# 2             Irvine   USC00047888     33.744   -117.866              63.0
# 3          New Haven   USC00307134     40.961    -72.715              37.0
# 4    Fort Lauderdale   USC00083168     26.140    -80.106              63.0
# 5         Long Beach   USW00023129     33.811   -118.146              63.0
# 6           Hartford   USW00014752     41.736    -72.650              62.0
# 7         Providence   USC00379423     41.984    -71.490              60.0
# 8         Birmingham   USC00013781     33.272    -86.833              61.0
# 9     St. Petersburg   USC00087205     28.023    -82.142              63.0
# 10    Virginia Beach   USW00013769     36.816    -76.033              63.0
# 11           Oakland   USC00046336     37.798   -122.264              63.0
# 12   West Palm Beach   USC00086764     26.826    -80.148              63.0
# 13        Louisville   USW00013810     38.228    -85.663              63.0
# 14         Charlotte   USC00313356     35.265    -81.143              63.0
# 15          Columbus   USC00338951     40.126    -82.943              62.0
# 16    San Bernardino   USC00047470     33.951   -117.388              63.0
# 17        Bridgeport           NaN        NaN        NaN               NaN
# 18          St. Paul   USC00218450     44.984    -93.177              63.0
# 19            Tucson   USR0000ASAG     32.316   -110.813              47.0
# 20            Fresno   USC00043256     36.767   -119.709              63.0
# 21       Albuquerque   USC00296754     35.139   -106.710              63.0
# 22       Kansas City   USC00234154     39.064    -94.386              62.0
# 23             Tulsa   USC00341828     36.322    -95.580              50.0
# 24         Ft. Worth   USW00013961     32.819    -97.361              63.0
# 25            Austin   USC00410431     30.224    -97.732              63.0
# 26           El Paso   USC00298535     32.282   -106.759              63.0
# 27           Orlando   USC00082229     29.018    -81.310              62.0
# 28      Jacksonville   USC00084366     30.287    -81.392              61.0
# 29      Indianapolis   USW00093819     39.707    -86.280              62.0
# ..               ...           ...        ...        ...               ...
# 40           Raleigh   USC00317079     35.794    -78.698              63.0
# 41         Cleveland   USW00014820     41.413    -81.860              62.0
# 42        Cincinnati   USC00331515     39.154    -84.623              62.0
# 43         Nashville   USC00401039     35.990    -86.778              61.0
# 44           Memphis   USC00226527     34.953    -89.829              62.0
# 45           Norfolk   USC00446147     36.870    -76.228              63.0
# 46         Milwaukee   USC00473391     42.937    -88.029              63.0
# 47           Buffalo   USC00306047     43.021    -78.846              63.0
# 48        Pittsburgh   USC00362574     40.501    -80.083              60.0
# 49       Minneapolis   USC00214884     44.978    -93.246              63.0
# 50          Honolulu   USC00519397     21.271   -157.816              62.0
# 51           Seattle   USW00024234     47.530   -122.300              63.0
# 52           Phoenix   USC00028499     33.425   -111.921              63.0
# 53         San Diego   USW00003131     32.815   -117.139              63.0
# 54         St. Louis   USC00237452     38.629    -90.270              63.0
# 55       New Orleans   USC00168941     29.910    -90.034              63.0
# 56            Dallas   USW00013960     32.851    -96.855              63.0
# 57            Boston           NaN        NaN        NaN               NaN
# 58             Tampa   USC00087205     28.023    -82.142              63.0
# 59      Philadelphia   USC00366886     39.957    -75.172              63.0
# 60           Detroit   USC00202015     42.319    -83.237              63.0
# 61     San Francisco   USW00023272     37.770   -122.426              63.0
# 62            Denver   USC00052223     39.729   -105.008              63.0
# 63           Houston   USW00012977     29.622    -95.656              63.0
# 64             Miami   USC00083909     25.817    -80.285              63.0
# 65           Atlanta   USC00094700     33.531    -84.354              62.0
# 66           Chicago   USC00111550     41.855    -87.609              63.0
# 67       Los Angeles   USW00093134     34.051   -118.235              63.0
# 68  Washington, D.C.   USC00186350     38.913    -76.970              63.0
# 69          New York   USW00094728     40.778    -73.969              63.0
#
#            Urban start  Urban end Rural station  Rural Lat  Rural Lon  \
# 0           2002-08-01 2016-10-31   USC00020288     33.462   -111.481
# 1  1893-01-01 00:00:00 2016-09-30   USR0000TLBJ     33.172    -97.375
# 2           1916-05-01 2016-11-30   USR0000CFRE     33.808   -117.711
# 3           1938-03-01 2016-09-30   USC00065445     41.972    -73.220
# 4           1952-04-01 2016-09-30   USR0000FCAC     25.390    -80.680
# 5           1949-01-01 2016-12-31   USR0000CCHI     34.331   -118.030
# 6           1920-01-01 2016-12-31   USC00060227     41.841    -73.008
# 7           1967-11-01 2016-10-31   USC00375270     41.856    -71.733
# 8           2003-12-01 2016-10-31   USC00010505     33.452    -87.357
# 9  1892-09-01 00:00:00 2016-10-31   USC00083153     27.570    -82.137
# 10          1945-03-01 2016-12-31   USC00440385     36.661    -75.911
# 11          1970-10-01 2016-12-31   USR0000CTRA     37.833   -122.066
# 12          2002-11-01 2016-10-31   USC00088368     26.470    -80.640
# 13          2000-09-01 2016-10-31   USC00150955     37.956    -86.116
# 14 1890-01-01 00:00:00 2016-09-30   USC00389625     34.938    -81.225
# 15          1952-05-01 2016-10-31   USC00331404     40.291    -82.654
# 16 1893-01-01 00:00:00 2016-11-30   USR0000CBPI     34.319   -117.013
# 17                 NaT        NaT           NaN        NaN        NaN
# 18          1993-09-01 2016-10-31   USR0000MCSA     45.302    -93.101
# 19          1995-06-01 2016-08-31   USR0000ASOL     32.403   -110.711
# 20          1999-01-01 2016-06-30   USR0000CFAN     36.883   -119.465
# 21          1994-04-01 2016-05-31   USC00294366     35.388   -106.543
# 22          1990-01-01 2016-10-31   USC00146333     39.117    -95.410
# 23          1900-04-01 2016-10-31   USC00344812     36.150    -96.250
# 24          1946-09-01 2016-10-31   USC00413289     32.847    -97.476
# 25          2004-02-01 2016-06-30   USR0000TBEL     30.566    -98.038
# 26          1959-04-01 2016-08-31   USC00294426     32.616   -106.740
# 27 1892-01-01 00:00:00 2016-10-31   USR0000FCEN     29.105    -81.630
# 28          1944-07-01 2016-12-31   USW00063856     30.807    -81.459
# 29          1948-01-01 2016-12-31   USR0000IHAR     39.000    -86.422
# ..                 ...        ...           ...        ...        ...
# 40 1892-01-01 00:00:00 2016-10-31   USC00316122     35.680    -78.915
# 41          1938-05-01 2016-12-31   USC00333780     41.307    -81.013
# 42          1970-08-01 2016-10-31   USR0000KCRI     38.769    -84.601
# 43          2001-10-01 2016-10-31   USC00403636     36.340    -86.827
# 44          1998-03-01 2016-10-31   USC00033821     35.687    -90.096
# 40              14.0          2003-04-01 2016-10-31
# 41              11.0 1893-06-01 00:00:00 2016-11-30
# 42              18.0          2003-03-01 2016-09-30
# 43              16.0          2000-05-01 2016-08-31
# 44               9.0          1959-05-01 2016-12-31
# 45               5.0          2004-07-01 2016-07-31
# 46              13.0          1995-01-01 2016-10-31
# 47              18.0          2005-03-01 2016-10-31
# 48              10.0          1989-07-01 2016-07-31
# 49              15.0          2003-05-01 2016-11-30
# 50              24.0          1969-09-01 2016-12-31
# 51              15.0          1915-01-01 2016-11-30
# 52               3.0          1930-07-01 2016-12-31
# 53               4.0          1942-09-01 2016-12-31
# 54               7.0          1974-04-01 2016-11-30
# 55              12.0          2002-12-01 2016-11-30
# 56               8.0          2000-01-01 2016-09-30
# 57               NaN                 NaT        NaT
# 58               4.0          2001-08-01 2016-09-30
# 59              14.0          1978-12-01 2016-11-30
# 60              12.0          2001-11-01 2017-01-31
# 61               9.0          1998-10-01 2016-08-31
# 62               8.0          1995-08-01 2016-08-31
# 63              15.0          1946-06-01 2016-12-31
# 64               4.0          1978-06-01 2016-09-30
# 65               5.0          2004-04-01 2016-11-30
# 66              15.0          1963-07-01 2016-12-31
# 67               9.0          2002-11-01 2016-11-30
# 68              10.0          1974-09-01 2016-12-31
# 69              25.0 1893-04-01 00:00:00 2017-01-31
#
# [70 rows x 13 columns]

# %%
# Out:
# (70, 13)

# %%
outFile
# Out:
# 'USpairs_stationlengths_stationavailability75_noairport.csv'

# %%
pairs[pairs.City.str.contains('Provid')][['Urban Lon', 'Urban Lat']].values[0]
# Out:
# array([-71.49 ,  41.984])

# %%
np.array([[-71.414979700000004, 41.821102310000001],
         [-71.49 ,  41.984]])
# Out:
# array([[-71.4149797 ,  41.82110231],
#        [-71.49      ,  41.984     ]])

# %%
pairs
# Out:
#                 City Urban station  Urban Lat  Urban Lon  Urban brightness  \
# 0               Mesa   USC00022782     33.419   -111.644              63.0
# 1      Grand Prairie   USC00410337     32.757    -97.073              63.0
# 2             Irvine   USC00047888     33.744   -117.866              63.0
# 3          New Haven   USC00307134     40.961    -72.715              37.0
# 4    Fort Lauderdale   USC00083168     26.140    -80.106              63.0
# 5         Long Beach   USW00023129     33.811   -118.146              63.0
# 6           Hartford   USW00014752     41.736    -72.650              62.0
# 7         Providence   USC00379423     41.984    -71.490              60.0
# 8         Birmingham   USC00013781     33.272    -86.833              61.0
# 9     St. Petersburg   USC00087205     28.023    -82.142              63.0
# 10    Virginia Beach   USW00013769     36.816    -76.033              63.0
# 11           Oakland   USC00046336     37.798   -122.264              63.0
# 12   West Palm Beach   USC00086764     26.826    -80.148              63.0
# 13        Louisville   USW00013810     38.228    -85.663              63.0
# 14         Charlotte   USC00313356     35.265    -81.143              63.0
# 15          Columbus   USC00338951     40.126    -82.943              62.0
# 16    San Bernardino   USC00047470     33.951   -117.388              63.0
# 17        Bridgeport           NaN        NaN        NaN               NaN
# 18          St. Paul   USC00218450     44.984    -93.177              63.0
# 19            Tucson   USR0000ASAG     32.316   -110.813              47.0
# 20            Fresno   USC00043256     36.767   -119.709              63.0
# 21       Albuquerque   USC00296754     35.139   -106.710              63.0
# 22       Kansas City   USC00234154     39.064    -94.386              62.0
# 23             Tulsa   USC00341828     36.322    -95.580              50.0
# 24         Ft. Worth   USW00013961     32.819    -97.361              63.0
# 25            Austin   USC00410431     30.224    -97.732              63.0
# 26           El Paso   USC00298535     32.282   -106.759              63.0
# 27           Orlando   USC00082229     29.018    -81.310              62.0
# 28      Jacksonville   USC00084366     30.287    -81.392              61.0
# 29      Indianapolis   USW00093819     39.707    -86.280              62.0
# ..               ...           ...        ...        ...               ...
# 40           Raleigh   USC00317079     35.794    -78.698              63.0
# 41         Cleveland   USW00014820     41.413    -81.860              62.0
# 42        Cincinnati   USC00331515     39.154    -84.623              62.0
# 43         Nashville   USC00401039     35.990    -86.778              61.0
# 44           Memphis   USC00226527     34.953    -89.829              62.0
# 45           Norfolk   USC00446147     36.870    -76.228              63.0
# 46         Milwaukee   USC00473391     42.937    -88.029              63.0
# 47           Buffalo   USC00306047     43.021    -78.846              63.0
# 48        Pittsburgh   USC00362574     40.501    -80.083              60.0
# 49       Minneapolis   USC00214884     44.978    -93.246              63.0
# 50          Honolulu   USC00519397     21.271   -157.816              62.0
# 51           Seattle   USW00024234     47.530   -122.300              63.0
# 52           Phoenix   USC00028499     33.425   -111.921              63.0
# 53         San Diego   USW00003131     32.815   -117.139              63.0
# 54         St. Louis   USC00237452     38.629    -90.270              63.0
# 55       New Orleans   USC00168941     29.910    -90.034              63.0
# 56            Dallas   USW00013960     32.851    -96.855              63.0
# 57            Boston           NaN        NaN        NaN               NaN
# 58             Tampa   USC00087205     28.023    -82.142              63.0
# 59      Philadelphia   USC00366886     39.957    -75.172              63.0
# 60           Detroit   USC00202015     42.319    -83.237              63.0
# 61     San Francisco   USW00023272     37.770   -122.426              63.0
# 62            Denver   USC00052223     39.729   -105.008              63.0
# 63           Houston   USW00012977     29.622    -95.656              63.0
# 64             Miami   USC00083909     25.817    -80.285              63.0
# 65           Atlanta   USC00094700     33.531    -84.354              62.0
# 66           Chicago   USC00111550     41.855    -87.609              63.0
# 67       Los Angeles   USW00093134     34.051   -118.235              63.0
# 68  Washington, D.C.   USC00186350     38.913    -76.970              63.0
# 69          New York   USW00094728     40.778    -73.969              63.0
#
#            Urban start  Urban end Rural station  Rural Lat  Rural Lon  \
# 0           2002-08-01 2016-10-31   USC00020288     33.462   -111.481
# 1  1893-01-01 00:00:00 2016-09-30   USR0000TLBJ     33.172    -97.375
# 2           1916-05-01 2016-11-30   USR0000CFRE     33.808   -117.711
# 3           1938-03-01 2016-09-30   USC00065445     41.972    -73.220
# 4           1952-04-01 2016-09-30   USR0000FCAC     25.390    -80.680
# 5           1949-01-01 2016-12-31   USR0000CCHI     34.331   -118.030
# 6           1920-01-01 2016-12-31   USC00060227     41.841    -73.008
# 7           1967-11-01 2016-10-31   USC00375270     41.856    -71.733
# 8           2003-12-01 2016-10-31   USC00010505     33.452    -87.357
# 9  1892-09-01 00:00:00 2016-10-31   USC00083153     27.570    -82.137
# 10          1945-03-01 2016-12-31   USC00440385     36.661    -75.911
for i in range(0, pairs.shape[0]): #range(31,32): # for baltimore
    lat = atlas.iloc[i]['lat']
    lon = atlas.iloc[i]['lng']
    city = atlas.iloc[i]['city_ascii']
    urban_distance = scipy.spatial.distance.pdist(np.array([[lon, lat],
         pairs[pairs.City.str.contains(city)][['Urban Lon', 'Urban Lat']].values[0] ]))
    rural_distance = scipy.spatial.distance.pdist(np.array([[lon, lat],
         pairs[pairs.City.str.contains(city)][['Rural Lon', 'Rural Lat']].values[0] ]))
    
    u_distances[i] = urban_distance
    r_distances[i] = rural_distance

# %%
pairs['Urban distance'] = u_distances
pairs['Rural distance'] = r_distances

# %%
pairs[(~np.isnan(pairs['Urban Lat']))].to_csv(outFile)

# %%
pairs[pairs['Urban distance'] < .1]
# Out:
#                 City Urban station  Urban Lat  Urban Lon  Urban brightness  \
# 0               Mesa   USC00022782     33.419   -111.644              63.0
# 1      Grand Prairie   USC00410337     32.757    -97.073              63.0
# 2             Irvine   USC00047888     33.744   -117.866              63.0
# 4    Fort Lauderdale   USC00083168     26.140    -80.106              63.0
# 5         Long Beach   USW00023129     33.811   -118.146              63.0
# 6           Hartford   USW00014752     41.736    -72.650              62.0
# 10    Virginia Beach   USW00013769     36.816    -76.033              63.0
# 11           Oakland   USC00046336     37.798   -122.264              63.0
# 12   West Palm Beach   USC00086764     26.826    -80.148              63.0
# 13        Louisville   USW00013810     38.228    -85.663              63.0
# 20            Fresno   USC00043256     36.767   -119.709              63.0
# 21       Albuquerque   USC00296754     35.139   -106.710              63.0
# 24         Ft. Worth   USW00013961     32.819    -97.361              63.0
# 25            Austin   USC00410431     30.224    -97.732              63.0
# 31         Baltimore   USW00093784     39.281    -76.608              63.0
# 32          San Jose   USW00023293     37.359   -121.923              63.0
# 33        Sacramento   USW00023271     38.555   -121.416              63.0
# 34         Las Vegas   USW00053123     36.211   -115.195              63.0
# 40           Raleigh   USC00317079     35.794    -78.698              63.0
# 45           Norfolk   USC00446147     36.870    -76.228              63.0
# 49       Minneapolis   USC00214884     44.978    -93.246              63.0
# 50          Honolulu   USC00519397     21.271   -157.816              62.0
# 51           Seattle   USW00024234     47.530   -122.300              63.0
# 53         San Diego   USW00003131     32.815   -117.139              63.0
# 54         St. Louis   USC00237452     38.629    -90.270              63.0
# 55       New Orleans   USC00168941     29.910    -90.034              63.0
# 56            Dallas   USW00013960     32.851    -96.855              63.0
# 59      Philadelphia   USC00366886     39.957    -75.172              63.0
# 61     San Francisco   USW00023272     37.770   -122.426              63.0
# 62            Denver   USC00052223     39.729   -105.008              63.0
# 64             Miami   USC00083909     25.817    -80.285              63.0
# 67       Los Angeles   USW00093134     34.051   -118.235              63.0
# 68  Washington, D.C.   USC00186350     38.913    -76.970              63.0
# 69          New York   USW00094728     40.778    -73.969              63.0
#
#            Urban start  Urban end Rural station  Rural Lat  Rural Lon  \
# 0           2002-08-01 2016-10-31   USC00020288     33.462   -111.481
# 1  1893-01-01 00:00:00 2016-09-30   USR0000TLBJ     33.172    -97.375
# 2           1916-05-01 2016-11-30   USR0000CFRE     33.808   -117.711
# 34               5.0          1940-04-01 2016-12-31        0.025026
# 40              14.0          2003-04-01 2016-10-31        0.058785
# 45               5.0          2004-07-01 2016-07-31        0.055734
# 49              15.0          2003-05-01 2016-11-30        0.006115
# 50              24.0          1969-09-01 2016-12-31        0.055235
# 51              15.0          1915-01-01 2016-11-30        0.056559
# 53               4.0          1942-09-01 2016-12-31        0.041297
# 54               7.0          1974-04-01 2016-11-30        0.030617
# 55              12.0          2002-12-01 2016-11-30        0.085212
# 56               8.0          2000-01-01 2016-09-30        0.034410
# 59              14.0          1978-12-01 2016-11-30        0.043020
# 61               9.0          1998-10-01 2016-08-31        0.045321
# 62               8.0          1995-08-01 2016-08-31        0.026058
# 64               4.0          1978-06-01 2016-09-30        0.067615
# 67               9.0          2002-11-01 2016-11-30        0.082163
# 68              10.0          1974-09-01 2016-12-31        0.041650
# 69              25.0 1893-04-01 00:00:00 2017-01-31        0.030109
#
#     Rural distance
# 0         0.257912
# 1         0.602709
# 2         0.174437
# 4         0.919939
# 5         0.558898
# 6         0.335624
# 10        0.203662
# 11        0.167819
# 12        0.585050
# 13        0.455276
# 20        0.336386
# 21        0.299620
# 24        0.173031
# 25        0.420222
# 31        0.456836
# 32        0.212391
# 33        0.537247
# 34        0.267551
# 40        0.303852
# 45        0.299944
# 49        0.355575
# 50        0.149664
# 51        0.425754
# 53        0.591119
# 54        0.713087
# 55        0.881751
# 56        0.640386
# 59        0.501182
# 61        0.179615
# 62        0.322849
# 64        0.812127
# 67        0.282411
# 68        0.537294
# 69        0.526215

# %%
atlas[atlas['city'].str.contains('Provid')]
# Out:
#             city  city_ascii        lat       lng       pop  \
# 6871  Providence  Providence  41.821102 -71.41498  663726.5
#
#                        country iso2 iso3      province
# 6871  United States of America   US  USA  Rhode Island

# %%
pairs[pairs.City.str.contains('Provid')][['Urban Lon', 'Urban Lat']].values
# Out:
# array([[-71.49 ,  41.984]])

# %%
atlas[atlas['city'].str.contains('Provid')]['lng'].values
# Out:
# array([-71.4149797])

# %%
# check providence
lat = atlas[atlas['city'].str.contains('Provid')]['lat'].values[0]
lon = atlas[atlas['city'].str.contains('Provid')]['lng'].values[0]
#     lat = atlas.iloc[i]['lat']
#     lon = atlas.iloc[i]['lng']
#     city = atlas.iloc[i]['city_ascii']
city = 'Providence'
closeststations = tree.query([lon,lat], k =15, distance_upper_bound=1)
# Make sure the closest stations are within a finite distanc
closestInds = closeststations[1][~np.isinf(closeststations[0])]
# make sure that there are stations 
if closestInds.shape[0] > 0 : 
    urban = ghcn.Brightness[closestInds].argmax()
    rural = ghcn.Brightness[closestInds].argmin()
#     #         if urban != rural: 
#     urban_data = ulmo.ncdc.ghcn_daily.get_data(urban, as_dataframe=True, update=False)
#     rural_data = ulmo.ncdc.ghcn_daily.get_data(rural, as_dataframe=True, update=False)

#     number_urban_stations = (ghcn.Brightness[closestInds] >= brightness_threshold).sum() # number of urban stations is equivalent to brightness over 30
#     number_rural_stations = (ghcn.Brightness[closestInds] < brightness_threshold).sum() # number of rural stations is equivalent to brightness over 30

# %%
urban
# Out:
# 'USC00198367'

# %%
closeststations
# Out:
# (array([ 0.17934242,  0.20883027,  0.28371209,  0.30198826,  0.31195871,
#          0.31215564,  0.31241783,  0.3199293 ,  0.32761113,  0.35333929,
#          0.35499005,  0.35512523,  0.35876265,  0.36551376,  0.36781983]),
#  array([16818, 16813, 16817, 13724, 13700, 13738, 13743, 16816, 16815,
#         22560, 16814, 13720, 13737, 22561, 16812]))

# %%
ghcn.iloc[closestInds]
# Out:
#                 lat     lon  elevation state              name gsn flag  \
# GHCN ID
# USC00379423  41.984 -71.490       33.0    RI        WOONSOCKET      NaN
# USC00371875  41.668 -71.557       85.0    RI        COVENTRY 2      NaN
# USC00377581  41.626 -71.209       27.0    RI          TIVERTON      NaN
# USC00195984  41.992 -71.166       29.0    MA       NORTON WEST      NaN
# USC00192913  42.078 -71.238       82.0    MA           FOXBORO      NaN
# USC00198368  41.955 -71.133       30.0    MA      TAUNTON 4 NW      NaN
# USC00199316  42.133 -71.433       64.0    MA       WEST MEDWAY      NaN
# USC00375270  41.856 -71.733      192.0    RI  NORTH FOSTER 1 E      NaN
# USC00375215  41.500 -71.350        4.0    RI      NEWPORT ROSE      NaN
# USW00054796  41.491 -71.541       35.0    RI     KINGSTON 1 NW      NaN
# USC00374266  41.490 -71.543       35.0    RI          KINGSTON      NaN
# USC00194760  42.163 -71.511       85.0    MA           MILFORD      NaN
# USC00198367  41.900 -71.065        6.0    MA           TAUNTON      NaN
# USW00054797  41.478 -71.541       32.0    RI      KINGSTON 1 W      NaN
# USC00370218  41.566 -71.150       30.0    RI   ADAMSVILLE 2 NW      NaN
#
#             HCN/CRN FLAG   WMO ID  Brightness
# GHCN ID
# USC00379423          NaN      NaN        60.0
# USC00371875          NaN      NaN        60.0
# USC00377581          NaN      NaN        31.0
# USC00195984          NaN      NaN        48.0
# USC00192913          NaN      NaN        59.0
# USC00198368          NaN      NaN        60.0
# USC00199316           HC      NaN        53.0
# USC00375270          NaN      NaN        12.0
# USC00375215          NaN      NaN        43.0
# USW00054796           CR  72511.0        52.0
# USC00374266           HC      NaN        52.0
# USC00194760          NaN      NaN        57.0
# USC00198367           HC      NaN        61.0
# USW00054797           CR  72512.0        43.0
# USC00370218          NaN      NaN        15.0

# %%
closestInds
# Out:
# array([16818, 16813, 16817, 13724, 13700, 13738, 13743, 16816, 16815,
#        22560, 16814, 13720, 13737, 22561, 16812])

# %%
ghcn.Brightness[closestInds]
# Out:
# GHCN ID
# USC00379423    60.0
# USC00371875    60.0
# USC00377581    31.0
# USC00195984    48.0
# USC00192913    59.0
# USC00198368    60.0
# USC00199316    53.0
# USC00375270    12.0
# USC00375215    43.0
# USW00054796    52.0
# USC00374266    52.0
# USC00194760    57.0
# USC00198367    61.0
# USW00054797    43.0
# USC00370218    15.0
# Name: Brightness, dtype: float64

# %%
drop_cities = ['Mesa','Long Beach', 'Grand Prairie', 'Virginia Beach', 'St. Paul' ]

# %%
pairs[~np.isnan(pairs['Urban Lat'])].set_index(['City']).drop(drop_cities).to_csv(outFile)

# %%
outFile
# Out:
# 'USpairs_stationlengths_stationavailability75_noairport.csv'
